# %%
# %matplotlib inline
import random
random.seed(1234)
from string import punctuation
import pandas as pd
import gzip
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
# import nltk
# nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string
import spacy
import matplotlib.pyplot as plt
import pyLDAvis #python library for interactive topic model visualization
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()
spacy.prefer_gpu()
nlp = spacy.load("en_core_web_sm")

# import gensim.downloader
# w2v = gensim.downloader.load('word2vec-google-news-300')

# import logging
# logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# import warnings
# warnings.filterwarnings("ignore",category=DeprecationWarning)

import pickle
import numpy as np

# Sklearn
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from pprint import pprint

# Plotting tools
# import pyLDAvis
# import pyLDAvis.sklearn
# import matplotlib.pyplot as plt
# %matplotlib inline

from tqdm.notebook import tqdm as tqdm
tqdm.pandas()
import math
import nltk
from collections import defaultdict

nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])
from nltk.probability import FreqDist
from gensim.models.ldamulticore import LdaMulticore
from nltk import tokenize

stop_words = stopwords.words('english')

from nltk.stem import WordNetLemmatizer
  
lemmatizer = WordNetLemmatizer()

from numpy import dot
from numpy.linalg import norm
import random

import itertools

#nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer
sent = SentimentIntensityAnalyzer()

from scipy.spatial.distance import pdist
from scipy.spatial import distance
from scipy.cluster.hierarchy import dendrogram, linkage

from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

from nltk.tokenize import sent_tokenize

from sklearn.preprocessing import MinMaxScaler
from nltk import pos_tag

import re

# from sentence_transformers import SentenceTransformer
# sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')

# %% [markdown]
# # Read Data

# %%
df = pd.read_csv('./all_df.csv', index_col = False)

# %%
df0 = df.loc[(df.category_2 == 'Cats')]
df1 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Food') ]
df2 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Beds & Furniture')] 
df3 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Litter & Housebreaking')]
df4 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Toys')]
df5 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Treats')]
df6 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Grooming') ]
df7 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Feeding & Watering Supplies') ]
df8 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Cat Flaps, Steps, Nets & Pens') ]
df9 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Collars, Harnesses & Leashes') ]
df10 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Health Supplies')]
df11 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Educational Repellents')]
df12 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Carriers & Strollers')]
df13 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Cages')]
df14 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Memorials')]
df15 = df.loc[(df.category_2 == 'Cats') & (df.category_3 == 'Apparel')]

# %%
# with open ('./model/df1.pickle', 'wb') as handle:
#     pickle.dump(df1, handle)

# %%
with open ('./model/df1.pickle', 'rb') as handle:
    df1 = pickle.load(handle)

# %%
df1.head()
# Out:
#       Unnamed: 0      reviewerID        asin  \
# 7723        7723  A11W8BQHCSU0RA  B00008437P
# 7724        7724  A2J5FJRZV4994H  B00008437P
# 7725        7725   A7NB0VU0UQ88D  B00008437P
# 7726        7726  A1CV90TGSKF3DT  B00008437P
# 7727        7727   AZVMWL9E4T9ZD  B00008437P
#
#                                           reviewerName helpful  \
# 7723                                     Connie Gelfer  [0, 0]
# 7724                                    D. Bors "Dors"  [1, 1]
# 7725                                        Gail Aslin  [1, 1]
# 7726                                          Jennifer  [1, 2]
# 7727  JR Dixey "I am a technophile and librarian in...  [0, 0]
#
#                                              reviewText  overall  \
# 7723  I found these on sale and bought them on a whi...      5.0
# 7724  My kittens were crazy over these, but as they ...      4.0
# 7725  My cat absolutely loves spinners!  She carries...      5.0
# 7726  these were TINY and made out of very lightweig...      1.0
# 7727  I bought this cat toy thinking that I would us...      5.0
#
#                              summary  unixReviewTime   reviewTime  ...  \
# 7723                      need more!      1379462400  09 18, 2013  ...
# 7724          Favorite for some cats      1354579200   12 4, 2012  ...
# 7725              Best Cat Toy Ever!      1366675200  04 23, 2013  ...
# 7726  TINY, CHEAPLY MADE, CAT CHOKED      1335744000  04 30, 2012  ...
# 7727                  For Birds Too!      1389398400  01 11, 2014  ...
#
#                     salesRank  \
# 7723  {'Pet Supplies': 84866}
# 7724  {'Pet Supplies': 84866}
# 7725  {'Pet Supplies': 84866}
# 7726  {'Pet Supplies': 84866}
# 7727  {'Pet Supplies': 84866}
#
#                                                   imUrl  brand  \
# 7723  http://ecx.images-amazon.com/images/I/51R535q-...    NaN
# 7724  http://ecx.images-amazon.com/images/I/51R535q-...    NaN
# 7725  http://ecx.images-amazon.com/images/I/51R535q-...    NaN
# 7726  http://ecx.images-amazon.com/images/I/51R535q-...    NaN
# 7727  http://ecx.images-amazon.com/images/I/51R535q-...    NaN
#
#                               categories  \
# 7723  [['Pet Supplies', 'Cats', 'Food']]
# 7724  [['Pet Supplies', 'Cats', 'Food']]
# 7725  [['Pet Supplies', 'Cats', 'Food']]
# 7726  [['Pet Supplies', 'Cats', 'Food']]
# 7727  [['Pet Supplies', 'Cats', 'Food']]
#
#                                             description    category_1  \
# 7723  Crazy Spinners will drive your cat crazy! Perf...  Pet Supplies
# 7724  Crazy Spinners will drive your cat crazy! Perf...  Pet Supplies
# 7725  Crazy Spinners will drive your cat crazy! Perf...  Pet Supplies
# 7726  Crazy Spinners will drive your cat crazy! Perf...  Pet Supplies
# 7727  Crazy Spinners will drive your cat crazy! Perf...  Pet Supplies
#
#      category_2 category_3 category_4 category_5
# 7723       Cats       Food        NaN        NaN
# 7724       Cats       Food        NaN        NaN
# 7725       Cats       Food        NaN        NaN
# 7726       Cats       Food        NaN        NaN
# 7727       Cats       Food        NaN        NaN
#
# [5 rows x 23 columns]

# %%
sents = [tokenize.sent_tokenize(str(r)) for r in df1.reviewText.tolist()]
columns_name = ['Sentence' + str(i) for i in range(1, 31, 1)]
sents_df1 = pd.DataFrame([sen[:30] for sen in sents], columns = columns_name)

# %%
with open ('./model/sents_df1.pickle', 'wb') as handle:
    pickle.dump(sents_df1, handle)

# %%
with open ('./model/sents_df1.pickle', 'rb') as handle:
    sents_df1 = pickle.load(handle)

# %% [markdown]
# # Get attributes

# %%
def clean(sentence, stop_words):
    '''
    Clean sentence. 
            Parameters:
                    sentence (string): A string. 
                    stop_words (list): A list of words to be removed from a sentence. 
                    Lemmatize (boolean): A boolean to indicate whether or not to run lemmatization. . 
                    
            Returns:
                    _ (list): A list of cleaned tokens. 
    '''
    sen0 = ' '.join([word.lower() for word in str(sentence).split() if word.lower() not in stop_words])
    sen1 = sen0.translate(str.maketrans('', '', punctuation))
    tokens1 = [re.sub('[\d.,]' , '', word.lower()) for word in str(sen1).split() if word.lower() not in stop_words]
    sen2 = ' '.join(tokens1)
    tokens1 = [word.lemma_ for word in nlp(sen2)] 
    return tokens1

# def sent_to_words(sentences):
#     '''
#     Simplify and tokenize strings in an iterable.
    
#             Parameters:
#                     sentences (iterable): Review strings in a list or as a pandas.series.
                    
#             Returns:
#                     _ (generator): Simplify review tokens.  
#     '''
#     for sentence in sentences:
#         yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

def get_bigrams(data_words): 
    '''
    Form bigram.
    
        Parameters:
            data_words (iterable): token lists in an iterable. 

        Returns:
           _, _, bigram_pmi (data frame): Bigrams and their pmi scores in a Data Frame. 
    '''
    bigram_measures = nltk.collocations.BigramAssocMeasures()
    finder = nltk.collocations.BigramCollocationFinder.from_documents(data_words) 
    finder.apply_freq_filter(20)
    bigram_scores = finder.score_ngrams(bigram_measures.pmi)
    bigram_pmi = pd.DataFrame(bigram_scores)
    bigram_pmi.columns = ['bigram', 'pmi']
    bigram_pmi.sort_values(by='pmi', axis = 0, ascending = False, inplace = True)
    
    bigram_scores2 = finder.score_ngrams(bigram_measures.raw_freq)
    bigram_freq = pd.DataFrame(bigram_scores2)
    bigram_freq.columns = ['bigram', 'freq']
    bigram_freq.sort_values(by='freq', axis = 0, ascending = False, inplace = True)

    return finder, bigram_measures, bigram_pmi, bigram_freq

def bigram_filter(bigram):
    """
    Filter bigram. 
        
        Parameters:
            bigram (string): A bigram.

        Returns:
           _ (boolean): Decide whether or not to keep the bigram.
    """
    stop_words = stopwords.words('english')   
    tag = nltk.pos_tag(bigram)
    if tag[0][1] not in ['JJ', 'NN'] and tag[1][1] not in ['NN']: #we only want adjective + noun
        return False
    if bigram[0] in stop_words or bigram[1] in stop_words: 
        return False
    if 'n' in bigram or 't' in bigram:
        return False
    if 'PRON' in bigram: 
        return False
    if len(bigram[0]) <= 2 or len(bigram[1]) <= 2:
        return False
    return True

def get_trigrams(data_words): 
    trigram_measures = nltk.collocations.TrigramAssocMeasures()
    finder = nltk.collocations.TrigramCollocationFinder.from_documents(data_words) 
    finder.apply_freq_filter(20)
    trigram_scores = finder.score_ngrams(trigram_measures.pmi)

    trigram_pmi = pd.DataFrame(trigram_scores)
    trigram_pmi.columns = ['trigram', 'pmi']
    trigram_pmi.sort_values(by='pmi', axis = 0, ascending = False, inplace = True)
    
    trigram_scores2 = finder.score_ngrams(trigram_measures.raw_freq)
    trigram_freq = pd.DataFrame(trigram_scores2)
    trigram_freq.columns = ['trigram', 'freq']
    trigram_freq.sort_values(by='freq', axis = 0, ascending = False, inplace = True)

    return finder, trigram_measures, trigram_pmi, trigram_freq

def trigram_filter(trigram):
    tag = nltk.pos_tag(trigram)
    stop_words = stopwords.words('english')
    if tag[0][1] not in ['JJ', 'NN'] and tag[1][1] not in ['JJ','NN']:
        return False
    if trigram[0] in stop_words or trigram[-1] in stop_words or trigram[1] in stop_words:
        return False
    if 'n' in trigram or 't' in trigram:
        return False
    if 'PRON' in trigram:
        return False
    if len(trigram[0]) <= 2 or len(trigram[1]) <= 2 and len(trigram[2]) <= 2:
        return False
    return True 

def replace_ngram(x, bigrams, trigrams):
    '''
    Form ngram. 
        
        Parameters:
            bigram (string): a ngrams.

        Returns:
           x (string): A connected ngrams with underscore.  
    '''
    for gram in trigrams:
        x = x.replace(gram, '_'.join(gram.split()))
    for gram in bigrams:
        x = x.replace(gram, '_'.join(gram.split()))
    return x

def remove_stopwords(texts, extra_stopwords = []):
    '''
    Remove stopwords in an iterable (string or tokens).

        Parameters:
                texts (iterable): Review strings in a list or as a pandas.series.

        Returns:
                _ (list): Simplify review stirngs without stopwords.  
    '''
    stop_words = stopwords.words('english') + extra_stopwords
    return [[word for word in doc.split() if word not in stop_words] for doc in texts]

# def lemmatize_skip_ngrams(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
#     '''feed tokens'''
#     nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])
#     texts_out = []
#     for sent in texts:
#         doc = nlp(' '.join(sent)) 
#         if len(allowed_postags) > 0: 
#             returned_doc = []
#             for token in doc:
#                 if '_' in token.text:
#                     returned_token = token.text
#                 if token.pos_ in allowed_postags and '_' not in token.text:
#                     returned_token = token.lemma_
#                 if token.pos_ not in allowed_postags and '_' not in token.text:
#                     continue
#                 returned_doc.append(returned_token)
#             texts_out.append(returned_doc)
                    
#         else: 
#             returned_doc = []
#             for token in doc:
#                 if '_' in token.text:
#                     returned_token = token.text
#                 else: 
#                     returned_token = token.lemma_
#                 returned_doc.append(returned_token)
#             texts_out.append(returned_doc)
#     return texts_out
# Out:
# <>:14: DeprecationWarning: invalid escape sequence \d
# <>:14: DeprecationWarning: invalid escape sequence \d
# C:\Users\JIATIN~1\AppData\Local\Temp/ipykernel_17924/1870827167.py:14: DeprecationWarning: invalid escape sequence \d
#   tokens1 = [re.sub('[\d.,]' , '', word.lower()) for word in str(sen1).split() if word.lower() not in stop_words]

# %%
remove_words = ['dog',
 'cat',
 'food',
 'bed',
 'litter',
 'product',
 'love',
 'like',
 'well',
 'would',
 'work',
 'toy',
 'great',
 'make',
 'good',
 'time',
 'go',
 'I',
 'little',
 'small',
 'look',
 'try',
 'really',
 'seem',
 'recommend',
 'day',
 'month',
 'year',
 'much',
 'nice' , 
 'old', 
 'able', 
 'first', 
 'happy', 
 'thing', 
 'kitten'
]
extra_stopwords = ["don't", "donnt", "he's", "i'd", "would", "she's", "that's", \
                   "i'm", "can't", "i've", "they're", "we'll", "willn't", \
                   "isn't", "aren't", "wouldn't", "would've", "we've", "ve"] + \
                   ["cat", "food"] + remove_words
stop_words = sorted(list(set(stopwords.words('english')  + extra_stopwords + remove_words))) + \
['cat',
 'eat',
 'get',
 'dry',
 'feed',
 'buy',
 'give',
 'love',
 'find',
 'food',
 'try',
 'use',
 'bag',
 'go',
 'think',
 'wet',
 'know',
 'make',
 'seem',
 'say',
 'year',
 'kitty',
 'high',
 'see',
 'stuff',
 'come',
 'look',
 'keep',
 'want',
 'start',
 'every',
 'less',
 'free',
 'take',
 'need',
 'lot',
 'mix',
 'fancy',
 'many',
 'put',
 'feast',
 'good',
 'coat',
 'bit',
 'new',
 'something',
 'change',
 'case',
 'help',
 'sure',
 'month',
 'open',
 'box',
 'way',
 'bad',
 'big',
 'leave',
 'another',
 'last']

# %%
'last' in stop_words
# Out:
# True

# %%
len(sorted(set(stop_words)))
# Out:
# 275

# %%
def extract_attributes(reviews, stop_words):
    cleaned_tokens = [clean(sen, stop_words = stop_words) for sen in reviews]
    sens = [' '.join(sen) for sen in cleaned_tokens] 
    cleaned_tokens2 = [[token.lemma_ for token in nlp(sen) if token.text not in stop_words] for sen in tqdm(sens)] #different ways to lemmatize

    bifinder, bimeasures, bi_pmi, bi_freq = get_bigrams(tqdm(cleaned_tokens)) 
    tri_finder, tri_measures, tri_pmi, tri_freq = get_trigrams(tqdm(cleaned_tokens))
    
    bifinder, bimeasures, bi_pmi2, bi_freq2 = get_bigrams(tqdm(cleaned_tokens2)) 
    tri_finder, tri_measures, tri_pmi2, tri_freq2 = get_trigrams(tqdm(cleaned_tokens2))
    print('get bigrams.')
    cleaned_bi_pmi = bi_pmi[bi_pmi.progress_apply(lambda bigram: bigram_filter(bigram['bigram']) and bigram.pmi > 5, axis = 1)] 
    cleaned_bi_pmi2 = bi_pmi2[bi_pmi2.progress_apply(lambda bigram: bigram_filter(bigram['bigram']) and bigram.pmi > 5, axis = 1)] 
# 
    print('get trigrams.')
    cleaned_tri_pmi = tri_pmi[tri_pmi.progress_apply(lambda trigram: trigram_filter(trigram['trigram']) and trigram.pmi > 5, axis = 1)]
    cleaned_tri_pmi2 = tri_pmi2[tri_pmi2.progress_apply(lambda trigram: trigram_filter(trigram['trigram']) and trigram.pmi > 5, axis = 1)]

    print('get lemmatized tokens from spacy.')
    tags = [pos_tag(sen) for sen in tqdm(cleaned_tokens2)]
    print('get adjectives.')
    adj_tokens = [t[0] for sen in tags for t in sen if t[1] == 'JJ']
    print('get nouns.')
    noun_tokens = [t[0] for sen in tags for t in sen if t[1] == 'NN']
    print('get verbs.')
    verb_tokens = [t[0] for sen in tags for t in sen if t[1] == 'VB']

    return {
        'cleaned_tokens': cleaned_tokens,
        'cleaned_tokens2': cleaned_tokens2,
        'cleaned_bi_pmi': cleaned_bi_pmi, 
        'cleaned_tri_pmi': cleaned_tri_pmi,
        'cleaned_bi_pmi2': cleaned_bi_pmi2, 
        'cleaned_tri_pmi2': cleaned_tri_pmi2,
        'cleaned_bi_freq': bi_freq, 
        'cleaned_tri_freq': tri_freq,
        'cleaned_bi_freq2': bi_freq2, 
        'cleaned_tri_freq2': tri_freq2,
        'tags': tags,
        'adj_tokens': FreqDist(adj_tokens).most_common(100),
        'noun_tokens': FreqDist(noun_tokens).most_common(100),
        'verb_tokens': FreqDist(verb_tokens).most_common(100)
    }

# %%
df1_dict = extract_attributes(tqdm(df1.reviewText.tolist()), stop_words = stop_words)
# Out:
#   0%|          | 0/27843 [00:00<?, ?it/s]
#   0%|          | 0/27843 [00:00<?, ?it/s]
#   0%|          | 0/27843 [00:00<?, ?it/s]
#   0%|          | 0/27843 [00:00<?, ?it/s]
#   0%|          | 0/27843 [00:00<?, ?it/s]
#   0%|          | 0/27843 [00:00<?, ?it/s]
# get bigrams.
#   0%|          | 0/3352 [00:00<?, ?it/s]
#   0%|          | 0/2185 [00:00<?, ?it/s]
# get trigrams.
#   0%|          | 0/347 [00:00<?, ?it/s]
#   0%|          | 0/229 [00:00<?, ?it/s]
# get lemmatized tokens from spacy.
#   0%|          | 0/27843 [00:00<?, ?it/s]
# get adjectives.
# get nouns.
# get verbs.

# %%
with open ('./model/df1_dict.pickle', 'wb') as handle:
    pickle.dump(df1_dict, handle)

# %%
with open ('./model/df1_dict.pickle', 'rb') as handle:
    df1_dict = pickle.load(handle)

# %%
df1_sen1_dict = extract_attributes(tqdm(sents_df1.Sentence1.tolist()), stop_words = stop_words)
# Out:
#   0%|          | 0/27843 [00:00<?, ?it/s]
#   0%|          | 0/27843 [00:00<?, ?it/s]
#   0%|          | 0/27843 [00:00<?, ?it/s]
#   0%|          | 0/27843 [00:00<?, ?it/s]
#   0%|          | 0/27843 [00:00<?, ?it/s]
#   0%|          | 0/27843 [00:00<?, ?it/s]
# get bigrams.
#   0%|          | 0/553 [00:00<?, ?it/s]
#   0%|          | 0/552 [00:00<?, ?it/s]
# get trigrams.
#   0%|          | 0/52 [00:00<?, ?it/s]
#   0%|          | 0/52 [00:00<?, ?it/s]
# get lemmatized tokens from spacy.
#   0%|          | 0/27843 [00:00<?, ?it/s]
# get adjectives.
# get nouns.
# get verbs.

# %%
cleaned_sents_df1 = sents_df1.Sentence1.progress_apply(lambda x:clean(str(x), stop_words = stop_words))
# Out:
#   0%|          | 0/27843 [00:00<?, ?it/s]

# %%
#sents_df1.Sentence2.tolist()

# %%
#df1_sen2_dict = extract_attributes(tqdm(sents_df1.Sentence2.tolist()), stop_words = stop_words)

# %%
df1_dict['cleaned_bi_pmi2'] = df1_dict['cleaned_bi_pmi2'].reset_index(drop = True)
# remove_indexes1 = [44, 89, 84, 113, 114, 116, 117, 121, 122, 127, 137, 158, 159]
# keep_indexes1 = list(set(df1_dict['cleaned_bi_pmi2'][:160].index.tolist()) - set(remove_indexes1))

# %%
# df1_dict['cleaned_bi_pmi2'][:40]

# %%
keep_indexes = [6, 7, 8, 21, 23, 24, 26, 29, 30, 33, 35, 38, 68, 70, 75] #8? 
df1_dict['cleaned_bi_pmi2'].iloc[keep_indexes] # feature list 1
feature_lst1 = df1_dict['cleaned_bi_pmi2'].iloc[keep_indexes]['bigram'].tolist()

# %%
df1_dict['cleaned_bi_pmi2'][40:80]
feature_lst1
# Out:
# [('pyridoxine', 'hydrochloride'),
#  ('thiamine', 'mononitrate'),
#  ('powdered', 'cellulose'),
#  ('choline', 'chloride'),
#  ('fatty', 'acids'),
#  ('calcium', 'iodate'),
#  ('sodium', 'bisulfate'),
#  ('sodium', 'bisulfite'),
#  ('calcium', 'carbonate'),
#  ('ferrous', 'sulfate'),
#  ('zinc', 'oxide'),
#  ('folic', 'acid'),
#  ('ocean', 'whitefish'),
#  ('zinc', 'sulfate'),
#  ('break', 'bank')]

# %%
feature_lst1

# %%
df1_dict['cleaned_bi_pmi2'].iloc[keep_indexes]['bigram'].values

# %%
bigrams = [' '.join(x) for x in df1_dict['cleaned_bi_pmi2'].iloc[keep_indexes]['bigram'].values]
#trigrams = [' '.join(x) for x in df1_dict['cleaned_tri_pmi2'].iloc[retain_indexes].trigram.values]

# %%
sorted(bigrams) #'complete balanced', 'popular specialty', 'prime membership'

# %%
w2v.similarity('zinc', 'sodium')

# %%
sorted(list(set([w.split()[0] for w in bigrams] + [w.split()[1] for w in bigrams])))

# %%
#FreqDist([w for sen in df1_dict['cleaned_tokens2'] for w in sen]).most_common(20)

# %%
df1_dict['cleaned_tri_pmi'] = df1_dict['cleaned_tri_pmi'].reset_index(drop = True) #not high quality - manually select
df1_dict['cleaned_tri_pmi2'] = df1_dict['cleaned_tri_pmi2'].reset_index(drop = True) #not high quality - manually select
retain_indexes = [47, 48, 53, 78]
feature_lst3 = df1_dict['cleaned_tri_pmi2'].iloc[retain_indexes]['trigram'].tolist()

# %%
df1_dict['cleaned_tri_pmi2'][40:80]
feature_lst3
# Out:
# [('diversity', 'flavor', 'choose'),
#  ('vitamin', 'nutrient', 'mineral'),
#  ('deliver', 'front', 'door'),
#  ('royal', 'canin', 'special')]

# %%
trigrams = [' '.join(x) for x in df1_dict['cleaned_tri_pmi2'].iloc[retain_indexes]['trigram'].values]

# %%
sorted(trigrams)

# %%
sorted(trigrams + bigrams +
      list(set([w.split()[0] for w in bigrams] + [w.split()[1] for w in bigrams])) +
      list(set([w.split()[0] for w in trigrams] + [w.split()[1] for w in trigrams] + [w.split()[2] for w in trigrams])))

# %%
w2v.similarity('chronic', 'disease')

# %%
keep_indexes = [4, 8, 15, 28, 32, 38, 39, 65, 75, 76, 119] #product attributes
df1_dict['cleaned_bi_freq2'].iloc[keep_indexes]
feature_lst2 = df1_dict['cleaned_bi_freq2'].iloc[keep_indexes]['bigram'].tolist()

# %%
df1_dict['cleaned_bi_freq2'][80:120]
feature_lst2
# Out:
# [('natural', 'balance'),
#  ('subscribe', 'save'),
#  ('variety', 'pack'),
#  ('quality', 'ingredient'),
#  ('taste', 'wild'),
#  ('different', 'flavor'),
#  ('save', 'money'),
#  ('brown', 'rice'),
#  ('prescription', 'diet'),
#  ('waste', 'money'),
#  ('low', 'carb')]

# %%
df1_dict['cleaned_tri_freq2'] = df1_dict['cleaned_tri_freq2'].reset_index(drop = True) #not high quality - manually select
retain_indexes = [27, 17, 33, 34, 39, 41]
feature_lst4 = df1_dict['cleaned_tri_freq2'].iloc[retain_indexes]['trigram'].tolist()

# %%
df1_dict['cleaned_tri_freq2'][:40]
feature_lst4
# Out:
# [('subscribe', 'save', 'program'),
#  ('complete', 'balanced', 'nutrition'),
#  ('vitamin', 'b', 'supplement'),
#  ('vitamin', 'e', 'supplement'),
#  ('subscribe', 'save', 'option'),
#  ('urinary', 'tract', 'health')]

# %%
#[t[0] for t in df1_dict['noun_tokens']]

# %%
[t[0] for t in df1_dict['noun_tokens']]

feature_lst5 =  \
['brand',
 'flavor',
 'price',
 'ingredient',
 'quality',
 'chicken',
 'order',
 'variety',
 'grain',
 'meat',
 'smell',
 'formula',
 'treat',
 'taste',
 'wellness',
 'health',
# 'weight',
 'pack',
 'protein',
 'tuna',
 'science',
 'balance',
 'cost',
 'size',
 'friskie', #fresh
 'corn',
 'money',
 'turkey',
 'salmon',
 'amount',
 'byproduct',
 'beef',
 'ship',
 'care',
 'choice',
 'contain',
 'rice',
 'nutrition',
 'vitamin',
 'gravy',
 'chunk',
 'prescription',
 'waste']

# %%
[t[0] for t in df1_dict['adj_tokens']]

feature_lst6 = ['healthy',
 'expensive',
 'natural',
 'different',
 'cheap',
 'fish',
 'several',
 'kibble',
 'ingredient',
 'gravy',
 'organic',
 'fresh',
 'grainfree',
 'salmon',
 'nutritional',
'diabetic',
 'vegetable']

# %%
feature_lst = feature_lst1 +feature_lst2 + feature_lst3 + feature_lst4 + feature_lst5 + feature_lst6

# %% [markdown]
# # form ngram tokens

# %% [markdown]
# #### document level

# %%
stop_words + ['kittens']

# %%
[[token for token in sen if token not in stop_words] for sen in df1_dict['cleaned_tokens2']]
# Out:
# [['find',
#   'sale',
#   'buy',
#   'whim',
#   'omg',
#   'nuts',
#   'hardwood',
#   'spin',
#   'easily',
#   'funny',
#   'see',
#   'kitty',
#   'carry',
#   'around',
#   'mouth',
#   'drop',
#   'shoe',
#   'etc',
#   'fish',
#   'need',
#   'get',
#   'furniture',
#   'constantly',
#   'retrieve'],
#  ['kittens',
#   'crazy',
#   'grow',
#   'pay',
#   'attention',
#   'new',
#   'play',
#   'fetch',
#   'chase',
#   'bring',
#   'back',
#   'long',
#   'want',
#   'throw',
#   'carry',
#   'around',
#   'play',
#   'never',
#   'see',
#   'crazy',
#   'ten',
#   'usually',
#   'find',
#   'one',
#   'end',
#   'furniture',
#   'always',
#   'locate',
#   'one',
#   'want',
#   'one',
#   'think',
#   'overprice',
#   'piece',
#   'plastic',
#   'right',
#   'worth'],
#  ['absolutely',
#   'spinner',
#   'carry',
#   'around',
#   'mouth',
#   'toss',
#   'around',
#   'chase',
#   'far',
#   'favorite'],
#  ['tiny',
#   'lightweight',
#   'plastic',
#   'give',
#   'one',
#   'minute',
#   'chew',
#   'ball',
#   'tip',
#   'choke',
#   'stay',
#   'away'],
#  ['buy',
#   'thinking',
#   'use',
#   'spinner',
#   'basis',
#   'hang',
#   'curious',
#   'playful',
#   'parakeet',
#   'cage',
#   'parakeet',
#   'yet',
#   'vacillate',
#   'kind',
#   'string',
#   'hang',
#   'evening',
#   'spur',
#   'moment',
#   'decide',
#   'stick',
#   'individually',
#   'bar',
#   'cage',
#   'instead',
#   'hang',
#   'huge',
#   'hit',
#   'put',
#   'hour',
#   'ago',
#   'stop',
#   'play',
#   'pick',
#   'move',
#   'around',
#   'drop',
#   'onto',
#   'dish',
#   'pick',
#   'back',
#   'even',
#   'roll',
#   'around',
#   'floor',
#   'cage',
#   'hold',
#   'claw',
#   'riot'],
#  ['lil',
#   'perfect',
#   'quiet',
#   'entertainmentto',
#   'steal',
#   'big',
#   'swollow',
#   'perfect',
#   'lil',
#   'hardwood',
#   'tile',
#   'desk',
#   'hard',
#   'surface',
#   'spin',
#   'prounce',
#   'wish',
#   'come',
#   'high',
#   'count'],
#  ['definitely',
#   'favorite',
#   'tile',
#   'hard',
#   'wood',
#   'floor',
#   'also',
#   'fun',
#   'carpet'],
#  ['blu',
#   'somehow',
#   'find',
#   'one',
#   'around',
#   'house',
#   'toss',
#   'air',
#   'chase',
#   'tough',
#   'keep',
#   'find',
#   'one',
#   'order',
#   'x',
#   'pack',
#   'take',
#   'long',
#   'get',
#   'quite',
#   'frankly',
#   'could',
#   'find',
#   'anywhere',
#   'else'],
#  ['bad', 'part', 'get', 'lose', 'furniture', 'new', 'relocate'],
#  ['  ', 'playful', 'use', 'grrat', 'young', 'though'],
#  ['meet', 'nutritional', 'need'],
#  ['use',
#   'science',
#   'diet',
#   '  ',
#   'coat',
#   'soft',
#   'shiny',
#   'recently',
#   'adopt',
#   'rescue',
#   'find',
#   'week',
#   'box',
#   'stunk',
#   'bad',
#   'gag',
#   'finally',
#   'system',
#   '  ',
#   'science',
#   'diet',
#   'huge',
#   'difference',
#   'smell',
#   'price',
#   'high',
#   'compare',
#   'brand',
#   'find',
#   'store',
#   'however',
#   'nutritionally',
#   'satisfied',
#   'long',
#   'way',
#   'average',
#   '  ',
#   'one',
#   'bad',
#   'feed',
#   'anything',
#   'else'],
#  ['use',
#   'buy',
#   'science',
#   'diet',
#   'know',
#   'elderly',
#   'special',
#   'need',
#   'dry',
#   'decide',
#   'buy',
#   'bag',
#   'big',
#   'mistakehe',
#   'notice',
#   'dispenser',
#   'greasy',
#   'decide',
#   'give',
#   'another',
#   'house',
#   'result',
#   'iti',
#   'caretaker',
#   'feral',
#   'colony',
#   '  ',
#   'feral',
#   'even',
#   'crazy',
#   'eat',
#   'eagerly',
#   'pour',
#   'bag',
#   'bin',
#   'every',
#   'scoop',
#   'oil',
#   'scooper',
#   'also',
#   'plate',
#   'heavy',
#   'oil',
#   'even',
#   'smell',
#   'disgustingsadly',
#   'nine',
#   'different',
#   'say',
#   'buy',
#   'sample',
#   'locally',
#   'buy',
#   'bag',
#   'hit'],
#  ['always',
#   'start',
#   'plain',
#   'formula',
#   'six',
#   'later',
#   'start',
#   'eat',
#   'treat',
#   'human',
#   'milk',
#   'nothing',
#   'formula',
#   'rest',
#   'life',
#   'need',
#   'anything',
#   'else',
#   'perfect',
#   'weight',
#   'bad',
#   'world',
#   'fat',
#   'coat',
#   'hairball',
#   'never',
#   'kill',
#   'anyone',
#   'ever',
#   'get',
#   'sick',
#   'always',
#   'know',
#   'one',
#   'certain'],
#  ['market'],
#  ['put',
#   'title',
#   'box',
#   'since',
#   'ask',
#   'write',
#   'aboutit',
#   'take',
#   'bit',
#   'get',
#   'use',
#   'new',
#   'find',
#   'fillingso',
#   'eat',
#   '  ',
#   'cup',
#   'twice',
#   'way',
#   'control',
#   'weight',
#   'indoor',
#   'linving',
#   'onefloor',
#   'apartment',
#   'exercise',
#   'live',
#   'house',
#   '  ',
#   'set',
#   'stair',
#   'use',
#   'regularly',
#   'control',
#   'weight',
#   'necessary'],
#  ['senior', 'get', 'sick', 'eat', 'poor', 'quallity', 'eat', 'brand'],
#  ['use',
#   'one',
#   'five',
#   'figure',
#   'puker',
#   'die',
#   'get',
#   'another',
#   '  ',
#   'begin',
#   'vomit',
#   'frequently',
#   'lightbulb',
#   'finally',
#   'head',
#   'stop',
#   'science',
#   'diet',
#   'vomiting',
#   'stop',
#   'return',
#   'hmmmmmy',
#   'carpet'],
#  ['complaint',
#   'piece',
#   'bite',
#   'chew',
#   'piece',
#   'size',
#   'read',
#   'digestion',
#   'teethgum',
#   'piece',
#   'bit',
#   'big',
#   'chew'],
#  ['growth',
#   'health',
#   'pet',
#   'come',
#   'vet',
#   'healthy',
#   'weight',
#   'boisterous',
#   'job',
#   'science',
#   'diet'],
#  ['get',
#   'kitty',
#   'one',
#   'picky',
#   'feeding',
#   'purina',
#   'one',
#   'chicken',
#   'rice',
#   'purina',
#   'indoor',
#   'formula',
#   'one',
#   'one',
#   'indoor',
#   'formula',
#   'one',
#   'eat',
#   'hill',
#   'prescription',
#   'diet',
#   'kd',
#   'figure',
#   'since',
#   'eat',
#   'hope',
#   'start',
#   'give',
#   'today'],
#  ['  ',
#   'eat',
#   'heathy',
#   'vet',
#   'shelter',
#   'get',
#   'kitty',
#   'indoor',
#   'outdoor',
#   'keep',
#   'box',
#   'house',
#   'case',
#   'less',
#   'nutrient',
#   'stay',
#   'waste',
#   'worth',
#   'money',
#   'keep',
#   'healthy',
#   'coat',
#   'shiny'],
#  ['charlie',
#   'science',
#   'diet',
#   'exceptional',
#   'nutirional',
#   'taste',
#   'way',
#   'deliver',
#   'front',
#   'door',
#   'drag',
#   'car',
#   'porch',
#   'already',
#   'decide',
#   'store'],
#  ['coat',
#   'wonderfully',
#   'shiny',
#   'body',
#   'sleek',
#   'muscular',
#   'romeo',
#   'julia',
#   'healthy',
#   'due',
#   'nourishment',
#   'provide',
#   'formula'],
#  ['one',
#   'young',
#   'one',
#   'outside',
#   'size',
#   'pellet',
#   'exceptionally',
#   'automatic',
#   'feeder',
#   'ask',
#   'veterinarian',
#   'readily',
#   'okayed',
#   'suitable',
#   'diet',
#   'price',
#   'compare',
#   'favorably'],
#  ['vet',
#   'start',
#   'ago',
#   'every',
#   'bring',
#   'house',
#   'use',
#   'whatever',
#   'appropriate',
#   'age',
#   'etc',
#   'right',
#   'adult',
#   'healthy',
#   'trim',
#   'use',
#   'original',
#   'adult',
#   'optimal',
#   'care',
#   'absolutely',
#   'order',
#   'subscribe',
#   'save',
#   'convenient',
#   'mean',
#   'never',
#   'forget',
#   'pick',
#   'always',
#   'backup',
#   'bag',
#   'already',
#   'plus',
#   'free',
#   'shipping',
#   'easily',
#   'offset',
#   'dollar',
#   'difference',
#   'cheap',
#   'could',
#   'pay',
#   'elsewhere',
#   'town',
#   'mean',
#   'spend',
#   'gas',
#   'drive',
#   'across',
#   'town',
#   'discount',
#   'pet',
#   'store',
#   'come',
#   'home',
#   'preferred',
#   'deliver',
#   'front',
#   'door',
#   'thank',
#   'amazon'],
#  ['back',
#   'ship',
#   'house',
#   'several',
#   'never',
#   'run',
#   'back',
#   'wear',
#   'mommy',
#   'kitty',
#   'delight'],
#  ['order',
#   'hill',
#   'science',
#   '  ',
#   'early',
#   'nugget',
#   'large',
#   'hard',
#   'eati',
#   'receive',
#   'email',
#   'suggest',
#   'adult',
#   'optimal',
#   'care',
#   'problem',
#   'size',
#   'hardness',
#   'thank',
#   'help'],
#  ['science',
#   'diet',
#   'use',
#   'many',
#   'nutritionally',
#   'satisfied',
#   'long',
#   'way',
#   'coat',
#   'soft',
#   'shiny',
#   'price',
#   'high',
#   'compare',
#   'brand',
#   'find',
#   'store',
#   'worth',
#   'science',
#   'diet',
#   'huge',
#   'difference',
#   'general'],
#  ['quality',
#   'dry',
#   'course',
#   'always',
#   'keep',
#   'clean',
#   'fresh',
#   'water',
#   'available'],
#  ['read',
#   'review',
#   'see',
#   'many',
#   'similar',
#   'one',
#   'say',
#   'thank',
#   'read',
#   'almost',
#   'ad',
#   'science',
#   'diet',
#   'sure',
#   'think',
#   'eat',
#   'science',
#   'diet',
#   'optimal',
#   'care',
#   '  ',
#   'never',
#   'problem',
#   'last',
#   'bag',
#   'order',
#   'two',
#   'three',
#   'vomit',
#   'hair',
#   'ball',
#   'one',
#   'act',
#   'bit',
#   'lethargic',
#   'notice',
#   'last',
#   'couple',
#   'drink',
#   'unusual',
#   'amount',
#   'water',
#   'worry',
#   'planning',
#   'speak',
#   'vet',
#   'soon',
#   'oily',
#   'previous',
#   'bag',
#   'purchase',
#   'smell',
#   'different',
#   'read',
#   'previous',
#   'review',
#   'hill',
#   'change',
#   'formula',
#   '  ',
#   'never',
#   'problem',
#   '  ',
#   'sure',
#   'worried',
#   'hope',
#   'harm'],
#  ['vet',
#   'brand',
#   'think',
#   'eat',
#   'less',
#   'compare',
#   'brand',
#   'filler',
#   'way',
#   'healthy'],
#  ['contain',
#   'low',
#   'level',
#   'magnesium',
#   'supermarket',
#   'low',
#   'magnesium',
#   'level',
#   'help',
#   'prevent',
#   'urethra',
#   'problem',
#   'especially',
#   'male',
#   'due',
#   'narrow',
#   'urethra',
#   'rather',
#   'pay',
#   'high',
#   'price',
#   'brand',
#   'bring',
#   'emergency',
#   'vet',
#   'middle',
#   'night',
#   'urinary',
#   'tract',
#   'get',
#   'block',
#   'mention',
#   'aggravation',
#   'cause',
#   'brand',
#   'low',
#   'magnesium',
#   'include',
#   'iam',
#   'nutromax',
#   'hills',
#   'science',
#   'diet',
#   'roundshape',
#   'rather',
#   'hook',
#   'easy',
#   'one',
#   'toothchallenge',
#   'swallow'],
#  ['smell', 'kitty', 'upset', 'stomach', 'coat', 'beautiful'],
#  ['hills',
#   'science',
#   'diet',
#   'since',
#   'come',
#   'home',
#   'keep',
#   'healthy',
#   'vet',
#   'always',
#   'stuck',
#   'get',
#   'big',
#   'bag',
#   'easy',
#   'store',
#   'large',
#   'airtight',
#   'container',
#   'near',
#   'worry',
#   'buying',
#   'every',
#   'week',
#   'glad',
#   'see',
#   'amazon',
#   'prime',
#   'use',
#   'way',
#   'speciality',
#   'pet',
#   'store',
#   'get',
#   'place',
#   'petco',
#   'always',
#   'carry',
#   'iteditupdate',
#   'turn',
#   '  ',
#   'young',
#   'one',
#   '  ',
#   'later',
#   'still',
#   'healthy',
#   'active',
#   'overweight'],
#  ['deliver',
#   'house',
#   'save',
#   'trip',
#   'lift',
#   'package',
#   'car',
#   'item',
#   'deliver',
#   'garage'],
#  ['  ',
#   'catsage',
#   '  ',
#   'eat',
#   'anything',
#   'elseso',
#   'quess',
#   'might',
#   'waste',
#   'money',
#   'foodtrye',
#   'themi',
#   'feed',
#   'mine',
#   'since',
#   '  ',
#   'oldwhen',
#   'get'],
#  ['  ',
#   'eat',
#   '  ',
#   'veterinary',
#   'technician',
#   'know',
#   'pet',
#   'eat',
#   'high',
#   'quality',
#   'diet',
#   'decide',
#   'switch',
#   'brand',
#   'pet',
#   'hill',
#   'science',
#   'diet',
#   'please',
#   'gradually',
#   'abrupt',
#   'change',
#   'pet',
#   'diet',
#   'may',
#   'cause',
#   'vomiting',
#   'andor',
#   'diarrhea',
#   'change',
#   'take',
#   'place',
#   '  ',
#   'week',
#   'period',
#   'gradually',
#   'increase',
#   'new',
#   'diet',
#   'oh',
#   'forgot',
#   'cost',
#   '  ',
#   'pound',
#   'bag',
#   'select',
#   'subscribe',
#   'save',
#   'option',
#   'pay',
#   '  ',
#   'price',
#   'local',
#   'store',
#   'ask',
#   '  ',
#   'plus',
#   'tax',
#   'plus',
#   'gas',
#   'vehicle',
#   'need',
#   'know',
#   'talk',
#   'aboutplease',
#   'write',
#   'amazon',
#   'let',
#   'know',
#   'impact',
#   'wallet',
#   'start',
#   'tax',
#   'purchase',
#   'amazonwith',
#   'kindest',
#   'regardscheryl',
#   'l'],
#  ['gracie',
#   'overweight',
#   'use',
#   'foodshe',
#   'lose',
#   'weight',
#   'active',
#   'one',
#   'itlove',
#   'itlove'],
#  ['horrific',
#   'junk',
#   'ingredient',
#   'care',
#   'want',
#   'take',
#   'five',
#   'minute',
#   'research',
#   'feeding',
#   'guarantee',
#   'feed'],
#  ['three',
#   'four',
#   'become',
#   'disintereste',
#   'iam',
#   'dry',
#   'since',
#   'change',
#   'formula',
#   'ago',
#   'iam',
#   'serve',
#   'wellall',
#   'crazy',
#   'dry',
#   'science',
#   'diet',
#   'however',
#   'chicken',
#   'flavor',
#   'disintereste',
#   'wet',
#   'use'],
#  ['find', 'low', 'rating', 'feed', 'get', 'anywhere'],
#  ['know',
#   'different',
#   'dry',
#   'open',
#   'bag',
#   'bit',
#   'meaty',
#   'style',
#   'keep',
#   'vomit',
#   'bowel',
#   'movement',
#   'house',
#   'uncharacteristic',
#   'switch',
#   'another',
#   'kitnkaboodle',
#   'solve',
#   'problem',
#   'pin',
#   'issue',
#   'directly'],
#  ['wish',
#   'pay',
#   'shipping',
#   'cause',
#   'easy',
#   'buy',
#   'online',
#   'find',
#   'transportation',
#   'grocery',
#   'store'],
#  ['price',
#   'place',
#   'check',
#   'free',
#   'shipping',
#   'doorwhat',
#   'deal',
#   'pet',
#   'chain',
#   'store',
#   'retail',
#   'store',
#   'owner',
#   'since',
#   '  ',
#   'stay',
#   'educated',
#   'regard',
#   'brand',
#   'use',
#   'many',
#   'every',
#   'penny',
#   'count',
#   'site',
#   'userfriendly',
#   'order',
#   'arrive',
#   'timely',
#   'mannerweve',
#   'shopped',
#   'amazoncom',
#   'recall',
#   'ever',
#   'problem',
#   'come',
#   'back',
#   'often',
#   'price',
#   'service'],
#  ['consist', 'nutrient', 'lucy', 'lucy', 'also', 'want'],
#  ['help',
#   'fat',
#   'lose',
#   'weight',
#   'think',
#   'hate',
#   'eat',
#   'put',
#   'back',
#   'regular',
#   'hill',
#   'concentration',
#   'camp',
#   'kind',
#   'funny',
#   'smell',
#   'also',
#   'smart',
#   'fool',
#   'kibble',
#   'may',
#   'sure',
#   'taste'],
#  ['two', 'age', '   ', 'yes', '   ', 'siamese', 'picky', 'science', 'diet'],
#  ['hills',
#   'science',
#   'diet',
#   'expensive',
#   'worth',
#   'every',
#   'penny',
#   'use',
#   'iam',
#   'lately',
#   'vomit',
#   'decide',
#   'switch',
#   'glad',
#   'may',
#   'still',
#   'blue',
#   'buffalo',
#   'least',
#   'read',
#   'also'],
#  ['use',
#   'hill',
#   'science',
#   'diet',
#   'number',
#   'buy',
#   'anything',
#   'else',
#   'pet',
#   'recall',
#   'one',
#   'hill',
#   'numerous',
#   'recall',
#   'even',
#   'though',
#   'expensive',
#   'market',
#   'find',
#   'last',
#   'lot',
#   'long',
#   'digestable',
#   'foster',
#   'parent',
#   'number',
#   'start',
#   'hill',
#   'soon',
#   'start',
#   'wean',
#   'bottle',
#   'shed',
#   'less',
#   'sign',
#   'health',
#   'shiny',
#   'coat',
#   'stay',
#   'excellent',
#   'health'],
#  ['science',
#   'diet',
#   'perfect',
#   'baby',
#   'healthy',
#   'coat',
#   'also',
#   'healthy',
#   'shiny',
#   'come',
#   'shape'],
#  ['order',
#   'think',
#   'buy',
#   '  ',
#   'lb',
#   'bag',
#   'ity',
#   'price',
#   'pay',
#   'store',
#   'big',
#   'box',
#   'arrive',
#   'shock',
#   'see',
#   'get',
#   'large',
#   'bag',
#   'price',
#   '  ',
#   'big',
#   'bag',
#   'fit',
#   'storage',
#   'container',
#   'rascal',
#   'last',
#   '  ',
#   'pet',
#   'store',
#   'even',
#   'pay',
#   'shipping',
#   'continue',
#   'order'],
#  ['thrilled', 'back', 'purina', 'chow', 'young', 'one'],
#  ['also',
#   'share',
#   'evening',
#   'put',
#   'top',
#   'leftover',
#   'kibble',
#   'morning',
#   'healthy',
#   'virtually',
#   'never',
#   'give',
#   'human',
#   'vary',
#   'flavor',
#   'always',
#   'eat',
#   'fact',
#   'introduce',
#   'variety'],
#  ['use',
#   'light',
#   'dry',
#   'two',
#   'mix',
#   'together',
#   'lotthe',
#   'price',
#   'buy',
#   'locallyand',
#   'delivery',
#   'free',
#   'thank',
#   'prime',
#   'accounti',
#   'feed',
#   'science',
#   'diet'],
#  ['last',
#   'three',
#   'two',
#   'raise',
#   'science',
#   'diet',
#   '  ',
#   'despite',
#   'fact',
#   'poor',
#   'graduate',
#   'student',
#   'eat',
#   'raman',
#   'suck',
#   'november',
#   '  ',
#   'terrible',
#   'eye',
#   'reactioninfection',
#   'research',
#   'could',
#   'cause',
#   'issue',
#   'find',
#   'brand',
#   'overprice',
#   'version',
#   'crappy',
#   'stuff',
#   'buy',
#   'grocery',
#   'store',
#   'feel',
#   'betray',
#   'company',
#   'even',
#   'three',
#   'different',
#   'vet',
#   'animal',
#   'one',
#   'even',
#   'audacity',
#   'say',
#   'believe',
#   'avoid',
#   'grain',
#   'heavy',
#   'foodsi',
#   'think',
#   'trust',
#   'cornell',
#   'veterinary',
#   'school',
#   'website',
#   'rather',
#   'vet',
#   'podunk',
#   'alabama',
#   'obviously',
#   'get',
#   'kickback',
#   'sd',
#   'push',
#   'immediately',
#   'change',
#   'publixs',
#   'new',
#   'dry',
#   'grain',
#   'free',
#   'inexpensive',
#   'unlike',
#   'blue',
#   'buffalo',
#   'etc',
#   'fear',
#   'die',
#   'three',
#   'ago',
#   'kidney',
#   'failure',
#   'die',
#   'due',
#   'complication',
#   'please',
#   'give',
#   'fuzzy',
#   'child'],
#  ['quality',
#   'fault',
#   'choose',
#   'large',
#   'size',
#   'hard',
#   'pack',
#   'ship',
#   'could',
#   'pack'],
#  ['male',
#   'literally',
#   'stinkiest',
#   'poo',
#   'world',
#   'live',
#   'tiny',
#   'apartment',
#   'poope',
#   'want',
#   'vomit',
#   'every',
#   'bad',
#   'science',
#   'diet',
#   'wonder',
#   'poop',
#   'still',
#   'stink',
#   'help',
#   'ton',
#   'healthy',
#   'last',
#   'long',
#   'eat',
#   'less',
#   'fill',
#   'healthy',
#   'anyone'],
#  ['  ',
#   'different',
#   'background',
#   'age',
#   'quite',
#   'healthy',
#   'appreciate',
#   'ease',
#   'save',
#   'order',
#   'amazon',
#   'prime',
#   'feed',
#   'arrive',
#   'doorstep',
#   'two',
#   'please',
#   'add',
#   '  ',
#   'pound',
#   'size',
#   'optimal',
#   'care',
#   'original',
#   'subscribe',
#   'save',
#   'program'],
#  ['get',
#   'shelter',
#   'feed',
#   'wanda',
#   'never',
#   'waste',
#   'clean',
#   'box',
#   'cut',
#   'stool',
#   'odor',
#   '  ',
#   'dye',
#   'stain',
#   'either',
#   'keep',
#   'wanda',
#   'healthy'],
#  ['adope',
#   '  ',
#   'rescue',
#   'siamese',
#   '  ',
#   'receive',
#   'abandon',
#   'living',
#   'rescue',
#   'several',
#   'feed',
#   'pet',
#   'decide',
#   'continue',
#   'extremely',
#   'thin',
#   'could',
#   'see',
#   'rib',
#   'dull',
#   'coat',
#   'nearly',
#   '  ',
#   'coat',
#   'shiny',
#   'soft',
#   'put',
#   'weight',
#   'weigh',
#   '  ',
#   'pound',
#   'feed',
#   'portion',
#   'every',
#   'morning',
#   '  ',
#   'graze',
#   'enjoy',
#   'also',
#   'note',
#   'stool',
#   'less',
#   'smelly',
#   'compare',
#   'receive',
#   'overall',
#   'ingredient',
#   'list',
#   'compare',
#   'cheap',
#   'difference',
#   'ingredient',
#   'cheap',
#   'use',
#   'chicken',
#   'ingredient',
#   'vs',
#   'chicken',
#   'science',
#   'diet'],
#  ['high',
#   'quality',
#   'dry',
#   'lot',
#   'natural',
#   'oil',
#   'keep',
#   'shiny',
#   'healthy',
#   'fed',
#   'decade',
#   'live',
#   'age',
#   'trip',
#   'vet',
#   'live',
#   '  ',
#   'diet',
#   'along',
#   'fancy',
#   'feast',
#   'wetfood',
#   'highly'],
#  ['recieve',
#   'item',
#   'damage',
#   'beg',
#   'tear',
#   'spill',
#   'returnedit',
#   'one',
#   'happen'],
#  ['  ',
#   '  ',
#   'take',
#   'right',
#   'away',
#   '  ',
#   'take',
#   'bit',
#   '  ',
#   'eat',
#   'especially',
#   'fresh',
#   'bag',
#   'sure',
#   'tightly',
#   'close',
#   'bag',
#   'use',
#   'stay',
#   'fresh',
#   'put',
#   'eat',
#   'right',
#   'away',
#   'sit',
#   'eat',
#   'become',
#   'raven'],
#  ['kitty',
#   'urinary',
#   'issue',
#   'develop',
#   'unprinted',
#   'crystal',
#   'precursor',
#   'kidney',
#   'stone',
#   'vet',
#   'say',
#   'probably',
#   'feel',
#   'pee',
#   'shard',
#   'glass',
#   'certainly',
#   'let',
#   'know',
#   'nobody',
#   'course',
#   'glad',
#   'let',
#   'know',
#   'even',
#   'get',
#   'outhere',
#   'learn',
#   'balance',
#   'specific',
#   'vitaminsmineral',
#   'amount',
#   'whack',
#   'prone',
#   'urinary',
#   'problem',
#   'switch',
#   'spot',
#   'stew',
#   'natural',
#   'give',
#   'dude',
#   'major',
#   'problem',
#   'apparently',
#   'science',
#   'diet',
#   'one',
#   'company',
#   'study',
#   'develop',
#   'formula',
#   'urinary',
#   'issue',
#   'behold',
#   'issue',
#   'since',
#   'switch',
#   'get',
#   'amenthe',
#   'price',
#   'point',
#   'big',
#   'bag',
#   'also',
#   'excellent',
#   'comparison',
#   'shopping',
#   'store',
#   'everybody'],
#  ['far',
#   'mix',
#   'hill',
#   'science',
#   'dry',
#   'catshave',
#   'eat',
#   'gradually',
#   'increase',
#   'amount',
#   'hill',
#   'sciencethe',
#   'eat',
#   'assume'],
#  ['quality',
#   'price',
#   'package',
#   'appropriatly',
#   'bag',
#   'rip',
#   'enjoy',
#   'know',
#   'balanced',
#   'nutrition',
#   'compare',
#   'junk',
#   'grocery',
#   'store'],
#  ['always',
#   'find',
#   'science',
#   'diet',
#   'superior',
#   'pet',
#   'brand',
#   'feline',
#   'member',
#   'family',
#   'eat',
#   'optimal',
#   'health',
#   'kibble',
#   'particularly',
#   'take',
#   'long',
#   'eat',
#   'less',
#   'likely',
#   'vomit',
#   'eat',
#   'quickly'],
#  ['item',
#   'arrive',
#   'quickly',
#   'packaging',
#   'protect',
#   'item',
#   'arrive',
#   'directly',
#   'door',
#   'order',
#   'online'],
#  ['sell', 'fair', 'price', 'deliver', 'home', 'hassle'],
#  ['eat',
#   'science',
#   'diet',
#   'dry',
#   'many',
#   'flavor',
#   'continue',
#   'purchase',
#   'science',
#   'diet'],
#  ['get',
#   'one',
#   'bag',
#   'science',
#   'diet',
#   'adopt',
#   'shelter',
#   'buy',
#   'bag',
#   'keep',
#   'read',
#   'review',
#   'say',
#   'always',
#   'ravenous',
#   'get',
#   'fat',
#   'guy',
#   'gain',
#   'weight',
#   'stuff',
#   'recently',
#   'run',
#   'feed',
#   'royal',
#   'canin',
#   'mixed',
#   'contentedly',
#   'sit',
#   'next',
#   'past',
#   'normal',
#   'feeding',
#   'past',
#   'point',
#   'normally',
#   'start',
#   'nagging',
#   'hour',
#   '  ',
#   'handso',
#   'ill',
#   'join',
#   'chorus',
#   'say',
#   'stuff',
#   'leave',
#   'beg',
#   'question',
#   'value',
#   'start',
#   'notice',
#   'couple',
#   'run',
#   'proof',
#   'know',
#   'buy',
#   'stuff'],
#  ['use',
#   'since',
#   'stay',
#   'healthy',
#   'coat',
#   'silky',
#   'shiney',
#   'vet',
#   'although',
#   'bit',
#   'expensive',
#   'stay',
#   'healthy',
#   'buy',
#   'cheap',
#   'local',
#   'source',
#   'ship',
#   'charge',
#   'order',
#   'johnny'],
#  ['feed',
#   '  ',
#   'science',
#   'diet',
#   'wait',
#   'pop',
#   'subscribe',
#   'save',
#   'end',
#   'review'],
#  ['adopt',
#   'shelter',
#   'type',
#   'feed',
#   'urge',
#   'continue',
#   'feed',
#   'absolutely',
#   'change',
#   'brand',
#   'anytime',
#   'soon',
#   'high',
#   'quality',
#   'dry',
#   'definitely',
#   'one',
#   'big',
#   'bag',
#   'especially',
#   'large',
#   'rubbermaid',
#   'etc',
#   'container',
#   'store',
#   'get',
#   'stale',
#   'glad',
#   'shelter',
#   'vet',
#   'end',
#   'know',
#   'feed',
#   'appropriately',
#   'high',
#   'quality',
#   'help',
#   'stay',
#   'healthy'],
#  ['nutritious',
#   'cheap',
#   'brand',
#   'actually',
#   'eat',
#   'less',
#   'lose',
#   'weight',
#   'brand'],
#  ['call',
#   'kidney',
#   'stone',
#   'constantly',
#   'vet',
#   'problem',
#   'vet',
#   'say',
#   'put',
#   'science',
#   'diet',
#   'could',
#   'help',
#   'hate',
#   'quite',
#   'expensive',
#   'vet',
#   'right',
#   'problem',
#   'get',
#   'brand',
#   'end',
#   'pay',
#   'vet',
#   'bill',
#   'sick',
#   'stick',
#   'brand',
#   'know',
#   'fact',
#   'ship',
#   'door',
#   'plus',
#   '  ',
#   'cheap',
#   'buying',
#   'store',
#   'winnerj',
#   'kline'],
#  ['usually',
#   'gobble',
#   'soon',
#   'put',
#   'bowl',
#   'cheap',
#   'buying',
#   'store',
#   'plan',
#   'bag',
#   'deliver',
#   'every',
#   'two',
#   'whatever'],
#  ['store',
#   'far',
#   'away',
#   'stop',
#   'buy',
#   'item',
#   'amazon',
#   'buy',
#   'arrive',
#   'quickly',
#   'shop'],
#  ['say', 'vet', 'giving', 'still', 'eat'],
#  ['get',
#   'ridiculously',
#   'price',
#   'last',
#   '  ',
#   'bag',
#   'buy',
#   'september',
#   '  ',
#   'amazon',
#   '  ',
#   'increase',
#   '  ',
#   'nearly',
#   '  ',
#   'increase',
#   'problem',
#   'hills',
#   'science',
#   'diet',
#   'raise',
#   'price',
#   'amazon'],
#  ['despite',
#   'brand',
#   'incredibly',
#   'high',
#   'cost',
#   'assume',
#   'reputation',
#   'another',
#   'brand',
#   'list',
#   'dozen',
#   'storebudget',
#   'brand',
#   'recall',
#   'early',
#   '  ',
#   'bad',
#   'batch',
#   'wheat',
#   'gluten',
#   'kill',
#   'lot',
#   'pet',
#   'brand',
#   'abovepremium',
#   'price',
#   'plant',
#   'budget',
#   'brand',
#   'claim',
#   'superiority',
#   'ingredient',
#   'list',
#   'notwithstanding',
#   'incredibly',
#   'dubious'],
#  ['fed',
#   'deal',
#   'weight',
#   'issue',
#   'read',
#   'ingredient',
#   'high',
#   'grain',
#   'content',
#   'compare',
#   'meat',
#   'content',
#   'carnivorous',
#   'sure',
#   'protein',
#   'add',
#   'somewhere',
#   'strike',
#   'rather',
#   'atkin',
#   'diet',
#   'put',
#   'high',
#   'meat',
#   'diet',
#   'lose',
#   'weight'],
#  ['maybe',
#   'spoil',
#   'exp',
#   'date',
#   'fine',
#   'smell',
#   'bad',
#   'could',
#   'keep',
#   'house',
#   'never',
#   'problem',
#   'sensitive',
#   'sense',
#   'smell',
#   'eat',
#   'eat',
#   'brand',
#   'super',
#   'cheap',
#   'high',
#   'end',
#   'life',
#   'sneak',
#   'keep',
#   'get',
#   'eat',
#   'offer',
#   'test'],
#  ['  ',
#   'eat',
#   'hill',
#   'science',
#   'daily',
#   'thrive',
#   'suppliment',
#   'water',
#   'portion',
#   'wet',
#   'mostly',
#   'sure',
#   'drink',
#   'enough'],
#  ['come', 'expect'],
#  ['local',
#   'animal',
#   'shelter',
#   'upon',
#   'adoption',
#   '  ',
#   'eat',
#   'hungry',
#   'sometimes',
#   'supplement',
#   'treat',
#   'last'],
#  ['although',
#   'pet',
#   'mislead',
#   'hill',
#   'reduce',
#   'weight',
#   'bag',
#   '  ',
#   'pound'],
#  ['four',
#   'enjoy',
#   'turn',
#   'bowl',
#   'sit',
#   'right',
#   'next',
#   'bowl',
#   'know',
#   'satisfy'],
#  ['  ',
#   'male',
#   'range',
#   'age',
#   '   ',
#   'yes',
#   '  ',
#   'blind',
#   'partially',
#   'deaf',
#   'vet',
#   'say',
#   'physical',
#   'shape',
#   'believe',
#   'keep',
#   'urinary',
#   'tract',
#   'healthy',
#   'highly',
#   'optimal',
#   'health'],
#  ['two',
#   'science',
#   'diet',
#   'problem',
#   'wish',
#   'picture',
#   'outside',
#   'bag',
#   'dry',
#   'tan',
#   'triangle',
#   'shape',
#   'dark',
#   'brownround',
#   'shape',
#   'always',
#   'end',
#   'buy',
#   'wrong',
#   'bag',
#   'one'],
#  ['question',
#   'science',
#   'diet',
#   'productit',
#   'expensive',
#   'worth',
#   'extra',
#   'payprice',
#   'notice',
#   'inch',
#   'upwould'],
#  ['usually',
#   'eat',
#   'indoor',
#   'mixed',
#   'hairball',
#   'control',
#   'instead',
#   'indoor',
#   'cheap',
#   'pick',
#   'around',
#   'eat',
#   'end',
#   'purchase'],
#  ['eat', 'except', 'hill', 'diet', 'prefer', 'table', 'scrap', 'must'],
#  ['perfect'],
#  ['stomach', 'issue', 'fine', 'awesome'],
#  ['picky', 'gobble', 'hide', 'bag', 'get'],
#  ['four',
#   'order',
#   'amazon',
#   'subscribe',
#   'save',
#   'always',
#   'cheap',
#   'pet',
#   'store',
#   'vet',
#   'even',
#   'heavy',
#   'bag',
#   'arrive',
#   'front',
#   'door',
#   'box',
#   'drag',
#   '  ',
#   'pound',
#   'bag',
#   'car',
#   'super',
#   'saver',
#   'ship',
#   'free'],
#  ['free',
#   'bag',
#   'facebook',
#   'site',
#   '  ',
#   'kittys',
#   'leo',
#   'lucy',
#   '  ',
#   'always',
#   'feed',
#   'science',
#   'diet',
#   'switch',
#   'variety',
#   'thank',
#   'science',
#   'diet',
#   'leo',
#   'lucy',
#   'mommy'],
#  ['accord',
#   'many',
#   'consumer',
#   'complaint',
#   'hill',
#   'reformulate',
#   'science',
#   'diet',
#   'lot',
#   'sick',
#   'two',
#   'science',
#   'diet',
#   'original',
#   '  ',
#   'problem',
#   'week',
#   'open',
#   'bag',
#   'reformulate',
#   'stuff',
#   'end',
#   'two',
#   'sick',
#   'complain',
#   'vomit',
#   'stuff',
#   'stunk',
#   'house',
#   'kibble',
#   'soak',
#   'oil',
#   'consumer',
#   'complain',
#   'wildly',
#   'new',
#   'formulation',
#   'web',
#   'hill',
#   'could',
#   'care',
#   'less',
#   'fact',
#   'local',
#   'pet',
#   'supply',
#   'tell',
#   'hill',
#   'rep',
#   'put',
#   '  ',
#   'discount',
#   'sticker',
#   'bag',
#   'hill',
#   'science',
#   'diet',
#   'bad',
#   'news',
#   'bad',
#   'business'],
#  ['  ',
#   'sooooo',
#   'picky',
#   'buy',
#   'weight',
#   'vet',
#   'say',
#   'get',
#   'regular',
#   'supermarket',
#   'kibble',
#   'christmas',
#   'buy',
#   'huge',
#   'bag',
#   'amazon',
#   '   ',
#   'tuxedo',
#   'gag',
#   'type',
#   'reflex',
#   'swallow',
#   'digest',
#   'kibble',
#   'throw',
#   'amazing',
#   'cute',
#   'orange',
#   'strip',
#   'tabby',
#   'tiger',
#   'kitty',
#   'kibble',
#   '  ',
#   'catsi',
#   'believe',
#   'receive',
#   'huge',
#   'bag',
#   'kibble',
#   'middle',
#   'dec',
#   'half',
#   'way',
#   'mid',
#   'way',
#   'january',
#   'goour',
#   '  ',
#   'hill',
#   'science',
#   'diet',
#   'optimal',
#   'care',
#   'kibble'],
#  ['use',
#   'prescription',
#   'diet',
#   'finally',
#   'nerve',
#   'see',
#   'could',
#   'tolerate',
#   'finally',
#   'feed',
#   'without',
#   'vet',
#   'superexpensive',
#   'stay',
#   'healthy',
#   'eat',
#   'happily'],
#  ['find',
#   'two',
#   'young',
#   'female',
#   'wonder',
#   'around',
#   'neighborhood',
#   'eventually',
#   'catch',
#   'fur',
#   'rough',
#   'dirty',
#   'malnourishment',
#   'harsh',
#   'weather',
#   'bath',
#   'science',
#   'diet',
#   'healthy',
#   'fur',
#   'soft',
#   'tooth',
#   'healthy',
#   'also',
#   'leave',
#   'bowl',
#   'science',
#   'diet',
#   'two',
#   'feral',
#   'want',
#   'catch',
#   'take',
#   'two',
#   'new',
#   'kitty'],
#  ['foodthis',
#   'frist',
#   'bag',
#   'use',
#   'sciece',
#   'dite',
#   'adult',
#   'upset',
#   'tummy',
#   'anythingi',
#   'reccomend'],
#  ['digestion', 'round', 'crunchie', 'ship', 'thank'],
#  ['think',
#   'parent',
#   'please',
#   'research',
#   'buying',
#   'contain',
#   'nothing',
#   'meatbyproduct',
#   'grain',
#   'stuff',
#   'kill',
#   'long',
#   'run',
#   'still',
#   'feed',
#   'stop',
#   'immediately',
#   'google',
#   'ingredient',
#   'science',
#   'diet',
#   'see'],
#  ['picky',
#   'also',
#   'get',
#   'upset',
#   'stomach',
#   'variety',
#   'however',
#   'science',
#   'diet',
#   'adult',
#   'optimal',
#   'use',
#   'shelter',
#   'buy',
#   'big',
#   'bag',
#   'long',
#   'put',
#   'gallon',
#   'sized',
#   'tupperware',
#   'type',
#   'container',
#   'half',
#   'price',
#   'pet',
#   'store'],
#  ['give',
#   'high',
#   'cost',
#   'feed',
#   'another',
#   'brand',
#   'take',
#   'less',
#   '  ',
#   'week',
#   'see',
#   'difference',
#   'coat',
#   'weight',
#   'eat',
#   'way',
#   'less',
#   'brand',
#   'poop',
#   '  ',
#   'cause',
#   'demand',
#   'double',
#   'eat',
#   'less',
#   'science',
#   'diet',
#   'personal',
#   'kitty',
#   'rescue',
#   'ranch',
#   'help',
#   'anywhere',
#   'must',
#   'watch',
#   'every',
#   'penny',
#   'cut',
#   'corner',
#   'every',
#   'way',
#   'possible',
#   'find',
#   'ultimate',
#   'foodeven',
#   'smell',
#   'bad'],
#  ['feed',
#   'exclusively',
#   'last',
#   '  ',
#   'least',
#   'extremely',
#   'healthy',
#   'one',
#   'live',
#   'almost',
#   '  ',
#   'two',
#   'way',
#   'price',
#   'store',
#   'normally',
#   '  ',
#   'sometimes',
#   'low',
#   '  ',
#   'autoship',
#   'price',
#   '  ',
#   'one',
#   'save',
#   '  ',
#   'expect',
#   'long',
#   'life',
#   'people',
#   'maybe',
#   'average',
#   '  ',
#   'every',
#   'penny',
#   'count'],
#  ['purchase',
#   'new',
#   'chuck',
#   'keep',
#   'get',
#   'diarrhea',
#   'feed',
#   '  ',
#   'vet',
#   'suggest',
#   'hill',
#   'science',
#   'diet',
#   'vet',
#   'prescribed',
#   'depo',
#   'clear',
#   'diarrhea',
#   'system',
#   'get',
#   'back',
#   'normal',
#   'feed',
#   '  ',
#   'hill',
#   'science',
#   'diet',
#   'diarrhea'],
#  ['four',
#   'science',
#   'diet',
#   'eat',
#   'brand',
#   'dry',
#   'store',
#   'buy',
#   'touch',
#   'feed',
#   'homeless',
#   'neighborhood',
#   'care',
#   'science',
#   'diet',
#   'wet',
#   'though'],
#  ['feed',
#   'science',
#   'diet',
#   'original',
#   '  ',
#   'picky',
#   'eater',
#   'refuse',
#   'eat',
#   'anything',
#   'else',
#   'recently',
#   'notice',
#   'odd',
#   'behavior',
#   'diarrhea',
#   'vomit',
#   'odd',
#   'place',
#   'sink',
#   'table',
#   'start',
#   'miss',
#   'patch',
#   'fur',
#   'usually',
#   'sign',
#   'distress',
#   'drink',
#   'lot',
#   'water',
#   'even',
#   'toilet',
#   'act',
#   'starve',
#   'even',
#   'though',
#   'eat',
#   'also',
#   'start',
#   'notice',
#   'strange',
#   'smell',
#   'every',
#   'feed',
#   'know',
#   'come',
#   'yesterday',
#   'catch',
#   'picky',
#   'eater',
#   'eat',
#   'decide',
#   'inspect',
#   'notice',
#   'bottom',
#   'bag',
#   'cover',
#   'mold',
#   'fairly',
#   'new',
#   'bag',
#   'week',
#   'start',
#   'review',
#   'online',
#   'noticed',
#   'people',
#   'complain',
#   'new',
#   'improved',
#   'formula',
#   'sort',
#   'plastic',
#   'preservative',
#   'increase',
#   'shelflife',
#   'animal',
#   'extremely',
#   'sick',
#   'even',
#   'result',
#   'death',
#   'upset',
#   'glad',
#   'find',
#   'late',
#   'change',
#   'brand',
#   'hopefully',
#   'get',
#   'picky',
#   'eater',
#   'agree',
#   'new'],
#  ['eat', '  ', 'yearsthey', 'get', 'tired', 'flavor'],
#  ['save',
#   'money',
#   'purchase',
#   'compare',
#   'pet',
#   'specialty',
#   'store',
#   'save',
#   'trip',
#   'way',
#   'location'],
#  ['give', 'purchase', 'pet', 'vet', 'say', 'healthy', 'fit', 'dry', 'eat'],
#  ['different',
#   'dry',
#   'high',
#   'end',
#   'national',
#   'brand',
#   'store',
#   'brand',
#   'agree',
#   'find',
#   'flavor',
#   'bit',
#   'right',
#   'size',
#   'texture',
#   'big',
#   'texture',
#   'slightly',
#   'moist',
#   'oily',
#   'even',
#   'smell',
#   'appeal',
#   'himthe',
#   'nutrition',
#   'value',
#   'balance',
#   'complete',
#   'indooroutdoor',
#   'yearround',
#   'healthy',
#   'coat',
#   'healthy',
#   'tooth',
#   'healthy',
#   'weight',
#   'never',
#   'hairball',
#   'always',
#   'lively',
#   'active',
#   'poop',
#   'always',
#   'healthy',
#   'toooverall',
#   'complete',
#   'balanced',
#   'nutrition',
#   'reasonable',
#   'price',
#   'mixed',
#   'beef',
#   'science',
#   'diet',
#   'wet',
#   'favorite'],
#  ['pretty',
#   'although',
#   'order',
#   'regular',
#   'senior',
#   'light',
#   'show',
#   'available',
#   'wish',
#   'know',
#   'order',
#   'senior'],
#  ['eat', 'also', 'healthyit', 'also', 'buy'],
#  ['enjoy',
#   'believe',
#   'fur',
#   'soft',
#   'sometimes',
#   'put',
#   'bit',
#   'water',
#   'bowl'],
#  ['three', 'feel', 'previous', 'purina'],
#  ['feed',
#   '  ',
#   'taste',
#   'get',
#   'obese',
#   'dawn',
#   'could',
#   'premium',
#   'cause',
#   'fat',
#   'chart',
#   'compare',
#   'ingredient',
#   'dry',
#   'science',
#   'diet',
#   'nearly',
#   'double',
#   'fat',
#   'brand',
#   'know',
#   'carbs',
#   'concern',
#   'pick',
#   'diet',
#   'carnivore',
#   'switch',
#   '  ',
#   'mos',
#   'agoto',
#   'iams',
#   'meat',
#   'primary',
#   'ingredient',
#   'less',
#   'half',
#   'fat',
#   'another',
#   'note',
#   'light',
#   'formulation',
#   'include',
#   'hill',
#   'replace',
#   'fat',
#   'grain',
#   'simply',
#   'acceptable',
#   'lead',
#   'obesity',
#   'surelythe',
#   'jury',
#   'still',
#   'battle',
#   'bulge',
#   'appear',
#   'bit',
#   'svelte',
#   'short'],
#  ['eat', 'anything', 'else', 'yak', 'keep', 'long', 'store', 'reasonably'],
#  ['brand', 'ingredient', 'one', 'particular', 'still', 'bad', 'deal'],
#  ['adopt',
#   'take',
#   'house',
#   'winter',
#   'painfully',
#   'thin',
#   'coat',
#   'thin',
#   'dull',
#   'hill',
#   'science',
#   'diet',
#   'vet',
#   'get',
#   'set',
#   'auto',
#   'ship',
#   'amazon'],
#  ['fussy',
#   'ever',
#   'share',
#   'home',
#   'eat',
#   'human',
#   'treat',
#   'stop',
#   'eat',
#   'change',
#   'variety',
#   'even',
#   'protest',
#   'get',
#   'new',
#   'bag',
#   'mix',
#   'gradually',
#   'main',
#   'supply',
#   'problem',
#   'get',
#   'brand',
#   'locally',
#   'near',
#   'price',
#   'get',
#   'prime',
#   'long',
#   'change',
#   'formula',
#   'ill',
#   'buy'],
#  ['dry',
#   'friskie',
#   'indoor',
#   'delight',
#   'seafood',
#   'flavor',
#   'kind',
#   'regular',
#   'kind'],
#  ['store', 'cheap', 'free', '  ', 'prime', 'beat'],
#  ['fun',
#   'become',
#   'soft',
#   'sleek',
#   'also',
#   'get',
#   'spare',
#   'hair',
#   'almost',
#   'bald',
#   'place',
#   'turn',
#   'diet',
#   'fix',
#   'problem'],
#  ['feline',
#   'want',
#   'healthy',
#   'buy',
#   'quality',
#   'buy',
#   'vet',
#   'buy',
#   'online'],
#  ['feed',
#   'past',
#   'six',
#   'two',
#   'big',
#   'bag',
#   'last',
#   'forever',
#   'always',
#   'available',
#   'ration',
#   'eat',
#   'expensive',
#   'upfront',
#   'cheap',
#   'probably',
#   'buy',
#   'two',
#   'three',
#   'cheap',
#   'long',
#   'run',
#   'beautiful',
#   'coat',
#   'healty',
#   'poop',
#   'either',
#   'box',
#   'also'],
#  ['happily',
#   'scarf',
#   'smell',
#   'ever',
#   'behavior',
#   'get',
#   'less',
#   'lethargic',
#   'morsel',
#   'perfect',
#   'develop',
#   'tooth',
#   'definitely',
#   'continue',
#   'buy',
#   'hill',
#   'science',
#   'diet',
#   'pet',
#   'needsprosmade',
#   'without',
#   'junkhappy',
#   'kittieshappy',
#   'ownersall',
#   'stuff',
#   'needconsa',
#   'tad',
#   'pricey',
#   'sooooo',
#   'worth'],
#  ['particularly',
#   'fond',
#   'health',
#   'issue',
#   'however',
#   'reception',
#   'shaky',
#   'plan',
#   'around',
#   'expect',
#   'need',
#   'sometimes',
#   'come',
#   'late',
#   'cause',
#   'monthy',
#   'change',
#   'diet'],
#  ['favorite',
#   'price',
#   'top',
#   'box',
#   'store',
#   'get',
#   'deliver',
#   'front',
#   'door'],
#  ['get', 'fancy', 'pet', 'store', 'except', 'spend', 'less', 'come', 'door'],
#  ['get',
#   'slightly',
#   'overweight',
#   'yr',
#   'borderingon',
#   'overweight',
#   'mo',
#   'weight',
#   'control',
#   'one',
#   'next',
#   'yo',
#   'tooth',
#   'throw',
#   'kibble',
#   'problem',
#   'though'],
#  ['kitty', 'lose', 'half', 'tooth', 'insist', 'chomp', 'away', 'formula'],
#  ['finicky', 'use', 'several', 'continue'],
#  ['amazoncom',
#   'sale',
#   'stuff',
#   'feed',
#   'pet',
#   'far',
#   'get',
#   'sick',
#   'appear',
#   'true',
#   'stuff',
#   'fake',
#   'replacement',
#   'online',
#   'sale',
#   'buy',
#   'one',
#   'separately',
#   'get',
#   '  ',
#   'buy',
#   'two',
#   'one',
#   'sale',
#   '  ',
#   'show',
#   'one',
#   'keep',
#   'mind',
#   'item',
#   'amazoncom'],
#  ['attest',
#   'long',
#   'term',
#   'affect',
#   'ie',
#   'whether',
#   'fat',
#   'know',
#   'natural',
#   'diet',
#   'consist',
#   'grain',
#   'main',
#   'ingredient',
#   'dry',
#   'imagine',
#   'eat',
#   'chip',
#   'also',
#   'feed',
#   'meaty',
#   'guess',
#   'point',
#   'avoid',
#   'pet',
#   'obesity',
#   'pet',
#   'balance',
#   'diet',
#   'rest',
#   'hold',
#   'manufacturer',
#   'dry',
#   'responsible',
#   'fact',
#   'otherwise',
#   'blame',
#   'mcdonald',
#   'fat',
#   'thinkanyway',
#   'know',
#   'dry',
#   'actually',
#   'rather',
#   'meaty',
#   'wet',
#   'know',
#   'switch',
#   'hill',
#   'science',
#   'diet',
#   'quit',
#   'finish',
#   'wet',
#   'set',
#   'fact',
#   'probably',
#   'pay',
#   'attention',
#   'suggest',
#   'serve',
#   'size',
#   'print',
#   'bag',
#   'oppose',
#   'keep',
#   'dish',
#   'full',
#   'everything',
#   'moderation',
#   'rightthe',
#   'reason',
#   'give',
#   '  ',
#   'start',
#   'instead',
#   '  ',
#   'abnormally',
#   'high',
#   'price',
#   'willing',
#   'pay',
#   'extra',
#   'kitty',
#   'mean',
#   'itso',
#   'highly',
#   'remember',
#   'use',
#   'part',
#   'balanced',
#   'diet'],
#  ['taste',
#   'fur',
#   'also',
#   'possible',
#   'poop',
#   'strong',
#   'smelling',
#   'though',
#   'use',
#   'one',
#   'noticeable',
#   'difference'],
#  ['buy',
#   'amazon',
#   'cheap',
#   'local',
#   'big',
#   'box',
#   'pet',
#   'store',
#   'rhyme',
#   'letgo',
#   'also',
#   'show',
#   'doorstep',
#   'click',
#   'debit',
#   'bank',
#   'account',
#   'even',
#   'bad'],
#  ['worried', 'suppose', 'want', 'eat', 'highly'],
#  ['nine', 'crazy', 'kibble', 'last', 'want', 'lbs', 'hate', 'ill', 'buying'],
#  ['past',
#   'offer',
#   'special',
#   'diet',
#   'fail',
#   'kidney',
#   'touch',
#   'single',
#   'one',
#   'extremely',
#   'thin',
#   'worth',
#   'starve',
#   'force',
#   'eat',
#   'repugnant',
#   'prescription',
#   'three',
#   'short',
#   'separate',
#   'hard',
#   'anywaythis',
#   'market',
#   'crf',
#   'ckf',
#   'lot',
#   'reading',
#   'one',
#   'low',
#   'phosphorus',
#   'commercial',
#   'diet',
#   'info',
#   'obtain',
#   'poor',
#   'boy',
#   'cranky',
#   'picky',
#   'though',
#   'overtly',
#   'suffer',
#   'probably',
#   'feel',
#   'use',
#   'appetite',
#   'lessen',
#   'open',
#   'every',
#   'pique',
#   'interest',
#   'eat',
#   'til',
#   'hit',
#   'something',
#   'darnnear',
#   'cry',
#   'immediately',
#   'dig',
#   'soon',
#   'set',
#   'plate',
#   'afriad',
#   'fluke',
#   'til',
#   'eat',
#   'wonderfulby',
#   'mean',
#   'check',
#   'vet',
#   'mine',
#   'believer',
#   'keep',
#   'kidneycat',
#   'eat',
#   'many',
#   'thyroid',
#   'issue',
#   'mine',
#   'skinnyim',
#   'vet',
#   'smell',
#   'consistency',
#   'guy',
#   'need',
#   'eat',
#   'thank',
#   'heaven'],
#  ['thsi'],
#  ['upon',
#   'cartoon',
#   'post',
#   'refrigerator',
#   'depict',
#   'owner',
#   'stand',
#   'feline',
#   'hand',
#   'pet',
#   'stare',
#   'skeptically',
#   'dish',
#   'caption',
#   'read',
#   'word',
#   'search',
#   'thank',
#   'youi',
#   'know',
#   'happen',
#   'cartoon',
#   'perhaps',
#   'fall',
#   'floor',
#   'one',
#   'eat',
#   'later',
#   'cough',
#   'part',
#   'hairballwe',
#   'three',
#   'wretched',
#   'creature',
#   'amanda',
#   'sissy',
#   'rag',
#   'finicky',
#   'eater',
#   'moreover',
#   'individual',
#   'preference',
#   'sync',
#   'fair',
#   'amount',
#   'leave',
#   'wet',
#   'ie',
#   'garbage',
#   'disposal',
#   'dry',
#   'generally',
#   'less',
#   'problematic',
#   'standpoint',
#   'acceptance',
#   'another',
#   'story',
#   'another',
#   'amanda',
#   'fill',
#   'empty',
#   'stomach',
#   'dry',
#   'often',
#   'throw',
#   'last',
#   'week',
#   'window',
#   'sill',
#   'groove',
#   'open',
#   'vertically',
#   'slide',
#   'window',
#   'come',
#   'rest',
#   'closedto',
#   'date',
#   'luck',
#   'overstatement',
#   'brand',
#   'provide',
#   'opportunity',
#   'fancy',
#   'feast',
#   'even',
#   'variety',
#   'instance',
#   'generally',
#   'flake',
#   'mince',
#   'slice',
#   'may',
#   'classic',
#   'grill',
#   'chunky',
#   'crapshootrecently',
#   'purchase',
#   'couple',
#   'max',
#   'pet',
#   'specialty',
#   'store',
#   'surprisingly',
#   'three',
#   'beggar',
#   'chowe',
#   'glaze',
#   'dishsince',
#   'various',
#   'flavor',
#   'permutation',
#   'adult',
#   'recipe',
#   'lamb',
#   'turkey',
#   'chicken',
#   'liver',
#   'seafood',
#   'venison',
#   'duck',
#   'salmon',
#   'even',
#   'one',
#   'recipe',
#   'fall',
#   'basket',
#   'mistake',
#   'chicken',
#   'oceanfish',
#   'formula',
#   'consume',
#   'enthusiasm',
#   'stand',
#   'amazed',
#   'new',
#   'paradigm',
#   'momentlooke',
#   'label',
#   'three',
#   'random',
#   'flavor',
#   'salmon',
#   'savory',
#   'duck',
#   'turkey',
#   'chicken',
#   'liver',
#   'ingredient',
#   'common',
#   'presumably',
#   'variety',
#   'chicken',
#   'potato',
#   'starch',
#   'wheat',
#   'gluten',
#   'pork',
#   'plasma',
#   'natural',
#   'flavor',
#   'salt',
#   'guar',
#   'gum',
#   'sodium',
#   'phosphate',
#   'calcium',
#   'carbonate',
#   'potassium',
#   'chloride',
#   'dlmethionine',
#   'taurine',
#   'xanthine',
#   'gum',
#   'ferrous',
#   'sulfate',
#   'vitamin',
#   'e',
#   'supplement',
#   'choline',
#   'chloride',
#   'zinc',
#   'oxide',
#   'thiamine',
#   'mononitrate',
#   'vitamin',
#   'b',
#   'copper',
#   'proteinate',
#   'manganous',
#   'sulfate',
#   'niacin',
#   'dcalcium',
#   'pantothenate',
#   'vitamin',
#   'supplement',
#   'vitamin',
#   'supplement',
#   'pyridoxine',
#   'hydrochloride',
#   'riboflavin',
#   'supplement',
#   'potassium',
#   'iodide',
#   'vitamin',
#   'b',
#   'supplement',
#   'sodium',
#   'selenite',
#   'folic',
#   'acid',
#   'biotin',
#   'one',
#   'cracker',
#   'course',
#   'individual',
#   'flavor',
#   'also',
#   'contain',
#   'ingredient',
#   'define',
#   'duck',
#   'savory',
#   'duckthe',
#   'label',
#   'states',
#   'formulate',
#   'meet',
#   'nutritional',
#   'level',
#   'establish',
#   'aafco',
#   'nutrient',
#   'profile',
#   'case',
#   'know',
#   'aafco',
#   'association',
#   'american',
#   'feed',
#   'control',
#   'official',
#   'accord',
#   'websitealthough',
#   'aafco',
#   'regulatory',
#   'authority',
#   'association',
#   'provide',
#   'forum',
#   'membership',
#   'industry',
#   'representation',
#   'achieve',
#   'three',
#   'main',
#   'goal',
#   'ensure',
#   'consumer',
#   'protection',
#   'safeguard',
#   'health',
#   'animal',
#   'human',
#   'provide',
#   'level',
#   'play',
#   'field',
#   'orderly',
#   'commerce',
#   'animal',
#   'feed',
#   'industrythese',
#   'goal',
#   'achieve',
#   'develop',
#   'implement',
#   'uniform',
#   'equitable',
#   'law',
#   'regulation',
#   'standard',
#   'definition',
#   'enforcement',
#   'policy',
#   'regulate',
#   'manufacture',
#   'distribution',
#   'sale',
#   'animal',
#   'feed',
#   'result',
#   'safe',
#   'effective',
#   'useful',
#   'feed',
#   'promote',
#   'uniformity',
#   'amongst',
#   'member',
#   'agenciesin',
#   'word',
#   'pet',
#   'policean',
#   'mou',
#   'memorandum',
#   'understanding',
#   'exist',
#   'aafco',
#   'drug',
#   'administration',
#   'guess',
#   'warm',
#   'fuzzy',
#   'exchange',
#   'card',
#   'christmas',
#   'enoughwhy',
#   'aafco',
#   'even',
#   'annual',
#   'meeting',
#   'ill',
#   'bet',
#   'debauchmax',
#   'manufacture',
#   'nutro',
#   'products',
#   'inc',
#   'franklin',
#   'tn',
#   'wonder',
#   'squirrel',
#   'flavor',
#   'consumption',
#   'kitty',
#   'live',
#   'back',
#   'woodswe',
#   'naive',
#   'believe',
#   'one',
#   'unholy',
#   'trio',
#   'ultimately',
#   'max',
#   'max',
#   'could',
#   'happen',
#   'soon',
#   'evening',
#   'meantime',
#   'force',
#   'back',
#   'square',
#   'one',
#   'gratitude',
#   'due',
#   'nutro',
#   'max'],
#  ['extremely',
#   'pickymy',
#   'especially',
#   'sauve',
#   'chunk',
#   'lamb',
#   'also',
#   'blue',
#   'lamb',
#   'dry'],
#  ['fur',
#   'baby',
#   'max',
#   'savory',
#   'duck',
#   'chunk',
#   'sauce',
#   'duck',
#   'meat',
#   'areusually',
#   'offer',
#   'eat',
#   'feed',
#   'baby',
#   'dry',
#   'unless',
#   'away',
#   'entire'],
#  ['search', 'healthy', 'actually', 'eat', 'buy'],
#  ['max',
#   'nutro',
#   'chunk',
#   'sauce',
#   'usually',
#   'eat',
#   'instead',
#   'lick',
#   'gravy',
#   'leave',
#   'rest',
#   'also',
#   'help',
#   'cavity',
#   'gain',
#   'need',
#   'weight',
#   'help',
#   'thyroid',
#   'condition',
#   'fully'],
#  ['one',
#   'soso',
#   'clean',
#   'dish',
#   'tomato',
#   'bisque',
#   'flavor',
#   'smell',
#   'soooo',
#   'bad',
#   'unreal',
#   'buy',
#   'flavor',
#   'stick',
#   'brand'],
#  ['allergic', 'main', 'store', 'brand', 'brand', 'quality', 'boy'],
#  ['precise',
#   'put',
#   'amazing',
#   'pet',
#   'light',
#   'formula',
#   'still',
#   'plenty',
#   'meat',
#   'less',
#   'calorie',
#   'fat',
#   'chubby',
#   'pet',
#   'course',
#   'light',
#   'formula',
#   'tasty',
#   'issue',
#   'taste',
#   'mix',
#   'holistic',
#   'complete',
#   'grain',
#   'free',
#   'turkey',
#   'chicken'],
#  ['excellent',
#   'feed',
#   '  ',
#   'grainfree',
#   'discover',
#   'urinary',
#   'infection',
#   'one',
#   'actually',
#   'allergy',
#   'gluten',
#   'grain',
#   'major',
#   'source',
#   'protein',
#   'pet',
#   'cheap',
#   'long',
#   'shelf',
#   'life',
#   'vet',
#   'sell',
#   'expensive',
#   'prescription',
#   'ingredient',
#   'three',
#   'cost',
#   'number',
#   'choice',
#   'grainfree',
#   'enjoy',
#   'variety',
#   'though',
#   'consistency',
#   'always',
#   'introduce',
#   'new',
#   'mixed',
#   'slowly',
#   'familiar',
#   'one',
#   'chief',
#   'advantage',
#   'one',
#   'shape',
#   'piece',
#   'star',
#   'shape',
#   'cause',
#   'eat',
#   'slowly',
#   'disc',
#   'shape',
#   'many',
#   'disc',
#   'often',
#   'swallow',
#   'whole',
#   'regurgitate',
#   'get',
#   'nourishment',
#   'get',
#   'mess',
#   'say',
#   'one',
#   'brand',
#   'digest',
#   'tolerate',
#   'pardon',
#   'say',
#   'super',
#   'concentrated',
#   'high',
#   'protein',
#   'cause',
#   'amazingly',
#   'bad',
#   'smell',
#   'pan',
#   'one',
#   'actually',
#   'help',
#   'gluten',
#   'allergic',
#   'firm',
#   'stool',
#   'consistency',
#   'leave',
#   'eye',
#   'water',
#   'odor',
#   'finally',
#   'importantly',
#   'eat',
#   'often',
#   'even',
#   'give',
#   'alongside',
#   'buy',
#   'precise',
#   'chicken',
#   'formula',
#   'long'],
#  ['feeding',
#   'sporkie',
#   'since',
#   '  ',
#   'never',
#   'sick',
#   'add',
#   'senior',
#   'variety',
#   'diet',
#   'precise',
#   'mix',
#   'one',
#   'however',
#   'change',
#   'twice',
#   'last',
#   '  ',
#   '  ',
#   'ago',
#   'switch',
#   'max',
#   'become',
#   'angry',
#   'aggressive',
#   'switch',
#   'back',
#   'fine',
#   'ago',
#   'add',
#   'natural',
#   'herbal',
#   'variety',
#   'precise',
#   'get',
#   'sick',
#   'get',
#   'uti',
#   'however',
#   'life',
#   'antibiotic',
#   'swear',
#   'precise',
#   'pain',
#   'ship',
#   'buy',
#   'locally',
#   'long',
#   'worth',
#   'sporkie'],
#  ['high',
#   'quality',
#   'bag',
#   'anticipated',
#   'fault',
#   'close',
#   'weight',
#   'picture'],
#  ['girl',
#   'picky',
#   'eater',
#   'usually',
#   'disregard',
#   'dry',
#   'soon',
#   'serve',
#   'bowl',
#   'precise',
#   'dove',
#   'often',
#   'eat',
#   'instead',
#   'wet'],
#  ['always',
#   'lookout',
#   'highquality',
#   'actually',
#   'eat',
#   'find',
#   'past',
#   'always',
#   'budget',
#   'stay',
#   'near',
#   '  ',
#   'perfect',
#   'expensive',
#   'quality',
#   'eat',
#   'one',
#   'sit',
#   'instead',
#   'come',
#   'back',
#   'nibble',
#   'every',
#   'health',
#   'extension',
#   'brand',
#   'raise',
#   'budget',
#   'glad',
#   'find',
#   'thisthis',
#   'patestyle',
#   'smell',
#   'strong',
#   'put',
#   'nose',
#   'fairly',
#   'close',
#   'smell',
#   'juicy',
#   'highly'],
#  ['price',
#   'ridiculous',
#   'want',
#   '   ',
#   'oz',
#   'pacage',
#   'petco',
#   'sale',
#   '  ',
#   'wagcom',
#   'buy',
#   'petco',
#   'right',
#   'flavor'],
#  ['want', 'quick', 'painless', 'transaction', 'place', 'purchase', 'wysong'],
#  ['complaint',
#   'order',
#   'arrive',
#   'expiration',
#   'date',
#   'one',
#   'ahead',
#   'eat',
#   '  ',
#   'six',
#   'pound',
#   'bag',
#   'return',
#   'whole',
#   'lot'],
#  ['yr',
#   'bore',
#   'vetsupplied',
#   'kd',
#   'since',
#   'crf',
#   'careful',
#   'eat',
#   'interested',
#   'eat',
#   'mix',
#   '  ',
#   'wit',
#   'rx',
#   'kd',
#   'stop',
#   'lose',
#   'weight',
#   'apparently',
#   'taste'],
#  ['high',
#   'quality',
#   'additive',
#   'always',
#   'wysong',
#   'senior',
#   '  ',
#   'kitty',
#   'stop',
#   'vomit',
#   'eat',
#   'keep',
#   'also',
#   'give',
#   '  ',
#   'boy',
#   'highly'],
#  ['  ',
#   'serious',
#   'digestion',
#   'problem',
#   'include',
#   'regular',
#   'vomiting',
#   'diarrhea',
#   'point',
#   'dehydrate',
#   'underweight',
#   'run',
#   'untill',
#   'hear',
#   'wysong',
#   'geriatrx',
#   'decide',
#   'say',
#   'quite',
#   'literally',
#   'save',
#   'life'],
#  ['many',
#   'week',
#   'realize',
#   'container',
#   'wysong',
#   'geriatrix',
#   'empty',
#   'anymore',
#   'use',
#   'one',
#   'treat',
#   'formula',
#   'change',
#   'say',
#   'new',
#   'label'],
#  ['quality',
#   'dry',
#   'main',
#   'staple',
#   'enjoy',
#   'share',
#   'fancy',
#   'feast',
#   'peaceful',
#   'life',
#   'interesting',
#   'give',
#   'extra',
#   'motivation',
#   'wake',
#   'morninggourmet',
#   'seafood',
#   'feast',
#   'favorite',
#   'flavor',
#   'rank',
#   'high',
#   'fancy',
#   'feast',
#   'gourmet',
#   'chicken',
#   'feast',
#   'ocean',
#   'whitefish',
#   'tuna',
#   'feastthe',
#   'flip',
#   'top',
#   'easy',
#   'sleepy',
#   'mom',
#   'serve',
#   'breakfast',
#   'smell',
#   'though',
#   'fishy',
#   'bad',
#   'perhaps',
#   'might',
#   'sour',
#   'cream',
#   'cracker',
#   'run',
#   'short',
#   'canapeacute',
#   'next',
#   'cocktail',
#   'partythe',
#   'state',
#   'main',
#   'ingredient',
#   'ocean',
#   'fish',
#   'liver',
#   'meat',
#   'byproduct',
#   'fish',
#   'broth',
#   'many',
#   'ingredient',
#   'course',
#   'vitamin',
#   'supplement',
#   'also',
#   'state',
#   'fancy',
#   'feast',
#   'seafood',
#   'feast',
#   'quotprovide',
#   'complete',
#   'balanced',
#   'nutrition',
#   'growth',
#   'maintenance',
#   'catsquot',
#   '  ',
#   'per',
#   '   ',
#   'lbs',
#   'body',
#   'weight',
#   'remind',
#   'quotrefrigerate',
#   'unused',
#   'portionquotwhether',
#   'serve',
#   'crystal',
#   'plain',
#   'white',
#   'ceramic',
#   'bowl',
#   'buddy',
#   'liddy',
#   'mushka',
#   'get',
#   'fancy',
#   'feast',
#   'thank',
#   'satisfied',
#   'purr'],
#  ['wonderful',
#   'wonderful',
#   'price',
#   'feel',
#   'buy',
#   'future',
#   'hope',
#   'company',
#   'never',
#   'stop',
#   'wonderful'],
#  ['recently',
#   'give',
#   'poor',
#   'review',
#   'elderly',
#   'appear',
#   'reaction',
#   'pain',
#   'eat',
#   'one',
#   'refuse',
#   'eat',
#   'thereafter',
#   'consider',
#   'possibility',
#   'may',
#   'sliver',
#   'bone',
#   'contamination',
#   'state',
#   'review',
#   'two',
#   'previously',
#   'turns',
#   'allergy',
#   'know',
#   'sure',
#   'mouth',
# ...
#   'order',
#   'item',
#   'amazon',
#   'subscribe',
#   'save',
#   'feature',
#   'trouble',
#   'every',
#   'item',
#   'suppose',
#   'come',
#   'never',
#   'track',
#   'say',
#   'ship',
#   'detail',
#   'say',
#   'return',
#   'sender',
#   'item',
#   'cancel',
#   'return',
#   'cancel',
#   'subscription',
#   'also',
#   'money',
#   'cost',
#   'figure',
#   'outamazon',
#   'always',
#   'get',
#   'catch',
#   'thisa',
#   'producti',
#   'green',
#   'world',
#   'wide',
#   'benefit',
#   'limit',
#   'ingredient',
#   'furry',
#   'one',
#   'taste',
#   'give',
#   'proper',
#   'amount',
#   'significantly',
#   'less',
#   'kind',
#   'poorly',
#   'dose',
#   'kitty',
#   'gain',
#   'ton',
#   'weight',
#   'give',
#   'vocal',
#   'pet',
#   'oily',
#   'smell',
#   'salmon',
#   'sure',
#   'check',
#   'package',
#   'daily',
#   'allowance'],
#  ['healthy',
#   'brand',
#   'find',
#   'grocery',
#   'store',
#   'use',
#   'subscribe',
#   'save',
#   'bit',
#   'less',
#   'expensive',
#   'local',
#   'grocery',
#   'store',
#   'deliver',
#   'never',
#   'run',
#   'far',
#   'always',
#   'deliver',
#   'condition',
#   'fresh'],
#  ['adopt',
#   '  ',
#   'ago',
#   'local',
#   'humane',
#   'clinic',
#   'tell',
#   'eat',
#   'specific',
#   'brand',
#   'purchase',
#   '  ',
#   'lb',
#   'bag',
#   'weigh',
#   '  ',
#   'pound',
#   'adopt',
#   '  ',
#   'dish',
#   'nibble',
#   'local',
#   'humane',
#   'center',
#   'furnished',
#   'center',
#   'concern',
#   'two',
#   'flavor',
#   'dry',
#   'without',
#   'success',
#   'frustration',
#   'purchase',
#   'purina',
#   'one',
#   'beyoud',
#   'chicken',
#   'oatmeal',
#   'put',
#   'handful',
#   'nugget',
#   'eated',
#   'come',
#   'meow',
#   'want',
#   'finallyi',
#   'find',
#   'eat',
#   'apparently',
#   'preference',
#   'thank',
#   'goodness',
#   'finally',
#   'find',
#   'enjoy',
#   'eat',
#   'maybe',
#   'put',
#   'couple',
#   'pound',
#   'almost',
#   'anorexic',
#   'anyone',
#   'picky',
#   'dry',
#   'purchase',
#   '  ',
#   'lb',
#   'bag',
#   'know',
#   'favorite',
#   'picky',
#   'whole',
#   'heartedly'],
#  ['chicken',
#   'high',
#   'ingredient',
#   'list',
#   'grain',
#   'suppose',
#   'supermarket',
#   'brand',
#   'dry',
#   'eat',
#   'reluctantly',
#   'nothing',
#   'available',
#   'tend',
#   'prefer',
#   'raw',
#   'meat',
#   'trashier',
#   'highly',
#   'artificially',
#   'flavor',
#   'dry',
#   'treat'],
#  ['picky',
#   'stuff',
#   'one',
#   'problem',
#   'forever',
#   'want',
#   'feed',
#   'always',
#   'mix',
#   'less',
#   'set',
#   'watch',
#   'urinary',
#   'hairball',
#   'issue',
#   'stuff',
#   'taste',
#   'change',
#   'every',
#   '  ',
#   'switch',
#   'around',
#   'lot',
#   'one',
#   'buy',
#   'add',
#   'rotation'],
#  ['price',
#   'unbelievable',
#   'last',
#   'bag',
#   'normally',
#   'mix',
#   'catfood',
#   'odd',
#   'flavor',
#   'since',
#   'rice',
#   'thank',
#   'god',
#   'purina',
#   'one',
#   'brand',
#   'purina'],
#  ['kitty',
#   'almost',
#   'every',
#   'store',
#   'buy',
#   'give',
#   'away',
#   'many',
#   'bag',
#   'uneaten',
#   'one',
#   'winner',
#   'give',
#   '  ',
#   'star',
#   'think',
#   'overprice',
#   'use',
#   'cost',
#   '  ',
#   'less',
#   'suddenly',
#   'shoot'],
#  ['weene',
#   'orphan',
#   'kitty',
#   'formula',
#   'use',
#   'wet',
#   'put',
#   'mid',
#   'meal',
#   'happily',
#   'munch',
#   'away'],
#  ['service',
#   'shipment',
#   'arrive',
#   'shortly',
#   'order',
#   'healthy',
#   'readily',
#   'available'],
#  ['wet',
#   'butmy',
#   'budget',
#   'support',
#   'decide',
#   'dry',
#   'put',
#   'piece',
#   'see',
#   'feel',
#   'second',
#   'moment',
#   'away',
#   'get',
#   'bag',
#   'glad',
#   'subscribe',
#   'monthly',
#   'delivery',
#   'snowy',
#   'condition',
#   'worry',
#   'drive',
#   'either'],
#  ['ingredient',
#   'list',
#   'find',
#   'far',
#   'advertize',
#   'suspiciously',
#   'quiet',
#   'nd',
#   'list',
#   'ingredient',
#   'chicken',
#   'meal',
#   'least',
#   'chicken',
#   'byproduct',
#   'meal',
#   'also',
#   'one',
#   'web',
#   'site',
#   'say',
#   'beet',
#   'pulp',
#   'stoolhardening',
#   'agent',
#   'want',
#   'nevertheless',
#   'ps',
#   'also',
#   'offer',
#   'plain',
#   'yogurt'],
#  ['favorite',
#   'fact',
#   'many',
#   'wholesome',
#   'ingredient',
#   'wow',
#   'price',
#   'grocery',
#   'store',
#   'charge',
#   'five',
#   'dollar',
#   'size',
#   'bag'],
#  ['feed',
#   'expensive',
#   'nongrain',
#   'end',
#   'die',
#   'undiagnosed',
#   'digestive',
#   'issue',
#   'tell',
#   'stick',
#   'purinaall',
#   'four',
#   'eat',
#   'complaint',
#   'eat',
#   'chow',
#   'two',
#   'life',
#   'switch',
#   'chow',
#   'vet',
#   'order',
#   'grow',
#   'fast',
#   'big',
#   'use',
#   'purina',
#   'house',
#   'treat',
#   'trust',
#   'vet',
#   'see',
#   'recommendafter',
#   'read',
#   'every',
#   'ingredient',
#   'list',
#   'every',
#   'exist',
#   'brand',
#   'exaggerate',
#   'back',
#   'trueforget',
#   'fancy',
#   'stuff',
#   'subscribe',
#   'save',
#   'cheap',
#   'store',
#   'one',
#   'less',
#   'remember',
#   'pick',
#   'shopping'],
#  ['start',
#   'woofe',
#   'right',
#   'away',
#   'typically',
#   'picky',
#   'eater',
#   'introduce',
#   'new',
#   'one'],
#  ['feline',
#   'companion',
#   'real',
#   'treasure',
#   'know',
#   'many',
#   'people',
#   'feel',
#   'way',
#   'companion',
#   'animal',
#   'line',
#   'defense',
#   'keep',
#   'healthy',
#   'sure',
#   'kibble',
#   'free',
#   'wheat',
#   'corn',
#   'soy',
#   'reading',
#   'know',
#   'extremely',
#   'important',
#   'serious',
#   'problem',
#   'diet',
#   'need',
#   'address',
#   'research',
#   'start',
#   'endocrine',
#   'disruptor',
#   'neurotoxin',
#   'belong',
#   'anyone',
#   'dieti',
#   'come',
#   'across',
#   'outstanding',
#   'local',
#   'grocery',
#   'store',
#   'stop',
#   'carry',
#   'similar',
#   'formulation',
#   'local',
#   'pet',
#   'store',
#   'taste',
#   'quite',
#   'similar',
#   'one',
#   'beyond',
#   'one',
#   'beyond',
#   'boss',
#   'every',
#   'serve',
#   'get',
#   'disgust',
#   'patent',
#   'let',
#   'three',
#   'neighborhood',
#   'handful',
#   'ecstatic',
#   'sigh',
#   'pickywhen',
#   'similar',
#   'run',
#   'low',
#   'buy',
#   'another',
#   'bag',
#   'one',
#   'beyond',
#   'give',
#   'remainder',
#   'treat',
#   'note',
#   'real',
#   'garbage',
#   'people',
#   'feed',
#   'sick',
#   'eat',
#   'people',
#   'eitherso',
#   'darle',
#   'back',
#   'one',
#   'beyond',
#   'available',
#   'locally',
#   'far',
#   'tell',
#   'amazon',
#   'itif',
#   'get',
#   'increase',
#   'nose',
#   'kiss',
#   'order',
#   'bag',
#   'prepared',
#   'reorder',
#   'probably',
#   'settle',
#   'anything',
#   'less',
#   'ever',
#   'againwhen',
#   'absolutely',
#   'positively',
#   'want',
#   'foodhere'],
#  ['store', 'buy', 'bad', 'choice', 'least', 'nowlol', 'thank'],
#  ['diabetic',
#   '  ',
#   'yrs',
#   'fur',
#   'incredibly',
#   'shiny',
#   'live',
#   'indoor',
#   'hunt'],
#  ['say',
#   'picky',
#   'understate',
#   'itthey',
#   'eat',
#   'people',
#   'thingthey',
#   'touch',
#   'wet',
#   'huhive',
#   'extreme',
#   'healthy',
#   'walk',
#   'awaywould',
#   'rather',
#   'eat',
#   'eat',
#   'thatsuffice',
#   'say',
#   'give',
#   'cheap',
#   'junk',
#   'know',
#   'even',
#   'taste',
#   'likefor',
#   'give',
#   'purina',
#   'one',
#   'still',
#   'occasion',
#   'lengthy',
#   'research',
#   'nutritional',
#   'moisture',
#   'content',
#   'one',
#   'beyond',
#   'keep',
#   'rise',
#   'topit',
#   'easy',
#   'find',
#   'oddly',
#   'enoughbuye',
#   'amazon',
#   'odd',
#   'choice',
#   'bag',
#   'heavy',
#   'bulky',
#   'see',
#   'subscription',
#   'get',
#   'deliver',
#   'house',
#   'definite',
#   'way',
#   'since',
#   'item',
#   'buy',
#   'pet',
#   'store',
#   '  ',
#   'minute',
#   'away',
#   'sure',
#   'beat',
#   'drive',
#   'one',
#   'itemthe',
#   'kitty',
#   '   ',
#   'skin',
#   'fur',
#   'healthy',
#   'weight',
#   'maintain',
#   'knock',
#   'wood',
#   'still',
#   'healthy',
#   'except',
#   'curse',
#   'hairball'],
#  ['thisi',
#   'pay',
#   'special',
#   'attention',
#   'ingredient',
#   'list',
#   'please',
#   'find',
#   'include',
#   'corn',
#   'byproduct',
#   'sadly',
#   'market',
#   'corn',
#   'second',
#   'third',
#   'ingredient',
#   'sometimes',
#   'second',
#   'third',
#   'ingredient',
#   'corn',
#   'meal',
#   'another',
#   'corn',
#   'byproduct',
#   'etc',
#   'wish',
#   'know',
#   'fact',
#   'long',
#   'ago',
#   'recently',
#   'healthy',
#   'choice',
#   'two',
#   'even',
#   'one',
#   'state',
#   'healthy',
#   'alternative',
#   'tend',
#   'contain',
#   'ingredient',
#   'question',
#   'amount',
#   'alarm',
#   'market',
#   'contain',
#   'corn',
#   'main',
#   'ingredient',
#   'healthiest',
#   'alternative',
#   'amazon',
#   'alternative',
#   'healthy',
#   'sadly',
#   'taste',
#   'one',
#   'adorehealthy',
#   'tasty',
#   'ask'],
#  ['piece', 'get', 'nutrient', 'grow', 'need'],
#  ['bengal',
#   'develop',
#   'allergic',
#   'skin',
#   'problem',
#   'eat',
#   'high',
#   'end',
#   'nutro',
#   'brand',
#   'taste',
#   'test',
#   '  ',
#   'turn',
#   'nose',
#   'everything',
#   'top',
#   'notch',
#   'ingredientshence',
#   'pricy',
#   'yes',
#   'picky',
#   'get',
#   'allergiic',
#   'reaction',
#   'easily',
#   'one',
#   'expensive',
#   'lover',
#   'cater'],
#  ['use', 'brand', 'dry', 'half', 'see', 'change', 'weight', 'eat', 'habit'],
#  ['three',
#   'new',
#   'tower',
#   'feeder',
#   'eat',
#   'around',
#   'leave',
#   'meow',
#   'mix',
#   'two',
#   'bag',
#   'plus'],
#  ['two',
#   'one',
#   'sensitive',
#   'tummy',
#   'tend',
#   'get',
#   'loose',
#   'motion',
#   'switch',
#   'right',
#   'back',
#   'however',
#   'price',
#   'site',
#   'lot',
#   'past',
#   'two',
#   'probably',
#   'buy',
#   'site'],
#  ['take',
#   'immediately',
#   'blend',
#   'since',
#   'different',
#   'brand',
#   'actually',
#   'refuse',
#   'eat',
#   'remainder',
#   'opt',
#   'ever',
#   'since',
#   'satisfied',
#   'evening',
#   'coat',
#   'actually',
#   'shiny',
#   'yet',
#   'think',
#   'dull',
#   'prior',
#   'definitely',
#   'purchase',
#   'brand'],
#  ['enjoy', 'know', 'get', 'blaance', 'nutrition'],
#  ['problem',
#   'eat',
#   'long',
#   'never',
#   'throw',
#   'bad',
#   'switch',
#   'wet',
#   'diet',
#   'since',
#   'though',
#   'control',
#   'weight'],
#  ['eat',
#   'whole',
#   'bag',
#   'aevery',
#   'low',
#   'price',
#   'thank',
#   'keep',
#   'price',
#   'lowand',
#   'top',
#   'quality'],
#  ['eat',
#   'dry',
#   'purina',
#   'brand',
#   'eat',
#   'flavor',
#   'one',
#   'beyond',
#   'dry',
#   'thoroughly',
#   'enjoy',
#   'glad',
#   'order',
#   'amazon'],
#  ['favorite',
#   'dry',
#   'give',
#   'anything',
#   'else',
#   'use',
#   'quite',
#   'kitty',
#   'thrive'],
#  ['new',
#   'arrive',
#   'next',
#   'week',
#   'rate',
#   'acceptance',
#   'hopefully',
#   'continue',
#   'grow',
#   'maintain',
#   'health'],
#  ['surprisingly', 'especially', 'ease', 'use', 'pouch', 'convenient', 'use'],
#  ['elder',
#   'eat',
#   'anything',
#   'young',
#   'use',
#   'feed',
#   'artemis',
#   'purina',
#   'vibrant',
#   'maturity',
#   '  ',
#   'could',
#   'long',
#   'find',
#   'grocery',
#   'store',
#   'several',
#   'brand',
#   'regurgitate',
#   'find',
#   'purina',
#   'one',
#   'issue',
#   'digestion',
#   'since',
#   'brand'],
#  ['eat',
#   'wet',
#   'dry',
#   'transfer',
#   'adult',
#   'wet',
#   'find',
#   'dry',
#   'yummy',
#   'yet',
#   'nutritional',
#   'hit',
#   'miss',
#   'purina',
#   'one',
#   'beyond',
#   'chicken',
#   'oatmeal',
#   'prove',
#   'yummy',
#   'produce',
#   'extremely',
#   'foul',
#   'smell',
#   'box',
#   'use',
#   'lot',
#   'aroma',
#   'candle',
#   'buy'],
#  ['one',
#   'cheap',
#   'far',
#   'protein',
#   'content',
#   'purchase',
#   'authority',
#   'brand',
#   'nutrition',
#   'kitty',
#   'also',
#   'get',
#   'subscribe',
#   'save',
#   'reach',
#   'doorstep',
#   'dust'],
#  ['science',
#   'diet',
#   'blue',
#   'wish',
#   'grain',
#   'content',
#   'bit',
#   'less',
#   'least',
#   'corn',
#   'wheatfree',
#   'digestion',
#   'fat',
#   'content',
#   'unlike',
#   'senior',
#   'feline',
#   'kibble',
#   'high',
#   'enough',
#   'keep',
#   'coat',
#   'condition'],
#  ['deal', 'hard', 'find', '  ', 'lb', 'list', 'prime', 'wish', 'order'],
#  ['finickyspoile',
#   'world',
#   'turn',
#   'nose',
#   'expensive',
#   'origen',
#   'taste',
#   'wild',
#   'wellness',
#   'evos',
#   '  ',
#   'meat',
#   'spot',
#   'stew',
#   'science',
#   'diet',
#   'paul',
#   'newmans',
#   'etc',
#   'etc',
#   'etc',
#   'feed',
#   'grainfree',
#   'freefeed',
#   'one',
#   'beyond',
#   'night',
#   'get',
#   'nighttime',
#   'munchie',
#   'start',
#   'pm',
#   'allow',
#   'sleep',
#   'picky',
#   'picky',
#   'princess',
#   'surprisingly',
#   'take',
#   'one',
#   'beyond',
#   'right',
#   'away',
#   'get',
#   'salmon',
#   'flavor',
#   'also'],
#  ['switch',
#   'fact',
#   'byproduct',
#   'everything',
#   'natural',
#   'plus',
#   'could',
#   'find',
#   'local',
#   'store',
#   'two',
#   'youngest',
#   'horrible',
#   'skin',
#   'issue',
#   'last',
#   'cheap',
#   'stuff',
#   'switch',
#   'dick',
#   'van',
#   'pattens',
#   'natural',
#   'balance',
#   'limit',
#   'ingredient',
#   'stick',
#   'constantly',
#   'scratch',
#   'two',
#   'large',
#   'scab',
#   'throw',
#   'crap',
#   'away',
#   'back',
#   'natural',
#   'balance',
#   'fool',
#   'garbarge'],
#  ['neon',
#   'age',
#   '  ',
#   'inflammatory',
#   'bowel',
#   'allergic',
#   'wheat',
#   'corn',
#   'beef',
#   'refuse',
#   'hill',
#   'allergy',
#   'prescription',
#   'importantly',
#   'control',
#   'diarrhea',
#   'issue'],
#  ['switch',
#   '  ',
#   'kindey',
#   'issue',
#   'patient',
#   'maintenance',
#   'uti',
#   'blockage',
#   'course',
#   'get',
#   'vet',
#   'care',
#   'hills',
#   'diet',
#   'sd',
#   'cd',
#   'whilethat',
#   'expensive',
#   'especially',
#   'run',
#   'rescue',
#   'consulting',
#   'vet',
#   'brand',
#   'w',
#   'cranberry',
#   'blue',
#   'buffalo',
#   'othersi',
#   'feed',
#   'brand',
#   'patient',
#   'kidney',
#   'issue',
#   'control',
#   'blockage',
#   'etc',
#   'also',
#   'give',
#   'supplement',
#   'uri',
#   'soothe',
#   'addition',
#   'male',
#   'fix',
#   'prone',
#   'kidney',
#   'issuesi',
#   'highly'],
#  ['expenxive', 'amount', 'recieve', 'eat', 'order', 'grow', 'last', 'long'],
#  ['expensive', 'name', 'brand', 'throw', 'less'],
#  ['never',
#   'find',
#   'anything',
#   'repeatedly',
#   'eat',
#   'find',
#   'dry',
#   'almost',
#   '  ',
#   'russian',
#   'blue',
#   'define',
#   'term',
#   'picky',
#   'eater',
#   'waste',
#   'simply',
#   'turn',
#   'away',
#   'female',
#   'rather',
#   'starve',
#   'eat',
#   'something',
#   'dislike',
#   'search',
#   'something',
#   'anything',
#   'eat',
#   'thank',
#   'purina',
#   'one',
#   'beyond',
#   'chicken',
#   'oatmeal'],
#  ['could',
#   'give',
#   'less',
#   'one',
#   'star',
#   'feed',
#   'two',
#   'think',
#   'healthy',
#   'ingredient',
#   'instead',
#   'purina',
#   'one',
#   'beyond',
#   'end',
#   'cause',
#   'need',
#   'surgery',
#   'within',
#   'one',
#   'end',
#   'lose',
#   'two',
#   'tooth',
#   'need',
#   'bladder',
#   'surgery',
#   'due',
#   'fact',
#   'five',
#   'bladder',
#   'stone',
#   'size',
#   'sand',
#   'pebble',
#   'vet',
#   'take',
#   'stone',
#   'analyze',
#   'say',
#   'buildup',
#   'mineral',
#   'due',
#   'diet',
#   'save',
#   'worry',
#   'heartache',
#   'buy'],
#  ['healthy',
#   'break',
#   'bank',
#   'dry',
#   'wellness',
#   'science',
#   'diet',
#   'blue',
#   'buffalo',
#   'etc',
#   'bring',
#   'bag',
#   'home',
#   'sit',
#   'one',
#   'actually',
#   'start',
#   'tear',
#   'bag',
#   'get',
#   'start',
#   'get',
#   'know',
#   'soon',
#   'dry',
#   'dish',
#   'get',
#   'low',
#   'start',
#   'cry',
#   'also',
#   'note',
#   'one',
#   'utis',
#   'vet',
#   'say',
#   'likely',
#   'stress',
#   'new',
#   'kitty',
#   'prozac',
#   'switch',
#   'utis',
#   'stop'],
#  ['   ',
#   'always',
#   'digestive',
#   'troublehad',
#   'feed',
#   'another',
#   'brandin',
#   'crazy',
#   'smell',
#   'opening',
#   'containereven',
#   'though',
#   'still',
#   'smell',
#   'brand',
#   'dry',
#   'foodhis',
#   'tooth',
#   'mouth',
#   'want',
#   'feed',
#   'foodafter',
#   'read',
#   'couple',
#   'review',
#   'purina',
#   'one',
#   'beyond',
#   'foodsalmon',
#   'brown',
#   'rice',
#   'figure',
#   'see',
#   'eat',
#   'brandwell',
#   'ithe',
#   'gain',
#   'weightpurre',
#   'playful',
#   'againno',
#   'upchuck',
#   'clean',
#   'upsthough',
#   'empty',
#   'bouka',
#   'box',
#   'often'],
#  ['notice',
#   'throw',
#   'less',
#   'poop',
#   'claim',
#   'notice',
#   'anything',
#   'less',
#   'litterboxmy',
#   'extremely',
#   'feel',
#   'give',
#   'decent',
#   'last'],
#  ['feed',
#   '  ',
#   'indooroutdoor',
#   'conjunction',
#   'give',
#   'choice',
#   'one',
#   'beyond',
#   'something',
#   'else',
#   'meow',
#   'mix',
#   'near',
#   'winner',
#   'house'],
#  ['buy', 'grocery', 'store', 'buy', 'amazon', 'probably', 'buy'],
#  ['kitty',
#   'eat',
#   'every',
#   'without',
#   'cornfrom',
#   'expensive',
#   'cheap',
#   'one',
#   'never',
#   'vomit',
#   'firmforme',
#   'poop',
#   'itsad',
#   'say',
#   'long'],
#  ['long',
#   'get',
#   'subscribe',
#   'save',
#   'account',
#   'miss',
#   'convenience',
#   'deliver'],
#  ['use',
#   'hate',
#   'dry',
#   'eat',
#   'without',
#   'wet',
#   'also',
#   'science',
#   'diet',
#   'even',
#   'hate',
#   'buy',
#   'bag',
#   'purina',
#   'one',
#   'beyond',
#   'test',
#   'eat',
#   'without',
#   'wet',
#   'finish',
#   'every',
#   'bowl',
#   'last',
#   'piece',
#   'kibble',
#   'immediately',
#   'buy',
#   'big',
#   'bag',
#   'big',
#   'plus',
#   'side',
#   'healthy',
#   'many',
#   'harmful',
#   'filler',
#   'kitty',
#   'chow',
#   'purina',
#   'one',
#   'beyond',
#   'definitely',
#   'owner'],
#  ...]

# %%
cleaned_sens = pd.DataFrame([re.sub(' +', ' ', ' '.join(sen)) for sen in df1_dict['cleaned_tokens2']], columns = ['cleaned_sens'])

# %%
bigrams = [' '.join(x) for x in df1_dict['cleaned_bi_pmi2'][:120].bigram.values]
trigrams = [' '.join(x) for x in df1_dict['cleaned_tri_pmi2'][:120].trigram.values]

# %%
cleaned_sens.cleaned_sens = cleaned_sens.cleaned_sens.map(lambda x: replace_ngram(x, bigrams, trigrams))

# %%
# bigrams2 = [' '.join(x) for x in df1_dict['cleaned_bi_freq2'][:120].bigram.values]
# trigrams2 = [' '.join(x) for x in df1_dict['cleaned_tri_freq2'][:120].trigram.values]

# %%
# cleaned_sens.cleaned_sens = cleaned_sens.cleaned_sens.map(lambda x: replace_ngram(x, bigrams2, trigrams2))

# %%
cleaned_sens.cleaned_sens[10]
# Out:
# 'meet cat nutritional need'

# %%
cleaned_sens.iloc[27841]
# Out:
# cleaned_sens    cat one issue pancreatitis ok far feed mixture...
# Name: 27841, dtype: object

# %%
cleaned_sens.cleaned_sens
# Out:
# 0        find sale buy whim kitten omg go nuts hardwood...
# 1        kittens crazy grow pay attention new play fetc...
# 2        absolutely love spinner carry around mouth tos...
# 3        tiny make lightweight plastic give one minute ...
# 4        buy thinking use spinner basis hang curious pl...
#                                ...
# 27838    cat receive wrong recipe order spot pate turke...
# 27839    buy twenty one year problem throw try change s...
# 27840    come take week explanation assume production r...
# 27841    cat one issue pancreatitis ok far feed mixture...
# 27842    new mother week name murphy cat adult life mur...
# Name: cleaned_sens, Length: 27843, dtype: object

# %% [markdown]
# #### sentence level

# %%
cleaned_sens1 = pd.DataFrame([re.sub(' +', ' ', ' '.join(sen)) for sen in df1_sen1_dict['cleaned_tokens2']], columns = ['cleaned_sens'])

# %%
cleaned_sens1.cleaned_sens = cleaned_sens1.cleaned_sens.map(lambda x: replace_ngram(x, bigrams, trigrams))

# %%
cleaned_sens1.iloc[27841]
# Out:
# cleaned_sens    cat
# Name: 27841, dtype: object

# %% [markdown]
# # investigate the corpus

# %%
updated_tags = [pos_tag(sen) for sen in tqdm(cleaned_sens.cleaned_sens.apply(lambda x:x.split()).values.tolist())]
# Out:
#   0%|          | 0/27843 [00:00<?, ?it/s]

# %%
connected_bigrams = [x.split()[0] + '_' + x.split()[1] for x in bigrams]
connected_trigrams = [x.split()[0] + '_' + x.split()[1] + '_' + x.split()[2] for x in trigrams]

# %%
#[[t for t in sen if t[0] in connected_bigrams] for sen in updated_tags]
#[[t for t in sen if t[0] in connected_trigrams] for sen in updated_tags]

# %%
updated_tags[7] #('around', 'IN')
# Out:
# [('blu', 'NN'),
#  ('love', 'VB'),
#  ('somehow', 'RB'),
#  ('find', 'VB'),
#  ('one', 'CD'),
#  ('around', 'IN'),
#  ('house', 'NN'),
#  ('love', 'NN'),
#  ('toss', 'IN'),
#  ('air', 'NN'),
#  ('chase', 'NN'),
#  ('tough', 'JJ'),
#  ('keep', 'NN'),
#  ('find', 'VBP'),
#  ('one', 'CD'),
#  ('order', 'NN'),
#  ('x', 'VBZ'),
#  ('pack', 'NNS'),
#  ('take', 'VBP'),
#  ('long', 'JJ'),
#  ('get', 'NN'),
#  ('quite', 'RB'),
#  ('frankly', 'RB'),
#  ('could', 'MD'),
#  ('find', 'VB'),
#  ('anywhere', 'JJ'),
#  ('else', 'RB')]

# %%
adv_tokens = [t[0] for sen in updated_tags for t in sen if t[1] == 'RB']
#adv_tokens

# %%
remained_tokens = [[t[0] for t in sen if any([t[1] not in ['CD', 'RB', 'MD', 'VBZ', 'IN', 'VBZ'], "_" in t[0]])] for sen in updated_tags]

# %%
tokens = [token for sen in remained_tokens for token in sen]
mc_tuples = FreqDist(tokens).most_common(100)
mc_words = [t[0] for t in mc_tuples] 
mc_words = [t[0] for t in mc_tuples] 
mc_adjs = [t[0] for t in df1_dict['adj_tokens']] 
mc_verbs = [t[0] for t in df1_dict['verb_tokens']] 
mc_nouns = [t[0] for t in df1_dict['noun_tokens']]

# %%
retain_words = [
# 'cat',
# 'eat',
# 'get',
# 'dry',
# 'feed',
# 'buy',
 'brand',
# 'give',
# 'love',
 'flavor',
# 'find',
# 'food',
 'chicken',
# 'try',
 'price',
 'ingredient',
# 'use',
 'healthy',
 'diet',
# 'bag',
 'vet',
 'pet',
 'store',
# 'go',
# 'think',
 'quality',
# 'wet',
# 'know',
# 'make',
 'amazon',
 'problem',
# 'seem',
# 'say',
# 'year',
 'order',
# 'kitty',
# 'high',
 'grain',
# 'see',
# 'come',
# 'stuff',
 'switch',
# 'look',
 'variety',
# 'keep',
# 'want',
 'smell',
# 'start',
# 'every',
 'expensive',
# 'less',
 'weight',
# 'free',
# 'take',
# 'need',
# 'lot',
 'natural',
# 'mix',
 'meat',
 'picky',
 'fancy_feast',
# 'many',
# 'put',
 'different',
 'formula',
 'treat',
# 'coat',
 'wellness',
# 'good',
 'week',
 'issue',
 'purchase',
# 'bit',
 'fish',
# 'new',
 'taste',
 'bowl',
 'cheap',
# 'something',
# 'change',
# 'case',
# 'help',
# 'sure',
 'throw',
# 'month',
 'gravy',
# 'open',
# 'box',
# 'way',
# 'bad',
# 'leave',
# 'big',
 'meal',
 'protein',
 'review',
 'tuna',
# 'another',
# 'last',
 'save',
 'health'
] + ['one', 'two', 'three', 'four', 'five', 'also', 'can', 'well', 'could', 'anything', 'also', 'different', 'enjoy', 'even', 'since', 'still', 'old']

# %%
deleted_words = [w for w in mc_words if w not in retain_words] + ['one', 'two', 'three', 'four', 'five', 'also', 'can', 'well', 'could', 'anything', 'also', 'different', 'enjoy', 'even', 'since', 'still', 'old'] + adv_tokens

# %%
deleted_words = list(set(deleted_words))

# %%
#sorted(deleted_words)

# %%
# import re
# re.sub('[\d.,]' , '', '25can')

# %%
final_tokens = [[token for token in sen.split() if token not in deleted_words] for sen in cleaned_sens.cleaned_sens.values.tolist()]

# %%
all_vocabularies = list(set([token for sen in final_tokens for token in sen]))

# %%
'would' in all_vocabularies
# Out:
# True

# %%
len(all_vocabularies)
# Out:
# 32198

# %% [markdown]
# #### sentence level

# %%
updated_tags_sens1 = [pos_tag(sen) for sen in tqdm(cleaned_sens1.cleaned_sens.apply(lambda x:x.split()).values.tolist())]
# Out:
#   0%|          | 0/27843 [00:00<?, ?it/s]

# %%
remained_tokens_sens1 = [[t[0] for t in sen if any([t[1] not in ['CD', 'RB', 'MD', 'VBZ', 'IN', 'VBZ'], "_" in t[0]])] for sen in updated_tags_sens1]

# %%
final_tokens_sens1 = [[token for token in sen.split() if token not in deleted_words] for sen in cleaned_sens1.cleaned_sens.values.tolist()]

# %% [markdown]
# # LDA

# %%
def vectorize(texts):
    dictionary = corpora.Dictionary(tqdm(texts))
    doc_term_matrix = [dictionary.doc2bow(doc) for doc in tqdm(texts)]
    return dictionary, doc_term_matrix

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        print('Round: '+ str(num_topics))
        model = LdaMulticore(corpus=corpus, 
                                num_topics=num_topics, 
                                id2word=dictionary,
                                passes=40,
                                iterations=10, 
                                chunksize = 100, 
                                eval_every = None,
                                random_state = 1234) #random_state
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, 
                                        texts=texts, 
                                        dictionary=dictionary, 
                                        coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

def get_keywords(doc_term_matrix, model): #top 20
    keywords_dict = {}
    for k in range(len(model.top_topics(doc_term_matrix))):
        tu = model.top_topics(doc_term_matrix)[k]
        keywords_lst = []
        for tup in tu[0]:
            keywords_lst.append(tup[1])
        keywords_dict[k] = keywords_lst
    return keywords_dict

# %%
cats_food_dictionary, cats_food_doc_term_matrix = vectorize(final_tokens)
# Out:
#   0%|          | 0/27843 [00:00<?, ?it/s]
#   0%|          | 0/27843 [00:00<?, ?it/s]

# %%
cats_food_sen1_dictionary, cats_food_sen1_doc_term_matrix = vectorize(final_tokens_sens1)
# Out:
#   0%|          | 0/27843 [00:00<?, ?it/s]
#   0%|          | 0/27843 [00:00<?, ?it/s]

# %%
cats_food_model_list, cats_food_coherence_values = compute_coherence_values(
                                                    dictionary=cats_food_dictionary, 
                                                    corpus=cats_food_doc_term_matrix, 
                                                    texts=final_tokens, 
                                                    start=2, 
                                                    limit=20, 
                                                    step=2)
# Out:
# Round: 2
# Round: 4
# Round: 6
# Round: 8
# Round: 10
# Round: 12
# Round: 14
# Round: 16
# Round: 18

# %%
cats_food_model_list
# Out:
# [<gensim.models.ldamulticore.LdaMulticore at 0x25499899880>,
#  <gensim.models.ldamulticore.LdaMulticore at 0x254998cde80>,
#  <gensim.models.ldamulticore.LdaMulticore at 0x254998c8910>,
#  <gensim.models.ldamulticore.LdaMulticore at 0x254998c8f70>,
#  <gensim.models.ldamulticore.LdaMulticore at 0x254998dcfd0>,
#  <gensim.models.ldamulticore.LdaMulticore at 0x25478372e20>,
#  <gensim.models.ldamulticore.LdaMulticore at 0x254998e4a90>,
#  <gensim.models.ldamulticore.LdaMulticore at 0x2548e7287c0>,
#  <gensim.models.ldamulticore.LdaMulticore at 0x254998dcaf0>]

# %%
limit=20; start=2; step=2;
x = range(start, limit, step)
plt.plot(x, cats_food_coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()
for m, cv in zip(x, cats_food_coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.5021
# Num Topics = 4  has Coherence Value of 0.6243
# Num Topics = 6  has Coherence Value of 0.5656
# Num Topics = 8  has Coherence Value of 0.5985
# Num Topics = 10  has Coherence Value of 0.543
# Num Topics = 12  has Coherence Value of 0.5276
# Num Topics = 14  has Coherence Value of 0.5218
# Num Topics = 16  has Coherence Value of 0.5015
# Num Topics = 18  has Coherence Value of 0.4897

# %%
with open ('./model/cats_food_model_list.pickle', 'wb') as handle:
    pickle.dump(cats_food_model_list, handle)

# %% [markdown]
# # model interpretation

# %%
with open ('./model/cats_food_model_list.pickle', 'rb') as handle:
    cats_food_model_list = pickle.load(handle)

# %%
# for m in cats_food_model_list: 
#     print(CoherenceModel(model=m, 
#                    texts=df1_dict['cleaned_tokens2'], 
#                    dictionary=cats_food_dictionary, 
#                    coherence='c_v').get_coherence())

# %%
cats_food_optimal_model = cats_food_model_list[1] #flavor, ingrent, price, (and ?) #brand, formula etc
model_topics = cats_food_optimal_model.show_topics(formatted=False)
cats_food_optimal_model.print_topics(num_topics=8,num_words=30)
# Out:
# [(0,
#   '0.053*"price" + 0.035*"order" + 0.014*"local" + 0.011*"brand" + 0.010*"large" + 0.009*"size" + 0.009*"receive" + 0.009*"shipping" + 0.007*"arrive" + 0.007*"carry" + 0.007*"several" + 0.007*"item" + 0.006*"online" + 0.006*"expensive" + 0.006*"delivery" + 0.006*"money" + 0.005*"per" + 0.005*"review" + 0.005*"beef" + 0.004*"dent" + 0.004*"small" + 0.004*"available" + 0.004*"convenient" + 0.004*"hate" + 0.004*"pound" + 0.004*"packaging" + 0.004*"send" + 0.004*"day" + 0.004*"stock" + 0.004*"house"'),
#  (1,
#   '0.019*"problem" + 0.012*"week" + 0.010*"sensitive" + 0.010*"clean" + 0.008*"work" + 0.008*"healthy" + 0.008*"day" + 0.007*"house" + 0.007*"morning" + 0.006*"night" + 0.006*"we" + 0.005*"without" + 0.005*"regular" + 0.005*"digestive" + 0.005*"time" + 0.005*"life" + 0.005*"do" + 0.005*"kind" + 0.005*"couple" + 0.004*"control" + 0.004*"fine" + 0.004*"health" + 0.004*"might" + 0.004*"care" + 0.004*"review" + 0.004*"wonderful" + 0.004*"siamese" + 0.004*"everything" + 0.004*"dish" + 0.004*"age"'),
#  (2,
#   '0.044*"ingredient" + 0.018*"tuna" + 0.013*"list" + 0.013*"brand" + 0.012*"natural" + 0.011*"real" + 0.009*"human" + 0.009*"byproduct" + 0.007*"corn" + 0.007*"product" + 0.007*"healthy" + 0.005*"whole" + 0.005*"supplement" + 0.005*"source" + 0.005*"read" + 0.005*"top" + 0.005*"company" + 0.004*"include" + 0.004*"oil" + 0.004*"vegetable" + 0.004*"rice" + 0.004*"wheat" + 0.004*"reason" + 0.004*"beef" + 0.004*"people" + 0.004*"green" + 0.003*"color" + 0.003*"nutritious" + 0.003*"may" + 0.003*"part"'),
#  (3,
#   '0.035*"brand" + 0.028*"healthy" + 0.018*"expensive" + 0.013*"kibble" + 0.010*"problem" + 0.010*"water" + 0.010*"recommend" + 0.010*"health" + 0.009*"ingredient" + 0.009*"natural" + 0.008*"pound" + 0.008*"low" + 0.007*"worth" + 0.007*"research" + 0.006*"raw" + 0.006*"male" + 0.006*"week" + 0.005*"amount" + 0.005*"royal_canin" + 0.004*"review" + 0.004*"prescription" + 0.004*"life" + 0.004*"several" + 0.004*"feline" + 0.004*"premium" + 0.004*"end" + 0.004*"energy" + 0.004*"choice" + 0.004*"may" + 0.004*"content"')]

# %%
pyLDAvis.enable_notebook()
topic_data =  pyLDAvis.gensim_models.prepare(cats_food_optimal_model, 
                                             cats_food_doc_term_matrix, 
                                             cats_food_dictionary
                                             #,mds = 'tsne'
                                            )
pyLDAvis.display(topic_data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1574825624184197444407325991"></div>
# <script type="text/javascript">
#
# var ldavis_el1574825624184197444407325991_data = {"mdsDat": {"x": [0.030456711478376173, -0.06846855036590072, 0.21266018102406808, -0.17464834213654362], "y": [0.06271581912295533, 0.18106255769835522, -0.08285001284178317, -0.16092836397952726], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [30.43306408655061, 23.496990518056844, 23.130508662800544, 22.939436732592004]}, "tinfo": {"Term": ["price", "ingredient", "order", "tuna", "healthy", "kibble", "brand", "expensive", "list", "local", "problem", "real", "sensitive", "receive", "byproduct", "shipping", "water", "recommend", "clean", "human", "natural", "arrive", "size", "carry", "week", "raw", "work", "male", "morning", "corn", "kibble", "raw", "male", "prescription", "diabetic", "urinary", "level", "calorie", "carb", "reduce", "crystal", "diabetes", "veterinarian", "budget", "carbohydrate", "closure", "ibd", "renal", "urinary_tract", "office", "resealable", "carbs", "bladder", "dietary", "blockage", "failure", "lean", "costly", "muscle", "castor_pollux", "thrive", "disease", "throughout", "water", "recommend", "expensive", "freeze", "research", "healthy", "low", "brand", "warm", "health", "pound", "energy", "worth", "royal_canin", "alternative", "premium", "amount", "extra", "rabbit", "natural", "problem", "content", "ingredient", "choice", "week", "life", "feline", "review", "end", "several", "may", "sensitive", "siamese", "beautiful", "stinky", "spot_stew", "packet", "carpet", "m", "husband", "solve", "job", "wake", "ragdoll", "bathroom", "leg", "tail", "grateful", "pine", "shine", "pill", "noticeable", "clumping", "haired", "chubby", "wolf", "accident", "cleaning", "tidy", "rid", "wood", "night", "evening", "floor", "morning", "room", "horrible", "clean", "vomiting", "wonderful", "digestive", "work", "problem", "house", "upset", "week", "slow", "hour", "control", "I", "day", "time", "do", "fine", "regular", "life", "we", "couple", "without", "everything", "kind", "healthy", "age", "care", "might", "dish", "health", "review", "tuna", "real", "byproduct", "vegetable", "oil", "green", "color", "nutritious", "juice", "ocean", "egg", "taurine", "mineral", "cheese", "sardine", "china", "primary", "sweet_potato", "preservative", "artificial", "b", "gross", "additive", "temptation", "mush", "petite_cuisine", "manufacture", "starch", "yellow", "chop", "list", "clay", "usa", "ingredient", "human", "rice", "actual", "wheat", "poultry", "corn", "source", "supplement", "natural", "white", "product", "whole", "top", "read", "brand", "include", "company", "healthy", "people", "reason", "beef", "part", "may", "order", "price", "receive", "shipping", "arrive", "carry", "delivery", "dent", "convenient", "packaging", "stock", "subscription", "sale", "shipment", "cent", "service", "beat", "donate", "charge", "date", "refund", "discount", "car", "rip", "earthborn", "cancel", "crush", "reorder", "giblet", "bored", "disappoint", "damage", "item", "local", "buying", "reasonable", "online", "size", "large", "plastic", "send", "return", "dinner", "small", "money", "beef", "several", "per", "brand", "review", "expensive", "available", "hate", "pound", "day", "house"], "Freq": [3978.0, 4215.0, 2594.0, 1379.0, 3844.0, 1281.0, 5348.0, 2222.0, 1017.0, 1128.0, 2686.0, 796.0, 784.0, 684.0, 686.0, 649.0, 1073.0, 1127.0, 893.0, 824.0, 1965.0, 548.0, 976.0, 525.0, 1705.0, 626.0, 907.0, 587.0, 603.0, 747.0, 1280.921405673464, 626.0672382027929, 587.2916666664078, 441.5329222097009, 366.60950508123653, 347.54045243968716, 336.2131586332299, 309.0342668479398, 270.14544513849955, 267.43719084778985, 238.71696995595875, 222.2844963179286, 167.24269319957475, 149.82097642553788, 138.69408368673055, 149.15884807872834, 127.6080299951001, 115.0752829506765, 112.61533972468482, 99.41449714159222, 103.71625610080484, 95.95396276732927, 95.4131328292235, 88.77789142101754, 85.77491648959622, 89.94739778933348, 86.30985396945928, 86.1609788561796, 83.1050292879713, 76.51380023128364, 167.74456967714136,  ...

# %%
pyLDAvis.save_html(topic_data, 'cat_food_lda.html')

# %% [markdown]
# # link topics to sentence level (?????)

# %%
#pprint(cats_food_optimal_model.show_topics(formatted=False, num_words=30))

# %%
all_topics = {}
num_terms = 15 # Adjust number of words to represent each topic
lambd = 0.6 # Adjust this accordingly based on tuning above
for i in range(1,5): #Adjust this to reflect number of topics chosen for final LDA model
    topic = topic_data.topic_info[topic_data.topic_info.Category == 'Topic'+str(i)].copy()
    topic['relevance'] = topic['loglift']*(1-lambd)+topic['logprob']*lambd
    all_topics['Topic '+str(i)] = topic.sort_values(by='relevance', ascending=False).Term[:num_terms].values
pd.DataFrame(all_topics).T

# %%
# documents --------------
# count = 0
# for i in cats_food_optimal_model[cats_food_doc_term_matrix]:
#     print('doc :', count, i)
#     count += 1

# %%
vector = cats_food_optimal_model[cats_food_sen1_doc_term_matrix] #cats_food_sen1_dictionary, cats_food_sen1_doc_term_matrix

# %%
# sentences --------------
# count = 0
# for i in cats_food_optimal_model[cats_food_sen1_doc_term_matrix]:
#     print('doc :', count, i)
#     count += 1

# %%
def format_topics_sentences(ldamodel, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=cats_food_optimal_model, 
                                                  corpus=cats_food_sen1_doc_term_matrix, 
                                                  texts=final_tokens_sens1)

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)

# %%
df_dominant_topic = pd.concat([df_dominant_topic, sents_df1.Sentence1], axis = 1)

# %%
df_dominant_topic.head()

# %%
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_dominant_topic.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Topic_Perc_Contrib'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# # Format
# sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# # Show
# sent_topics_sorteddf_mallet.head()

# %%
sent_topics_sorteddf_mallet

# %%
pd.DataFrame(all_topics).T

# %%
sent_topics_sorteddf_mallet.Sentence1[0] #?

# %%
sent_topics_sorteddf_mallet.Sentence1[1] #?

# %%
sent_topics_sorteddf_mallet.Sentence1[2] #?

# %%
sent_topics_sorteddf_mallet.Sentence1[3] #?

# %%
#df_dominant_topic[df_dominant_topic.Document_No == 27] #???

# %% [markdown]
# # train W2V model

# %%
from gensim.test.utils import common_texts
from gensim.models import Word2Vec

# %%
#allreviews_lst = ' '.join([[word.lower() for word in str(sentence).split() if word.lower() not in stop_words] for sentence in df.reviewText.values.tolist()])

# %%
model = Word2Vec(sentences=df1_dict['cleaned_tokens2'], size=300, window=5, min_count=20, workers=-1)
model.save("word2vec.model")

# %% [markdown]
# # link features, plus text parsing, link sentences

# %%
import gensim.downloader
w2v = gensim.downloader.load('word2vec-google-news-300')
# w2v = Word2Vec.load("word2vec.model")

def vectorize_features(features):
    '''
    Embed features to vectors. 

        Parameters:
                features (list): A list of features. 

        Returns:
                arr_dict (dictionary): A dictionary collects {'feature': vector}.
    '''
    arr_dict = {}
    for f in features:
        if isinstance(f, tuple) and len(f) == 2:
            arr = np.mean(np.array([w2v[f[0]], w2v[f[1]]]), axis=0)
            arr_dict[f] = arr
        if isinstance(f, tuple) and len(f) == 3:
            arr = np.mean(np.array([w2v[f[0]], w2v[f[1]], w2v[f[2]]]), axis=0)
            arr_dict[f] = arr
        if isinstance(f, str):
            arr = w2v[f]
            arr_dict[f] = arr

    return arr_dict

def compare_pairwise_features(features, arr_dict):
    '''
    Compute similarity of pairwise features. 

        Parameters:
                features (list): A list of features. 
                arr_dict (dictionary): A dictionary collects {'feature': vector}.

        Returns:
                similarity_dict (dictionary): A dictionary collects {'(pairwise features in a tuple)': similarity score}.
    '''
    pairs =list(itertools.combinations(features, 2))
    similarity_dict = {}
    for p in pairs:
        score = dot(arr_dict[p[0]], arr_dict[p[1]])/(norm(arr_dict[p[0]])*norm(arr_dict[p[1]]))
        similarity_dict[p] = score
    return similarity_dict

# %%
# all_topics = {}
# num_terms = 15 # Adjust number of words to represent each topic
# lambd = 0.6 # Adjust this accordingly based on tuning above
# for i in range(1,5): #Adjust this to reflect number of topics chosen for final LDA model
#     topic = topic_data.topic_info[topic_data.topic_info.Category == 'Topic'+str(i)].copy()
#     topic['relevance'] = topic['loglift']*(1-lambd)+topic['logprob']*lambd
#     all_topics['Topic '+str(i)] = topic.sort_values(by='relevance', ascending=False).Term[:num_terms].values
# topic_kw_tables = pd.DataFrame(all_topics).T

# %%
w2v.similarity('chunk', 'amount') 
w2v.similarity('deliver', 'shipping')
# Out:
# 0.15923679

# %%
w2v.similarity('diet', 'meal') #??????
# Out:
# 0.39932004

# %%
w2v.most_similar('deliver')
# Out:
# [('delivering', 0.7694646120071411),
#  ('delivered', 0.7016089558601379),
#  ('delivers', 0.6644934415817261),
#  ('Delivering', 0.6292617321014404),
#  ('provide', 0.6142929792404175),
#  ('todeliver', 0.5873906016349792),
#  ('produce', 0.5805103778839111),
#  ('Deliver', 0.5291215181350708),
#  ('deliever', 0.5156580209732056),
#  ('achieve', 0.5106956958770752)]

# %%
feature_lst1 = [f[0] + ' ' + f[1] if isinstance(f, tuple) and len(f) == 2 else f for f in feature_lst]
feature_lst2 = [f[0] + ' ' + f[1] + ' ' + f[2] if isinstance(f, tuple) and len(f) == 3 else f for f in feature_lst1]

# %%
def bigram_filter(bigram):
    """
    Filter bigram. 
        
        Parameters:
            bigram (string): A bigram.

        Returns:
           _ (boolean): Decide whether or not to keep the bigram.
    """
    stop_words = stopwords.words('english')   
    tag = nltk.pos_tag(bigram)
    if tag[0][1] not in ['JJ', 'NN'] and tag[1][1] not in ['NN']: #we only want adjective + noun
        return False
    if bigram[0] in stop_words or bigram[1] in stop_words: 
        return False
    if 'n' in bigram or 't' in bigram:
        return False
    if 'PRON' in bigram: 
        return False
    if len(bigram[0]) <= 2 or len(bigram[1]) <= 2:
        return False
    return True

# %%
feature_lst2 = [
 'amount',
 #'balance',
 'beef',
 'brand',
 'break bank',
 'byproduct',
 'calcium carbonate',
 # 'calcium iodate', #?????????????????
 'cheap',
 'chicken',
 #'choice',
 'choline chloride',
 'chunk',
 'balanced nutrition',
 'corn',
 'cost',
# 'deliver front door',
# 'diabetic',
 'different flavor',
 'diversity flavor choose',
 'expensive',
 'fatty acids',
 'ferrous sulfate',
 'fish',
 'flavor',
 'folic acid',
 'formula',
 'fresh',
 #'friske',
 'grain',
 'gravy',
 'health',
 'ingredient',
 'kibble',
 'low carb', #adj + noun
 'meat',
 'money',
 'natural',
 'natural balance',
 'nutrition',
 'ocean whitefish', #noun + noun
# 'order',
 'organic',
 'pack',
 'powdered cellulose',
 'prescription',
 'price',
 'protein',
 'pyridoxine hydrochloride',
 'quality',
  'rice',
 'salmon',
 'save money',
 'several',
# 'ship',
 'size',
 'smell',
 'sodium bisulfate',
 'sodium bisulfite',
 'subscribe save',
 'subscribe save option',
 'subscribe save program',
 'taste',
 'taste wild',
 'thiamine mononitrate',
# 'treat',
 'tuna',
 'turkey',
 'variety',
 'variety pack',
 'vegetable',
 'vitamin',
 'vitamin b supplement',
 'vitamin e supplement',
 'vitamin nutrient mineral',
 'waste money',
# 'wellness',
 'zinc oxide',
 'zinc sulfate'
]

# %%
updated_feature_lst = []
for w in feature_lst2:
    if len(w.split()) == 2:
        updated_w = (w.split()[0], w.split()[1])
        updated_feature_lst.append(updated_w)
    if len(w.split()) == 3:
        updated_w = (w.split()[0], w.split()[1], w.split()[2])
        updated_feature_lst.append(updated_w)
    if len(w.split()) == 1:
        updated_feature_lst.append(w)

# %%
# feature_lst.remove(('manganese', 'proteinate'))
# feature_lst.remove(('zinc', 'proteinate'))
# feature_lst.remove(('copper', 'proteinate'))
# feature_lst.remove(('proteinate', 'copper'))

# %%
# feature_lst.remove(('calcium', 'pantothenate'))

# %%
vec_features = vectorize_features(updated_feature_lst)
dict_features = compare_pairwise_features(updated_feature_lst, vec_features)

# %%
{k: v for k, v in sorted(dict_features.items(), key=lambda item: item[1], reverse=True)}

# %%
{k: v for k, v in sorted(dict_features.items(), key=lambda item: item[1], reverse=False)}

# %%
for k, v in dict_features.items():
    if v < 0:
        dict_features[k] = 0

# %%
{k: v for k, v in sorted(dict_features.items(), key=lambda item: item[1], reverse=True)}

# %% [markdown]
# # clustering graphing using dendrogram

# %%
updated_feature_lst
# Out:
# ['amount',
#  'beef',
#  'brand',
#  ('break', 'bank'),
#  'byproduct',
#  ('calcium', 'carbonate'),
#  'cheap',
#  'chicken',
#  ('choline', 'chloride'),
#  'chunk',
#  ('balanced', 'nutrition'),
#  'corn',
#  'cost',
#  ('different', 'flavor'),
#  ('diversity', 'flavor', 'choose'),
#  'expensive',
#  ('fatty', 'acids'),
#  ('ferrous', 'sulfate'),
#  'fish',
#  'flavor',
#  ('folic', 'acid'),
#  'formula',
#  'fresh',
#  'grain',
#  'gravy',
#  'health',
#  'ingredient',
#  'kibble',
#  ('low', 'carb'),
#  'meat',
#  'money',
#  'natural',
#  ('natural', 'balance'),
#  'nutrition',
#  ('ocean', 'whitefish'),
#  'organic',
#  'pack',
#  ('powdered', 'cellulose'),
#  'prescription',
#  'price',
#  'protein',
#  ('pyridoxine', 'hydrochloride'),
#  'quality',
#  'rice',
#  'salmon',
#  ('save', 'money'),
#  'several',
#  'size',
#  'smell',
#  ('sodium', 'bisulfate'),
#  ('sodium', 'bisulfite'),
#  ('subscribe', 'save'),
#  ('subscribe', 'save', 'option'),
#  ('subscribe', 'save', 'program'),
#  'taste',
#  ('taste', 'wild'),
#  ('thiamine', 'mononitrate'),
#  'tuna',
#  'turkey',
#  'variety',
#  ('variety', 'pack'),
#  'vegetable',
#  'vitamin',
#  ('vitamin', 'b', 'supplement'),
#  ('vitamin', 'e', 'supplement'),
#  ('vitamin', 'nutrient', 'mineral'),
#  ('waste', 'money'),
#  ('zinc', 'oxide'),
#  ('zinc', 'sulfate')]

# %%
from scipy.spatial.distance import pdist
from scipy.spatial import distance
from scipy.cluster.hierarchy import dendrogram, linkage
Z = linkage(np.array(list(vec_features.values())), 'average') #average and complete are good!!!

# %%
fig = plt.figure(figsize=(30, 30))
dn = dendrogram(Z, 
                orientation='right', 
                labels=list(vec_features.keys()),
                #color_threshold = 4,
               leaf_font_size = 18) #cosine distance = 1 - consine similarity
plt.show()

# %% [markdown]
# # sentence2vec - gensim.doc2vec

# %%
sents_df1.head()
# Out:
#                                            Sentence1  \
# 0  I found these on sale and bought them on a whi...
# 1  My kittens were crazy over these, but as they ...
# 2                  My cat absolutely loves spinners!
# 3  these were TINY and made out of very lightweig...
# 4  I bought this cat toy thinking that I would us...
#
#                                            Sentence2  \
# 0                                               None
# 1  Now I have a new year old cat and he plays fet...
# 2  She carries them around in her mouth when she ...
# 3  i gave one to my cat and in under a minute, sh...
# 4  I haven't made my own parakeet toys yet, so I ...
#
#                                            Sentence3  \
# 0                                               None
# 1  HE will chase it and bring it back as long as ...
# 2                           By far her favorite toy!
# 3                                         STAY AWAY.
# 4  Then this evening, on the spur of the moment, ...
#
#                                            Sentence4  \
# 0                                               None
# 1  He carries them around and plays by himself wi...
# 2                                               None
# 3                                               None
# 4  They have been a huge hit - I put them in abou...
#
#                                            Sentence5  \
# 0                                               None
# 1       I have never seen a cat so crazy over a toy.
# 2                                               None
# 3                                               None
# 4  He picks them up, moves them around, drops the...
#
#                                            Sentence6  \
# 0                                               None
# 1  I have ten of them, but can usually only find ...
# 2                                               None
# 3                                               None
# 4                                       What a riot.
#
#                                           Sentence7  \
# 0                                              None
# 1  He always seems to locate one when he wants one.
# 2                                              None
# 3                                              None
# 4                                              None
#
#                                            Sentence8 Sentence9 Sentence10  \
# 0                                               None      None       None
# 1  I think they are a little overpriced for littl...      None       None
# 2                                               None      None       None
# 3                                               None      None       None
# 4                                               None      None       None
#
#    ... Sentence21 Sentence22 Sentence23 Sentence24 Sentence25 Sentence26  \
# 0  ...       None       None       None       None       None       None
# 1  ...       None       None       None       None       None       None
# 2  ...       None       None       None       None       None       None
# 3  ...       None       None       None       None       None       None
# 4  ...       None       None       None       None       None       None
#
#   Sentence27 Sentence28 Sentence29 Sentence30
# 0       None       None       None       None
# 1       None       None       None       None
# 2       None       None       None       None
# 3       None       None       None       None
# 4       None       None       None       None
#
# [5 rows x 30 columns]

# %%
cleaned_sents_df1_lst = [[word for word in sen if word != ' ']for sen in cleaned_sents_df1.values.tolist() ]

# %%
len(cleaned_sents_df1_lst)
# Out:
# 27843

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(cleaned_sents_df1_lst)]
tagged_data
# Out:
# [TaggedDocument(words=['find', 'sale', 'buy', 'whim', 'kitten', 'omg', 'go', 'nuts', 'hardwood', 'spin', 'easily', 'funny', 'kitty', 'carry', 'around', 'mouth', 'drop', 'shoe', 'etc', 'fish', 'furniture', 'constantly', 'retrieve'], tags=[0]),
#  TaggedDocument(words=['kittens', 'crazy', 'grow', 'pay', 'attention'], tags=[1]),
#  TaggedDocument(words=['absolutely', 'love', 'spinner'], tags=[2]),
#  TaggedDocument(words=['tiny', 'make', 'lightweight', 'plastic'], tags=[3]),
#  TaggedDocument(words=['buy', 'think', 'spinner', 'basis', 'hang', 'curious', 'playful', 'parakeet', 'cage'], tags=[4]),
#  TaggedDocument(words=['lil', 'love', 'toy'], tags=[5]),
#  TaggedDocument(words=['definitely', 'favorite'], tags=[6]),
#  TaggedDocument(words=['blu', 'love'], tags=[7]),
#  TaggedDocument(words=['cat', 'thing'], tags=[8]),
#  TaggedDocument(words=['playful', 'use'], tags=[9]),
#  TaggedDocument(words=['meet', 'cat', 'nutritional', 'need'], tags=[10]),
#  TaggedDocument(words=['use', 'science', 'diet', 'year'], tags=[11]),
#  TaggedDocument(words=['use', 'science', 'diet'], tags=[12]),
#  TaggedDocument(words=['good', 'always', 'well'], tags=[13]),
#  TaggedDocument(words=['good', 'market'], tags=[14]),
#  TaggedDocument(words=['title', 'since', 'ask', 'write', 'aboutit', 'take', 'use'], tags=[15]),
#  TaggedDocument(words=['senior', 'get', 'sick', 'eat', 'poor', 'quallity'], tags=[16]),
#  TaggedDocument(words=['use', 'one', 'five', 'year', 'figure', 'puker'], tags=[17]),
#  TaggedDocument(words=['cat', 'complaint', 'piece'], tags=[18]),
#  TaggedDocument(words=['growth', 'health', 'pet', 'come', 'recommend', 'vet'], tags=[19]),
#  TaggedDocument(words=['get', 'kitty', 'one'], tags=[20]),
#  TaggedDocument(words=['cat', 'heathy'], tags=[21]),
#  TaggedDocument(words=['charlie', 'love', 'science', 'diet'], tags=[22]),
#  TaggedDocument(words=['cat'], tags=[23]),
#  TaggedDocument(words=['cat', 'one', 'young', 'one', 'outside'], tags=[24]),
#  TaggedDocument(words=['vet', 'start', 'we', 'year', 'ago', 'work', 'bring', 'house', 'year'], tags=[25]),
#  TaggedDocument(words=['back', 'ship', 'house', 'several', 'time', 'cat', 'never', 'run', 'back', 'wear'], tags=[26]),
#  TaggedDocument(words=['order', 'hill', 'science', 'cat', 'early', 'nugget', 'large', 'hard', 'eati', 'receive', 'email', 'suggest', 'adult', 'optimal', 'care'], tags=[27]),
#  TaggedDocument(words=['science', 'diet', 'year'], tags=[28]),
#  TaggedDocument(words=['cat'], tags=[29]),
#  TaggedDocument(words=['read', 'review', 'see', 'similar', 'one', 'cat', 'this', 'cat', 'thank', 'read', 'almost', 'ad', 'science', 'diet'], tags=[30]),
#  TaggedDocument(words=['vet', 'recommend', 'brand', 'thought', 'cat'], tags=[31]),
#  TaggedDocument(words=['contain', 'low', 'level', 'magnesium', 'supermarket', 'food'], tags=[32]),
#  TaggedDocument(words=[], tags=[33]),
#  TaggedDocument(words=['cat', 'hills', 'science', 'diet', 'since', 'come', 'home', 'kitten'], tags=[34]),
#  TaggedDocument(words=['deliver', 'house'], tags=[35]),
#  TaggedDocument(words=['catsage', 'love', 'anything', 'elseso', 'do', 'not', 'quess', 'might', 'waste', 'money', 'foodtrye', 'themi', 'feed', 'mine', 'since', 'month', 'oldwhen', 'get'], tags=[36]),
#  TaggedDocument(words=['cat', 'eat', 'year'], tags=[37]),
#  TaggedDocument(words=['gracie', 'overweight', 'use', 'foodshe', 'lose', 'weight', 'active'], tags=[38]),
#  TaggedDocument(words=['horrific', 'make', 'junk', 'ingredient'], tags=[39]),
#  TaggedDocument(words=['three', 'four', 'cat', 'become', 'disintereste', 'iam', 'since', 'change', 'formula', 'month', 'ago'], tags=[40]),
#  TaggedDocument(words=['look', 'find', 'low', 'rating', 'feed'], tags=[41]),
#  TaggedDocument(words=['know', 'different', 'food', 'open', 'seem', 'small', 'bit', 'meaty', 'style'], tags=[42]),
#  TaggedDocument(words=['cat'], tags=[43]),
#  TaggedDocument(words=['price', 'well', 'place', 'check', 'ship', 'doorwhat', 'deal'], tags=[44]),
#  TaggedDocument(words=['consist', 'nutrient', 'lucy'], tags=[45]),
#  TaggedDocument(words=['help', 'fat', 'cat', 'lose', 'weight', 'hate'], tags=[46]),
#  TaggedDocument(words=['two', 'cat', 'age', '  ', 'yes'], tags=[47]),
#  TaggedDocument(words=['cat', 'hills', 'science', 'diet'], tags=[48]),
#  TaggedDocument(words=['use', 'hill', 'science', 'diet', 'number', 'year', 'anything', 'else'], tags=[49]),
#  TaggedDocument(words=['science', 'diet', 'perfect', 'baby', 'love', 'healthy'], tags=[50]),
#  TaggedDocument(words=['order', 'thought', 'buy', 'lb'], tags=[51]),
#  TaggedDocument(words=['thrilled', 'go', 'back', 'purina', 'chow', 'young', 'one'], tags=[52]),
#  TaggedDocument(words=[], tags=[53]),
#  TaggedDocument(words=['light', 'two', 'cat'], tags=[54]),
#  TaggedDocument(words=['three', 'cat', 'two', 'dog', 'raise', 'science', 'diet', 'despite', 'fact', 'poor', 'graduate', 'student'], tags=[55]),
#  TaggedDocument(words=['quality'], tags=[56]),
#  TaggedDocument(words=['male', 'literally', 'stinkiest', 'poo', 'world'], tags=[57]),
#  TaggedDocument(words=['cat', 'different', 'background', 'age', 'quite', 'healthy'], tags=[58]),
#  TaggedDocument(words=['get', 'shelter', 'cat'], tags=[59]),
#  TaggedDocument(words=['adope', 'rescue', 'siamese'], tags=[60]),
#  TaggedDocument(words=['quality', 'lot', 'natural', 'oil', 'keep', 'cat', 'shiny', 'healthy'], tags=[61]),
#  TaggedDocument(words=['recieve', 'item', 'damage'], tags=[62]),
#  TaggedDocument(words=['cat', 'take', 'right', 'away'], tags=[63]),
#  TaggedDocument(words=['urinary', 'issue'], tags=[64]),
#  TaggedDocument(words=['far', 'mix', 'hill', 'science', 'catshave', 'eat', 'gradually', 'increase', 'amount', 'hill', 'sciencethe', 'cat', 'eat', 'assume'], tags=[65]),
#  TaggedDocument(words=['quality', 'price'], tags=[66]),
#  TaggedDocument(words=['always', 'find', 'science', 'diet', 'superior', 'pet', 'brand'], tags=[67]),
#  TaggedDocument(words=['item', 'arrive', 'quickly', 'packaging', 'protect', 'item', 'arrive', 'directly', 'door'], tags=[68]),
#  TaggedDocument(words=['sell', 'fair', 'price', 'deliver', 'home', 'hassle'], tags=[69]),
#  TaggedDocument(words=['cat', 'eat', 'science', 'diet', 'year'], tags=[70]),
#  TaggedDocument(words=['get', 'one', 'science', 'diet', 'adopt', 'shelter', 'buy', 'go'], tags=[71]),
#  TaggedDocument(words=['use', 'cat', 'since'], tags=[72]),
#  TaggedDocument(words=['feed', 'cat', 'science', 'diet', 'year', 'wait', 'pop', 'subscribe', 'save'], tags=[73]),
#  TaggedDocument(words=['adopt', 'shelter', 'type', 'fed', 'urge', 'continue', 'feed'], tags=[74]),
#  TaggedDocument(words=['cat'], tags=[75]),
#  TaggedDocument(words=['call', 'kidney', 'stone'], tags=[76]),
#  TaggedDocument(words=['usually', 'gobble', 'soon', 'bowl'], tags=[77]),
#  TaggedDocument(words=['store', 'far', 'away', 'stop', 'buy', 'item'], tags=[78]),
#  TaggedDocument(words=['say'], tags=[79]),
#  TaggedDocument(words=['get', 'ridiculously', 'price'], tags=[80]),
#  TaggedDocument(words=['despite', 'brand', 'incredibly', 'cost', 'assume', 'reputation', 'brand', 'list', 'dozen', 'storebudget', 'brand', 'recall', 'early', 'batch', 'wheat', 'gluten', 'kill', 'pet'], tags=[81]),
#  TaggedDocument(words=['fed', 'cat', 'year', 'deal', 'weight', 'issue', 'read', 'ingredient'], tags=[82]),
#  TaggedDocument(words=['maybe', 'spoil'], tags=[83]),
#  TaggedDocument(words=['cat', 'hill', 'science', 'daily'], tags=[84]),
#  TaggedDocument(words=['come', 'expect'], tags=[85]),
#  TaggedDocument(words=['recommend', 'local', 'animal', 'shelter', 'upon', 'adoption'], tags=[86]),
#  TaggedDocument(words=['although', 'old', 'pet', 'mislead', 'hill', 'reduce', 'weight', 'pound'], tags=[87]),
#  TaggedDocument(words=['cat', 'four', 'enjoy'], tags=[88]),
#  TaggedDocument(words=['male', 'cat', 'range', 'age'], tags=[89]),
#  TaggedDocument(words=['two', 'cat', 'science', 'diet'], tags=[90]),
#  TaggedDocument(words=['question', 'science', 'diet', 'make', 'productit', 'expensive', 'worth', 'extra', 'payprice', 'notice', 'inch', 'upwould'], tags=[91]),
#  TaggedDocument(words=['usually', 'eat', 'indoor', 'mixed', 'hairball', 'control', 'try', 'instead', 'indoor', 'cheap'], tags=[92]),
#  TaggedDocument(words=['except', 'hills', 'diet', 'can'], tags=[93]),
#  TaggedDocument(words=['perfect'], tags=[94]),
#  TaggedDocument(words=['stomach', 'issue', 'fine'], tags=[95]),
#  TaggedDocument(words=['picky', 'gobble'], tags=[96]),
#  TaggedDocument(words=['four', 'cat'], tags=[97]),
#  TaggedDocument(words=['facebook', 'site'], tags=[98]),
#  TaggedDocument(words=['accord', 'consumer', 'complaint', 'hill', 'reformulate', 'science', 'diet', 'make', 'cat', 'sick'], tags=[99]),
#  TaggedDocument(words=['cat', 'sooooo', 'picky'], tags=[100]),
#  TaggedDocument(words=['use', 'prescription', 'diet', 'finally', 'nerve', 'could', 'tolerate'], tags=[101]),
#  TaggedDocument(words=['find', 'two', 'young', 'female', 'cat', 'wonder', 'around', 'neighborhood', 'eventually', 'catch', 'fur', 'rough', 'dirty', 'malnourishment', 'harsh', 'weather'], tags=[102]),
#  TaggedDocument(words=['love', 'foodthis', 'frist', 'use', 'sciece', 'dite'], tags=[103]),
#  TaggedDocument(words=[], tags=[104]),
#  TaggedDocument(words=['parent', 'please', 'research', 'buying'], tags=[105]),
#  TaggedDocument(words=['picky'], tags=[106]),
#  TaggedDocument(words=['cost', 'cat', 'brand', 'take', 'week', 'difference', 'coat', 'weight'], tags=[107]),
#  TaggedDocument(words=['feed', 'exclusively', 'cat', 'year', 'least', 'well'], tags=[108]),
#  TaggedDocument(words=['purchase', 'new', 'chuck', 'keep', 'get', 'diarrhea', 'feed', 'cat'], tags=[109]),
#  TaggedDocument(words=['four', 'cat', 'science', 'diet'], tags=[110]),
#  TaggedDocument(words=['feed', 'science', 'diet', 'original', 'year', 'picky', 'eater', 'refuse', 'anything', 'else'], tags=[111]),
#  TaggedDocument(words=['cat'], tags=[112]),
#  TaggedDocument(words=['save', 'money', 'purchase', 'compare', 'pet', 'specialty', 'store', 'save', 'trip', 'location'], tags=[113]),
#  TaggedDocument(words=['give', 'purchase', 'pet'], tags=[114]),
#  TaggedDocument(words=['try', 'different', 'food'], tags=[115]),
#  TaggedDocument(words=['pretty', 'although', 'order', 'regular', 'senior', 'light', 'show', 'available', 'wish', 'know', 'order', 'good', 'senior'], tags=[116]),
#  TaggedDocument(words=['eat', 'also', 'healthyit', 'also'], tags=[117]),
#  TaggedDocument(words=['cat', 'enjoy', 'believe', 'make', 'fur', 'soft'], tags=[118]),
#  TaggedDocument(words=['three', 'cat', 'feel', 'look', 'well', 'previous', 'purina'], tags=[119]),
#  TaggedDocument(words=['fed', 'year'], tags=[120]),
#  TaggedDocument(words=['cat', 'anything', 'else'], tags=[121]),
#  TaggedDocument(words=['brand', 'well', 'ingredient', 'one', 'particular', 'like', 'well'], tags=[122]),
#  TaggedDocument(words=['adopted', 'take', 'house', 'winter'], tags=[123]),
#  TaggedDocument(words=['fussy', 'ever', 'share', 'home'], tags=[124]),
#  TaggedDocument(words=['go', 'friskie', 'indoor', 'delight', 'seafood', 'flavor', 'kind', 'like', 'regular', 'kind'], tags=[125]),
#  TaggedDocument(words=['store', 'cheap', 'prime', 'beat'], tags=[126]),
#  TaggedDocument(words=['cat', 'fun', 'become', 'soft', 'sleek'], tags=[127]),
#  TaggedDocument(words=['feline'], tags=[128]),
#  TaggedDocument(words=['feed', 'cat', 'past', 'six', 'year'], tags=[129]),
#  TaggedDocument(words=['kitten', 'happily', 'scarf'], tags=[130]),
#  TaggedDocument(words=['cat', 'particularly', 'fond', 'health', 'great', 'issue'], tags=[131]),
#  TaggedDocument(words=['cat', 'favorite'], tags=[132]),
#  TaggedDocument(words=['pet', 'store', 'except', 'spend', 'come', 'door'], tags=[133]),
#  TaggedDocument(words=['get', 'slightly', 'overweight', 'yr', 'borderingon', 'overweight', 'mo'], tags=[134]),
#  TaggedDocument(words=['lose', 'half', 'tooth', 'insist', 'chomp', 'away', 'formula'], tags=[135]),
#  TaggedDocument(words=['love', 'finicky'], tags=[136]),
#  TaggedDocument(words=['amazoncom', 'sale', 'pet'], tags=[137]),
#  TaggedDocument(words=['attest', 'long', 'term', 'affect', 'ie'], tags=[138]),
#  TaggedDocument(words=['kitten', 'taste', 'seem', 'thing', 'fur', 'also', 'possible', 'poop', 'strong', 'smelling', 'though', 'use', 'try', 'one', 'noticeable', 'difference'], tags=[139]),
#  TaggedDocument(words=['amazon', 'cheap', 'local', 'pet', 'store', 'rhyme', 'letgo', 'also', 'show', 'doorstep', 'click', 'debit', 'bank', 'account'], tags=[140]),
#  TaggedDocument(words=['worried', 'suppose'], tags=[141]),
#  TaggedDocument(words=['nine', 'cat', 'crazy', 'kibble'], tags=[142]),
#  TaggedDocument(words=['past', 'offer', 'special', 'diet', 'cat', 'fail', 'kidney'], tags=[143]),
#  TaggedDocument(words=['cat', 'thsi'], tags=[144]),
#  TaggedDocument(words=['upon', 'cartoon', 'post', 'refrigerator', 'depict', 'owner', 'stand', 'feline', 'hand', 'look', 'pet', 'stare', 'skeptically', 'dish'], tags=[145]),
#  TaggedDocument(words=['cat', 'extremely', 'pickymy', 'cat', 'especially', 'sauve', 'chunk', 'lamb', 'also', 'blue', 'lamb'], tags=[146]),
#  TaggedDocument(words=['fur', 'baby', 'max', 'savory', 'duck', 'chunk', 'sauce', 'can'], tags=[147]),
#  TaggedDocument(words=['search', 'healthy', 'cat', 'actually'], tags=[148]),
#  TaggedDocument(words=['cat', 'max', 'nutro', 'chunk', 'sauce', 'usually', 'instead', 'lick', 'gravy', 'leave', 'rest'], tags=[149]),
#  TaggedDocument(words=['like', 'one', 'soso'], tags=[150]),
#  TaggedDocument(words=['cat', 'allergic', 'main', 'store', 'brand', 'brand'], tags=[151]),
#  TaggedDocument(words=['precise', 'put', 'amazing', 'pet'], tags=[152]),
#  TaggedDocument(words=['excellent'], tags=[153]),
#  TaggedDocument(words=['feeding', 'sporkie', 'since'], tags=[154]),
#  TaggedDocument(words=['quality', 'small', 'anticipated', 'fault', 'close', 'weight', 'picture'], tags=[155]),
#  TaggedDocument(words=['girl', 'picky', 'eater', 'usually', 'disregard'], tags=[156]),
#  TaggedDocument(words=['always', 'lookout', 'highquality', 'cat', 'actually'], tags=[157]),
#  TaggedDocument(words=['price', 'ridiculous'], tags=[158]),
#  TaggedDocument(words=['quick', 'painless', 'transaction', 'place', 'purchase', 'wysong'], tags=[159]),
#  TaggedDocument(words=['complaint'], tags=[160]),
#  TaggedDocument(words=['yr', 'seem', 'bored', 'vetsupplied', 'kd'], tags=[161]),
#  TaggedDocument(words=['quality', 'additive', 'always', 'wysong'], tags=[162]),
#  TaggedDocument(words=['serious', 'digestion', 'problem', 'include', 'regular', 'vomiting', 'diarrhea', 'point', 'dehydrate', 'underweight'], tags=[163]),
#  TaggedDocument(words=['week', 'realize', 'container', 'wysong', 'geriatrix', 'empty'], tags=[164]),
#  TaggedDocument(words=['cat', 'quality', 'main', 'staple', 'enjoy', 'share', 'make', 'peaceful', 'life', 'interesting', 'give', 'extra', 'motivation', 'wake', 'morninggourmet', 'seafood', 'favorite', 'flavor', 'other', 'rank', 'gourmet', 'chicken', 'ocean', 'whitefish', 'tuna', 'feastthe', 'flip', 'top', 'make', 'easy', 'sleepy', 'mom', 'serve', 'breakfast', 'smell', 'though', 'fishy'], tags=[165]),
#  TaggedDocument(words=['wonderful', 'wonderful', 'price'], tags=[166]),
#  TaggedDocument(words=['recently', 'give', 'poor', 'review', 'elderly', 'appear', 'reaction', 'pain', 'eat', 'one', 'refuse', 'thereafter'], tags=[167]),
#  TaggedDocument(words=['good', 'favorite'], tags=[168]),
#  TaggedDocument(words=['like'], tags=[169]),
#  TaggedDocument(words=['since', 'available', 'store'], tags=[170]),
#  TaggedDocument(words=['right', 'coolit', 'come', 'can', '  ', 'whole', 'can'], tags=[171]),
#  TaggedDocument(words=['crystal', 'finickiest', 'planet'], tags=[172]),
#  TaggedDocument(words=['like', 'variety'], tags=[173]),
#  TaggedDocument(words=['love', 'poultry', 'ground', 'one'], tags=[174]),
#  TaggedDocument(words=['one', 'slip', 'cat', 'favorite', 'almost', 'picture'], tags=[175]),
#  TaggedDocument(words=['suki', 'love', 'vitamin', 'mineral', 'night', 'give', 'nugget'], tags=[176]),
#  TaggedDocument(words=['one', 'variety', 'quotvarietyquot', 'cat', 'regular', 'like'], tags=[177]),
#  TaggedDocument(words=['finicky'], tags=[178]),
#  TaggedDocument(words=['variety', 'ground', 'thus', 'care', 'variety'], tags=[179]),
#  TaggedDocument(words=['cat', 'third', 'favorite'], tags=[180]),
#  TaggedDocument(words=['favorite', 'house'], tags=[181]),
#  TaggedDocument(words=['one', 'basic'], tags=[182]),
#  TaggedDocument(words=['twice', 'variety', 'enough', 'particular', 'variety'], tags=[183]),
#  TaggedDocument(words=['year', 'care', 'cat', 'entire', 'life'], tags=[184]),
#  TaggedDocument(words=['honestly', 'variety'], tags=[185]),
#  TaggedDocument(words=['course', 'nobody', 'ever', 'figure', 'cat', 'experience', 'opposite', 'onestar', 'reviewour', 'two', 'bengal', 'cat', 'eat', 'kibble', 'year', 'serious', 'tooth', 'problem', 'switch', 'can'], tags=[186]),
#  TaggedDocument(words=['live', 'well', 'job', 'variety', 'friskie'], tags=[187]),
#  TaggedDocument(words=['version', 'ground'], tags=[188]),
#  TaggedDocument(words=['accord'], tags=[189]),
#  TaggedDocument(words=['yet', 'like', 'one'], tags=[190]),
#  TaggedDocument(words=['cat', 'favorite', 'one'], tags=[191]),
#  TaggedDocument(words=['picky'], tags=[192]),
#  TaggedDocument(words=[], tags=[193]),
#  TaggedDocument(words=['flavor', 'decidedly', 'favorite', 'waif'], tags=[194]),
#  TaggedDocument(words=['two', 'cat', 'use', 'formula', 'guess', 'get', 'tired', 'maybe', 'formula', 'change'], tags=[195]),
#  TaggedDocument(words=['purchase', 'ff', 'chunky', 'chicken', 'along', 'chunky', 'turkey', 'two', 'flavor', 'cat'], tags=[196]),
#  TaggedDocument(words=['draw', 'call', 'somewhat'], tags=[197]),
#  TaggedDocument(words=['variety', 'pack', 'contain', 'twentyfour', 'can', 'always', 'ensure', 'supply', 'hand'], tags=[198]),
#  TaggedDocument(words=['love', 'variety', 'pack', 'particular', 'make', 'mealtime', 'veritable', 'newsworthy', 'event'], tags=[199]),
#  TaggedDocument(words=['around', 'quotspecial', 'treatquot', 'introduce', 'regular', 'daily', 'diet', 'may', 'wind', 'poor', 'house'], tags=[200]),
#  TaggedDocument(words=['pack', 'sams', 'club', 'dollar'], tags=[201]),
#  TaggedDocument(words=['variety', 'pack', 'contain', 'twentyfour', 'can', 'always', 'ensure', 'supply', 'hand'], tags=[202]),
#  TaggedDocument(words=['innova', 'evo', 'lb', 'bagnot'], tags=[203]),
#  TaggedDocument(words=['love', 'variety', 'pack', 'particular', 'make', 'mealtime', 'veritable', 'newsworthy', 'event'], tags=[204]),
#  TaggedDocument(words=['fast', 'delivery', 'price'], tags=[205]),
#  TaggedDocument(words=['receive', 'quickly', 'price'], tags=[206]),
#  TaggedDocument(words=['yr', 'siamese', 'random', 'always', 'stomach', 'issue'], tags=[207]),
#  TaggedDocument(words=['want', 'could', 'inside', 'cat', 'feral', 'cat'], tags=[208]),
#  TaggedDocument(words=['recommend', 'animal', 'rescue', 'foundation', 'luna', 'adopt'], tags=[209]),
#  TaggedDocument(words=['probably', 'buy', 'sedentary', 'type', 'indoor', 'girl'], tags=[210]),
#  TaggedDocument(words=['indoor', 'always', 'shed', 'almost', 'stop', 'process'], tags=[211]),
#  TaggedDocument(words=['taste', 'love'], tags=[212]),
#  TaggedDocument(words=['brand'], tags=[213]),
#  TaggedDocument(words=['always', 'love', 'can', 'excellent', 'price', 'size'], tags=[214]),
#  TaggedDocument(words=['purchase', 'beef', 'chicken', 'turkey', 'salmon', 'recipe', 'via', 'subscribe', 'save', 'two', 'time', 'arrive', 'home', 'cancel', 'can', 'dent', 'package', 'time'], tags=[215]),
#  TaggedDocument(words=['cat', 'buy', 'look', 'close', 'ingredient', 'notice', 'carrageenan'], tags=[216]),
#  TaggedDocument(words=['two', 'cat'], tags=[217]),
#  TaggedDocument(words=['stay', 'away', 'preparation', 'carb', 'thus', 'brand', 'loyalty', 'wellness', 'thrill', 'amazon', 'sell', 'load', 'cheap', 'local', 'pet', 'store'], tags=[218]),
#  TaggedDocument(words=['cat', 'ship', 'quick', 'cat', 'enjoy'], tags=[219]),
#  TaggedDocument(words=['grain'], tags=[220]),
#  TaggedDocument(words=['miss', 'midnight', 'like', 'variety', 'can', 'shipment', 'dentsive', 'pleased', 'brand'], tags=[221]),
#  TaggedDocument(words=['awful', 'car', 'stomach', 'issue', 'keep', 'vomit', 'week', 'batch', 'order'], tags=[222]),
#  TaggedDocument(words=['one', 'scoop', 'together'], tags=[223]),
#  TaggedDocument(words=['watch', 'enjoy', 'fuss'], tags=[224]),
#  TaggedDocument(words=['packaging', 'could'], tags=[225]),
#  TaggedDocument(words=['refuse', 'even', 'go', 'hour', 'foodmy', 'thought', 'persnickety', 'refuse', 'hour', 'know', 'hate', 'itgave', 'away', 'shelter'], tags=[226]),
#  TaggedDocument(words=['wish', 'brand', 'offer', 'sample', 'sale', 'even', 'beforebuye', 'can'], tags=[227]),
#  TaggedDocument(words=['spoil', 'cat', 'switch', 'wellness', 'brand', 'contributing', 'problem'], tags=[228]),
#  TaggedDocument(words=['search', 'cat'], tags=[229]),
#  TaggedDocument(words=['recently', 'order', 'three', 'different', 'wellness', 'can', 'variety'], tags=[230]),
#  TaggedDocument(words=['ten', 'cat', 'five', 'foster', 'plus', 'outside', 'feral', 'cat', 'importantly', 'fish', 'four', 'cat', 'uti', 'problem'], tags=[231]),
#  TaggedDocument(words=['two', 'large', 'cat'], tags=[232]),
#  TaggedDocument(words=['wellness', 'formula', 'like'], tags=[233]),
#  TaggedDocument(words=['ingredient', 'well', 'content', 'level', 'analysis', 'corei', 'feel', 'confident', 'good', 'choice', 'family'], tags=[234]),
#  TaggedDocument(words=['buy', 'love'], tags=[235]),
#  TaggedDocument(words=['spendy', 'grain', 'diet', 'improve', 'cat', 'gi', 'issue', 'immensely'], tags=[236]),
#  TaggedDocument(words=['elderly', 'wellness', 'can'], tags=[237]),
#  TaggedDocument(words=['switch', 'brand', 'cat', 'lose', 'lot', 'weight', 'fat', 'lively', 'young'], tags=[238]),
#  TaggedDocument(words=['two', 'senior', 'cat', 'lick', 'bowl', 'clean', 'unlike', 'premium', 'can', 'food'], tags=[239]),
#  TaggedDocument(words=['six', 'feline', 'companion', 'large', 'can', 'offer', 'economy', 'allow', 'we', 'afford', 'good', 'grain', 'food', 'family'], tags=[240]),
#  TaggedDocument(words=['since', 'start', 'primalpaleo', 'lifestyle', 'month', 'ago', 'start', 'use', 'brand', 'can'], tags=[241]),
#  TaggedDocument(words=['adopt', 'local', 'shelter', 'two', 'month', 'ago', 'get', 'home', 'extreme', 'diarrhea'], tags=[242]),
#  TaggedDocument(words=['cat', 'refuse', 'finicky'], tags=[243]),
#  TaggedDocument(words=['age', 'active', 'since', 'make', 'switch', 'wellness', 'beef', 'chicken'], tags=[244]),
#  TaggedDocument(words=['order', 'wellness', 'one', 'cat', 'diagnose', 'insulindependent', 'diabetic', 'month', 'ago'], tags=[245]),
#  TaggedDocument(words=['love', 'particularly', 'flavorit', 'pricey', 'compare', 'brand'], tags=[246]),
#  TaggedDocument(words=['none', 'kitty'], tags=[247]),
#  TaggedDocument(words=['still', 'progress', 'try', 'experiment', 'different', 'brand', 'flavor', 'grain'], tags=[248]),
#  TaggedDocument(words=['cat', 'buy', 'large', 'can', 'well', 'value', 'go', 'individual', 'size'], tags=[249]),
#  TaggedDocument(words=['adopt', 'two', 'testing', 'different', 'food'], tags=[250]),
#  TaggedDocument(words=['three', 'cat', 'can', 'family'], tags=[251]),
#  TaggedDocument(words=['order', 'brand', 'size', 'half', 'can', 'package', 'severely', 'dent'], tags=[252]),
#  TaggedDocument(words=['actually', 'meet', 'expectation', 'butunfortunately', 'cat', 'finicky'], tags=[253]),
#  TaggedDocument(words=['cat', 'run', 'bowl', 'treat', 'flavor', 'wellness'], tags=[254]),
#  TaggedDocument(words=['wrong'], tags=[255]),
#  TaggedDocument(words=['love', 'beef', 'chicken', 'flavor', 'wellness'], tags=[256]),
#  TaggedDocument(words=['decide', 'recently', 'switch', 'cat', 'grain'], tags=[257]),
#  TaggedDocument(words=['can', 'choice', 'cat', 'kitten'], tags=[258]),
#  TaggedDocument(words=['wellness', 'brand', 'pet', 'food', 'treat'], tags=[259]),
#  TaggedDocument(words=['switch', 'diet', 'wellness', 'diet', 'develop', 'kidney', 'failure'], tags=[260]),
#  TaggedDocument(words=['vet', 'say', 'cat', 'meat', 'cat', 'carnivore', 'unless', 'tiny', 'treat'], tags=[261]),
#  TaggedDocument(words=['cat', 'pretty', 'prefer', 'white', 'lining'], tags=[262]),
#  TaggedDocument(words=['hope', 'could', 'convince', 'cat', 'wellness', 'brand', 'even', 'week', 'try', 'transition'], tags=[263]),
#  TaggedDocument(words=['cat', 'grain', 'decide', 'add', 'wholesome', 'grain', 'can', 'wellness', 'say', 'excellent', 'doubt', 'cat', 'past', 'slop', 'come', 'want', 'quality', 'finally', 'get', 'quality', 'unfortunately', 'turn', 'nose', 'wellness', 'beef', 'chicken', 'grain', 'can', 'even', 'try', 'variety', 'flavor', 'dice', 'even', 'lap', 'juice', 'bowl'], tags=[264]),
#  TaggedDocument(words=['catkins', 'diet', 'healthy'], tags=[265]),
#  TaggedDocument(words=['past', 'week', 'transition'], tags=[266]),
#  TaggedDocument(words=['cat', 'meow', 'breakfast', 'morning'], tags=[267]),
#  TaggedDocument(words=['stick', 'well', 'part'], tags=[268]),
#  TaggedDocument(words=['one', 'healthy', 'brand', 'market'], tags=[269]),
#  TaggedDocument(words=['believe', 'pet'], tags=[270]),
#  TaggedDocument(words=['try', 'get', 'crystal', 'bladder'], tags=[271]),
#  TaggedDocument(words=['buy'], tags=[272]),
#  TaggedDocument(words=['cat', 'meet', 'healthy', 'criterion', 'look'], tags=[273]),
#  TaggedDocument(words=['cat'], tags=[274]),
#  TaggedDocument(words=['pleased', 'wellness'], tags=[275]),
#  TaggedDocument(words=['can', 'dent', 'make', 'hard', 'seem', 'dry'], tags=[276]),
#  TaggedDocument(words=['love', 'brand', 'can'], tags=[277]),
#  TaggedDocument(words=['cat'], tags=[278]),
#  TaggedDocument(words=['cat', 'absolutely', 'ingredient', 'greati', 'receive', 'shipment', 'four', 'case', 'various', 'wellness', 'core', 'food', 'may', 'th', 'include', 'item', 'ship', 'sell', 'amazoncom'], tags=[279]),
#  TaggedDocument(words=['order', 'easy'], tags=[280]),
#  TaggedDocument(words=['although', 'wellness', 'use', 'natural', 'material', 'animal', 'byproduct', 'reason', 'beef', 'chicken', 'reipe', 'foul', 'smell', 'sea'], tags=[281]),
#  TaggedDocument(words=['like', 'vet', 'tell', 'nutritious'], tags=[282]),
#  TaggedDocument(words=['cat', 'care', 'beefchicken', 'turkey', 'chicken', 'flavor'], tags=[283]),
#  TaggedDocument(words=['pricey', 'worth'], tags=[284]),
#  TaggedDocument(words=['cheap', 'consider', 'ingredient', 'meat'], tags=[285]),
#  TaggedDocument(words=['picky'], tags=[286]),
#  TaggedDocument(words=[], tags=[287]),
#  TaggedDocument(words=['receive', 'order', 'advertise', 'everything', 'excellent', 'conditionmy', 'mandy', 'year', 'excellent', 'health', 'thank', 'wellness', 'grain', 'food'], tags=[288]),
#  TaggedDocument(words=['cat', 'healthy'], tags=[289]),
#  TaggedDocument(words=['two', 'cat', 'diagnose', 'diabetes', 'hate', 'grain', 'essential', 'bring', 'sugar'], tags=[290]),
#  TaggedDocument(words=['three', 'cat', 'seem'], tags=[291]),
#  TaggedDocument(words=['yo', 'love', 'finicky'], tags=[292]),
#  TaggedDocument(words=['two', 'cat', 'year', 'sensitivity', 'lot', 'can'], tags=[293]),
#  TaggedDocument(words=['two', 'male', 'cat', 'normally', 'one', 'reoccurre', 'ut', 'problem'], tags=[294]),
#  TaggedDocument(words=['yearold', 'overweight', 'tabby', 'friday', 'urinary', 'tract', 'weight', 'problem', 'since'], tags=[295]),
#  TaggedDocument(words=[], tags=[296]),
#  TaggedDocument(words=['discover', 'friskie', 'special', 'diet', 'cracker', 'disappear', 'store'], tags=[297]),
#  TaggedDocument(words=['recurrent', 'urinary', 'stone', 'love', 'difficult', 'obtain'], tags=[298]),
#  TaggedDocument(words=['reason', 'give', 'star', 'instead', 'star', 'strange', 'design', 'substantial', 'amount', 'stick', 'inside', 'crevice', 'top', 'lip', 'long', 'empty', 'baby', 'spatula', 'scrape', 'offthat', 'say', 'cee', 'cee', 'devour'], tags=[299]),
#  TaggedDocument(words=['poor', 'review', 'kitten', 'figure', 'cat', 'might', 'flavor'], tags=[300]),
#  TaggedDocument(words=['furry', 'houshold', 'member', 'keen'], tags=[301]),
#  TaggedDocument(words=['different', 'throwing', 'review', 'counteract', 'negative', 'review'], tags=[302]),
#  TaggedDocument(words=['hate'], tags=[303]),
#  TaggedDocument(words=['tell', 'cat', 'diet', 'low', 'body', 'mass', 'panic', 'picky'], tags=[304]),
#  TaggedDocument(words=['try', 'manufacturer'], tags=[305]),
#  TaggedDocument(words=['ingredient', 'fresh', 'chicken', 'pet', 'food', 'saythe', 'piece', 'get', 'small', 'since', 'start', 'buy', 'four', 'year', 'ago', 'well', 'tiny', 'catsanimal'], tags=[306]),
#  TaggedDocument(words=['adopt', 'issue', 'digestive', 'system'], tags=[307]),
#  TaggedDocument(words=['buy', 'can', 'fish', 'chicken', 'liver', 'since', 'previous'], tags=[308]),
#  TaggedDocument(words=['real', 'relief'], tags=[309]),
#  TaggedDocument(words=['asinbpu', 'petguard', 'fish', 'chicken', 'liver', 'dinner', 'cat', 'oz', 'cansive', 'feeding', 'cat', 'petguard', 'year', 'quality', 'ingredient'], tags=[310]),
#  TaggedDocument(words=['lot', 'cat', 'greatly', 'appreciate', 'quantity', 'sell', 'cat', 'enjoy'], tags=[311]),
#  TaggedDocument(words=['price', 'size', 'right', 'donate', 'humane', 'society'], tags=[312]),
#  TaggedDocument(words=['cat'], tags=[313]),
#  TaggedDocument(words=['deal'], tags=[314]),
#  TaggedDocument(words=['cheap'], tags=[315]),
#  TaggedDocument(words=['donation', 'item', 'animal', 'rescue'], tags=[316]),
#  TaggedDocument(words=['strays', 'kibble', 'can', 'not', 'continue', 'purchase'], tags=[317]),
#  TaggedDocument(words=['cat'], tags=[318]),
#  TaggedDocument(words=['thing', 'cat', 'adore'], tags=[319]),
#  TaggedDocument(words=['gift', 'feline', 'sanctuary', 'gratefully', 'receive'], tags=[320]),
#  TaggedDocument(words=['money', 'issue', 'review', 'buy'], tags=[321]),
#  TaggedDocument(words=['mother', 'several', 'feral', 'cat', 'around', 'ask', 'order', 'get', 'decent', 'review', 'money'], tags=[322]),
#  TaggedDocument(words=['buy', 'provide', 'local', 'feral', 'colony'], tags=[323]),
#  TaggedDocument(words=['brand', 'cat', 'coat', 'smooth', 'silky', 'stomack', 'problem', 'actually', 'finish', 'what', 's', 'front'], tags=[324]),
#  TaggedDocument(words=['start', 'eat', 'since', 'oneappear', 'gourmet', 'say', 'baglook', 'fresh', 'size'], tags=[325]),
#  TaggedDocument(words=['cat', 'pricier', 'extend', 'itand', 'cat', 'blend', 'different', 'kibble'], tags=[326]),
#  TaggedDocument(words=['like', 'price', 'large', 'low', 'enough', 'allow', 'committ', 'buy', 'additional', 'bag', 'local', 'anumal', 'shelter'], tags=[327]),
#  TaggedDocument(words=['try', 'month', 'starve'], tags=[328]),
#  TaggedDocument(words=['bring', 'attention', 'friend', 'own', 'local', 'pet', 'store', 'three', 'cat', 'problem', 'weight', 'gain', 'shed', 'inability', 'hold', 'undoubtedly', 'result', 'diet', 'meow'], tags=[329]),
#  TaggedDocument(words=['live', 'one', 'meal', 'cat', 'enjoy', 'eat'], tags=[330]),
#  TaggedDocument(words=['strange', 'compare', 'folk', 'cat'], tags=[331]),
#  TaggedDocument(words=['cat', 'different', 'rating', 'redundant'], tags=[332]),
#  TaggedDocument(words=['six', 'mental', 'patient', 'cat', 'hard', 'wellness', 'salmon'], tags=[333]),
#  TaggedDocument(words=['buy', 'breeder', 'buy', 'say', 'anything', 'else'], tags=[334]),
#  TaggedDocument(words=['three', 'cat'], tags=[335]),
#  TaggedDocument(words=['always', 'bulk'], tags=[336]),
#  TaggedDocument(words=['friend', 'mine', 'old', 'active', 'trouble', 'get', 'around', 'start', 'wellness', 'strict', 'diethe', 'love', 'welltab', 'acive', 'everafter', 'introduce', 'productsim', 'hookedmy', 'love', 'look', 'forward', 'welltab', 'morningwe', 'consider', 'lucky', 'part', 'family', 'provide', 'good', 'nutrition', 'availablei', 'believe', 'leap', 'bound', 'anything', 'else', 'find'], tags=[337]),
#  TaggedDocument(words=['cat', 'adore'], tags=[338]),
#  TaggedDocument(words=['start', 'buy', 'promote', 'urinary', 'tract', 'health', 'one', 'kitty', 'prone', 'urinary', 'tract', 'infection'], tags=[339]),
#  TaggedDocument(words=['stop', 'eat'], tags=[340]),
#  TaggedDocument(words=['smell', 'fine', 'love'], tags=[341]),
#  TaggedDocument(words=['five', 'cat'], tags=[342]),
#  TaggedDocument(words=['cat', 'iam', 'year', 'recently', 'notice', 'inconsistency', 'vary', 'moisture', 'content', 'texture', 'smell', 'switch', 'natural', 'balance'], tags=[343]),
#  TaggedDocument(words=['adopt', 'rescue', 'shelter', 'underweight', 'vomiting', 'smelly', 'diarrhea'], tags=[344]),
#  TaggedDocument(words=['two', 'month', 'ago', 'yearold', 'begin', 'vomit', 'meal'], tags=[345]),
#  TaggedDocument(words=['vacation', 'long', 'ever', 'spend', 'away'], tags=[346]),
#  TaggedDocument(words=['cat', 'anymore', 'feed'], tags=[347]),
#  TaggedDocument(words=['get', 'two', 'cat'], tags=[348]),
#  TaggedDocument(words=['picky', 'eater'], tags=[349]),
#  TaggedDocument(words=['hate', 'fan', 'van', 'pattens', 'year', 'feel', 'must', 'save', 'money'], tags=[350]),
#  TaggedDocument(words=['eat', 'life'], tags=[351]),
#  TaggedDocument(words=['never', 'purchase', 'brand'], tags=[352]),
#  TaggedDocument(words=['gobble', 'switch', 'diet'], tags=[353]),
#  TaggedDocument(words=['quality', 'one', 'cat', 'health', 'problem', 'need'], tags=[354]),
#  TaggedDocument(words=['adopt', 'shelter', 'seem', 'underweight'], tags=[355]),
#  TaggedDocument(words=['buy', 'two', 'pack', 'salmon', 'ultra'], tags=[356]),
#  TaggedDocument(words=['although', 'place', 'review', 'ultra', 'formula', 'review', 'pertain', 'nb', 'can', 'flavor', 'cat', 'try', 'thus', 'far'], tags=[357]),
#  TaggedDocument(words=['purchase', 'ultra', 'formula', 'base', 'upon', 'positive', 'review'], tags=[358]),
#  TaggedDocument(words=['try', 'premium', 'food', 'particularly', 'iam', 'nutro', 'natural', 'choice', 'brand', 'affect', 'menu', 'food', 'recall'], tags=[359]),
#  TaggedDocument(words=['fed', 'week', 'nb', 'ever', 'since', 'wean'], tags=[360]),
#  TaggedDocument(words=['simply', 'seem', 'few', 'issue'], tags=[361]),
#  TaggedDocument(words=['ill', 'begin', 'say', 'cat', 'voracious', 'appetite'], tags=[362]),
#  TaggedDocument(words=['start', 'research', 'could', 'soon', 'ween', 'formula'], tags=[363]),
#  TaggedDocument(words=[], tags=[364]),
#  TaggedDocument(words=[], tags=[365]),
#  TaggedDocument(words=['cat', 'general', 'purina', 'catfood'], tags=[366]),
#  TaggedDocument(words=['review', 'since', 'human', 'self', 'actually'], tags=[367]),
#  TaggedDocument(words=['one', 'cat', 'bloody', 'stool', 'diarrhea', 'entire', 'life', 'one', 'half', 'year'], tags=[368]),
#  TaggedDocument(words=['cat', 'eat', 'brand', 'year'], tags=[369]),
#  TaggedDocument(words=['buy', 'hope', 'cheap', 'alternative', 'rx', 'vet', 'give'], tags=[370]),
#  TaggedDocument(words=['cat', 'seem', 'stop', 'urinary', 'tract', 'infection', 'say', 'seem'], tags=[371]),
#  TaggedDocument(words=['cat', 'eat', 'us', 'house', 'home', 'get', 'large', 'belly', 'show'], tags=[372]),
#  TaggedDocument(words=['seem', 'far', 'cat', 'drink', 'water'], tags=[373]),
#  TaggedDocument(words=['two', 'cat', 'always', 'feed', 'diet', 'stay', 'healthy', 'choose', 'without', 'filler', 'meal', 'meal', 'product'], tags=[374]),
#  TaggedDocument(words=['cat', 'subscribe', 'save', 'autodelivery'], tags=[375]),
#  TaggedDocument(words=['urinary', 'tract'], tags=[376]),
#  TaggedDocument(words=['feed', 'kitty', 'premium', 'live', 'one', 'experience', 'two', 'urinary', 'blockage', 'despite', 'foodkitty', 'stable', 'royal', 'canin', 'urinary', 'dietroyal', 'canin', 'veterinary', 'diet', 'feline', 'urinary', 'moderate', 'calorie', 'lb', 'bagbut', 'find', 'price', 'increase', 'ingredient', 'list', 'nothing', 'feed', 'past'], tags=[377]),
#  TaggedDocument(words=['cat', 'touch', 'formula'], tags=[378]),
#  TaggedDocument(words=['use', 'cat', 'switch'], tags=[379]),
#  TaggedDocument(words=['two', 'coupon', 'use', 'clean', 'vomit', 'everyday', 'figure', 'purina', 'pro', 'plan', 'cause'], tags=[380]),
#  TaggedDocument(words=['always', 'arrive', 'never', 'issue'], tags=[381]),
#  TaggedDocument(words=['young', 'neuter', 'male', 'suffer', 'sudden', 'complete', 'urinary', 'blockage', 'two', 'year', 'ago', 'struvite', 'crystal', 'formation', 'spend', 'almost', 'week', 'hospital', 'catheter', 'insert', 'frequent', 'bladder', 'flush'], tags=[382]),
#  TaggedDocument(words=['cat', 'tend', 'whatever', 'give'], tags=[383]),
#  TaggedDocument(words=['female', 'uti', 'vet', 'order', 'vetonly', 'supply', 'uti', 'price'], tags=[384]),
#  TaggedDocument(words=['purchase', 'bag', 'weight', 'management', 'four', 'lazy', 'fat', 'catsand', 'cup', 'bowl', 'leave', 'couple', 'hoursthis', 'devour'], tags=[385]),
#  TaggedDocument(words=['excellent', 'proplan', 'work'], tags=[386]),
#  TaggedDocument(words=['never', 'leave', 'review', 'think', 'share', 'result', 'other', 'issue'], tags=[387]),
#  TaggedDocument(words=['healthy'], tags=[388]),
#  TaggedDocument(words=['purchase', 'purina', 'pro', 'plan', 'sensitive', 'skin', 'stomach', 'formula', 'two', 'five', 'cat', 'skin', 'tail'], tags=[389]),
#  TaggedDocument(words=['get', 'eat', 'couple', 'day', 'start', 'turn', 'nose', 'give', 'icky', 'stuff', 'face', 'back', 'blue', 'buffalo', 'feeding', 'boy', 'kitties', 'house'], tags=[390]),
#  TaggedDocument(words=['state', 'review', 'always', 'cat', 'proplan'], tags=[391]),
#  TaggedDocument(words=['everything', 'exactly', 'describe'], tags=[392]),
#  TaggedDocument(words=['purchase', 'overweight'], tags=[393]),
#  TaggedDocument(words=['purina', 'one', 'different'], tags=[394]),
#  TaggedDocument(words=['pleased', 'ingrediant', 'however', 'would', 'not', 'one', 'bite'], tags=[395]),
#  TaggedDocument(words=['pound', 'eat', 'cup', 'sometimes', 'somehow', 'manage', 'weight', 'constant'], tags=[396]),
#  TaggedDocument(words=['seem', 'hill', 'prescription', 'diet', 'brand', 'urinary', 'tract', 'reduce', 'cost'], tags=[397]),
#  TaggedDocument(words=['please', 'read', 'main', 'ingredient', 'buy'], tags=[398]),
#  TaggedDocument(words=['help', 'sensitive', 'stomach', 'allergy', 'etc'], tags=[399]),
#  TaggedDocument(words=['cat', 'none', 'like'], tags=[400]),
#  TaggedDocument(words=['due', 'cat', 'south', 'africa', 'two', 'month', 'transport', 'venezuela'], tags=[401]),
#  TaggedDocument(words=['do', 'not', 'care', 'vet', 'say', 'heshe', 'also', 'nothing', 'side', 'affect', 'give', 'pet', 'shot', 'whenever', 'ask', 'question', 'minute', 'answer', 'busy', 'second', 'worth', 'utis', 'be', 'not', 'cause', 'ingredient', 'cat', 'water', 'water', 'bowl', 'cat', 'wild', 'water', 'meat', 'do', 'not', 'drink', 'cause', 'stress', 'organ', 'especially', 'bladder', 'kidney', 'cut', 'raw', 'chicken', 'breast', 'day', 'also', 'must', 'grain', 'fully', 'stop', 'organ', 'body', 'problem', 'infection', 'pain', 'joint', 'anything', 'even', 'shed', 'yes', 'shed', 'control', 'afford', 'yet', 'live', 'survive', 'vet', 'hour', 'nutrition', 'class', 'provide', 'science', 'diet', 'do', 'not', 'ask', 'brand', 'research', 'even', 'newman', 'own', 'i', 'd', 'evolve', 'name', 'local', 'store', 'brand'], tags=[402]),
#  TaggedDocument(words=['problem', 'urinary', 'tract', 'infection'], tags=[403]),
#  TaggedDocument(words=['cat', 'expensive'], tags=[404]),
#  TaggedDocument(words=['cat', 'spoil', 'try', 'lot', 'brand', 'take', 'right'], tags=[405]),
#  TaggedDocument(words=['litter', 'kiittie', 'purrfect', 'pal'], tags=[406]),
#  TaggedDocument(words=['cat'], tags=[407]),
#  TaggedDocument(words=['urinary', 'health', 'food', 'lack', 'kind', 'appeal', 'cat', 'brandflavor', 'suppose', 'eat', 'cat', 'itbut', 'different'], tags=[408]),
#  TaggedDocument(words=['cat', 'make', 'thirsty', 'point', 'drink', 'water', 'prevent', 'stone'], tags=[409]),
#  TaggedDocument(words=['male', 'tabby', 'female', 'tuxedo'], tags=[410]),
#  TaggedDocument(words=[], tags=[411]),
#  TaggedDocument(words=['adult', 'foodseem', 'nutritious', 'weight', 'management'], tags=[412]),
#  TaggedDocument(words=['cat', 'eat', 'reluctance'], tags=[413]),
#  TaggedDocument(words=['use', 'automatic', 'feeder', 'instead', 'overprice', 'science', 'diet', 'cd', 'vet'], tags=[414]),
#  TaggedDocument(words=['member', 'prime', 'receive', 'two', 'day', 'brand', 'get', 'vet', 'except'], tags=[415]),
#  TaggedDocument(words=['two', 'cat', 'two', 'dog', 'generally', 'pro', 'plan', 'brand', 'food', 'love'], tags=[416]),
#  TaggedDocument(words=['one', 'food', 'feline', 'urinary', 'syndrome'], tags=[417]),
#  TaggedDocument(words=['develop', 'ut', 'crystal', 'tell'], tags=[418]),
#  TaggedDocument(words=['eat', 'can', 'version', 'know', 'may', 'prevent', 'urinary', 'tract', 'problem', 'worth', 'extra', 'cost'], tags=[419]),
#  TaggedDocument(words=['mark', 'I', 'it'], tags=[420]),
#  TaggedDocument(words=['order', 'picture', 'send', 'different'], tags=[421]),
#  TaggedDocument(words=['one', 'cat', 'issue', 'utis'], tags=[422]),
#  TaggedDocument(words=['believe', 'finally', 'find', 'cat'], tags=[423]),
#  TaggedDocument(words=['vet', 'prescribe', 'royal', 'canin', 'urinary', 'formula', 'male', 'crazy', 'expensive'], tags=[424]),
#  TaggedDocument(words=['largefat', 'male', 'short', 'haired', 'use', 'frequent', 'stone', 'utis'], tags=[425]),
#  TaggedDocument(words=['neuter', 'male', 'phatboy', 'cuddlecuss', 'problem', 'uti', 'crystal', 'formation'], tags=[426]),
#  TaggedDocument(words=['urinary', 'obstruction', 'blockage', 'ago'], tags=[427]),
#  TaggedDocument(words=['nine', 'cat', 'strays', 'neighborhoodtwo', 'cat', 'develop', 'fus', 'switch', 'expensive', 'know', 'nonprescription', 'alternative', 'halfprice'], tags=[428]),
#  TaggedDocument(words=['ragdoll', 'tend', 'utii', 'want', 'formula', 'quality', 'specifically', 'formulate', 'health', 'issuesthis', 'vet', 'techanimal', 'nutritionist', 'certificate', 'read', 'medium', 'move', 'toward', 'quality', 'foodbut', 'large', 'decent', 'price', 'qualityhealthy', 'ingredientsthis', 'close', 'could', 'afford'], tags=[429]),
#  TaggedDocument(words=['cat', 'neighbor', 'slink', 'swip', 'outside', 'feral', 'tomcat'], tags=[430]),
#  TaggedDocument(words=['seven', 'cat', 'seven', 'daily', 'access', 'purina', 'pro', 'plan', 'urinary', 'tract', 'health', 'two', 'year'], tags=[431]),
#  TaggedDocument(words=['switch', 'urinary', 'tract', 'formula', 'find', 'purina', 'proplan'], tags=[432]),
#  TaggedDocument(words=['two', 'male', 'cat', 'one', 'recently', 'utivet', 'prescripte', 'expensive', 'brand', 'require', 'prescription', 'reorderthis', 'replacement', 'one', 'surprisingly', 'cat', 'healthy', 'nowvery'], tags=[433]),
#  TaggedDocument(words=['make', 'mistake', 'buying', 'month', 'ago', 'local', 'pet', 'store', 'sale'], tags=[434]),
#  TaggedDocument(words=['stomach', 'issue', 'food', 'one', 'upset', 'stomach'], tags=[435]),
#  TaggedDocument(words=['use', 'recipe', 'five', 'year', 'five', 'different', 'cat', 'excellent', 'healthfirst', 'foremost'], tags=[436]),
#  TaggedDocument(words=['ver', 'sensitive', 'stomach', 'agree', 'love'], tags=[437]),
#  TaggedDocument(words=['skin', 'allergy', 'different', 'food'], tags=[438]),
#  TaggedDocument(words=['switch', 'one', 'blue', 'buffalo', 'switch', 'small', 'size', 'kibble'], tags=[439]),
#  TaggedDocument(words=['search', 'search', 'right', 'special', 'need', 'hope', 'one', 'although', 'skin', 'stomach', 'problem', 'worse', 'well', 'either'], tags=[440]),
#  TaggedDocument(words=['buy', 'skin', 'issue', 'allergic', 'reaction', 'flea', 'medicine'], tags=[441]),
#  TaggedDocument(words=['proscheapcat', 'love', 'itconshis', 'skin', 'get', 'worsehis', 'vomiting', 'get', 'worsehe', 'develop', 'allergic', 'rashkitty', 'love', 'affordable', 'know', 'sensitive', 'stomach', 'skin', 'eager'], tags=[442]),
#  TaggedDocument(words=['cat', 'brand'], tags=[443]),
#  TaggedDocument(words=['seem', 'recipe', 'eat', 'use'], tags=[444]),
#  TaggedDocument(words=['chicken', 'maybe', 'lamb'], tags=[445]),
#  TaggedDocument(words=['always', 'hairball', 'problem', 'help', 'love'], tags=[446]),
#  TaggedDocument(words=['male', 'manx', 'serious', 'problem', 'prolapse', 'colon', 'month'], tags=[447]),
#  TaggedDocument(words=['cat', 'anything'], tags=[448]),
#  TaggedDocument(words=['yearold', 'persian', 'think', 'pretty'], tags=[449]),
#  TaggedDocument(words=['cat'], tags=[450]),
#  TaggedDocument(words=['issue', 'switch', 'resolve', 'vet', 'want', 'prescription', 'along', 'expensive', 'probiotic', 'medication'], tags=[451]),
#  TaggedDocument(words=['get', 'stomach', 'issue', 'ever', 'since', 'still', 'throw', 'reduce', 'quite'], tags=[452]),
#  TaggedDocument(words=['previous', 'user', 'quality', 'help', 'weight'], tags=[453]),
#  TaggedDocument(words=['buy', 'one', 'cat', 'need', 'lose', 'weight'], tags=[454]),
#  TaggedDocument(words=['cat', 'sensitive', 'stomach'], tags=[455]),
#  TaggedDocument(words=['jake', 'cat', 'vet', 'purina', 'except', 'pro', 'plan', 'line'], tags=[456]),
#  TaggedDocument(words=['start', 'sport', 'mohawk', 'shortly', 'adopt', 'chew', 'fur', 'could', 'reach', 'body'], tags=[457]),
#  TaggedDocument(words=['two', 'finicky', 'cat'], tags=[458]),
#  TaggedDocument(words=['shelter', 'since', 'year', 'allergy', 'make', 'eye', 'crusty', 'probably', 'reason', 'shelter', 'spend', 'hundred', 'dollar', 'vet', 'get', 'medication', 'prescription', 'also', 'tasty', 'unlike', 'prescription', 'x', 'price'], tags=[459]),
#  TaggedDocument(words=['yr', 'rescue', 'pretty', 'extreme', 'violence', 'starvation'], tags=[460]),
#  TaggedDocument(words=['kittiesshe', 'puke'], tags=[461]),
#  TaggedDocument(words=['switch', 'purina', 'pro', 'adopt', 'second', 'petsmart', 'shelter', 'animal'], tags=[462]),
#  TaggedDocument(words=['purina', 'pro', 'plan', 'excellent', 'brandmy', 'cat'], tags=[463]),
#  TaggedDocument(words=['try', 'brand', 'natural', 'balance', 'wellness', 'poor', 'throwing'], tags=[464]),
#  TaggedDocument(words=['develop', 'digestive', 'issue', 'seem', 'agree', 'fine'], tags=[465]),
#  TaggedDocument(words=['allergy', 'test', 'discover', 'allergic', 'ingredient', 'big', 'name', 'brand', 'food', 'vet', 'recommend', 'worked', 'wonder'], tags=[466]),
#  TaggedDocument(words=['ghost', 'meowzer', 'love', 'itshe', 'get', 'excited', 'bird', 'friendsid', 'purchase'], tags=[467]),
#  TaggedDocument(words=['old', 'rescue', 'shelter', 'half', 'ago', 'tummy', 'issue'], tags=[468]),
#  TaggedDocument(words=['multiple', 'cat'], tags=[469]),
#  TaggedDocument(words=['male', 'tabby', 'female', 'tuxedo'], tags=[470]),
#  TaggedDocument(words=['cat', 'one', 'itchy', 'skin', 'sensitive', 'stomach'], tags=[471]),
#  TaggedDocument(words=['rating', 'actually', 'cat'], tags=[472]),
#  TaggedDocument(words=['vet', 'recommend'], tags=[473]),
#  TaggedDocument(words=['two', 'cat', 'age', '  ', 'sensitive', 'food'], tags=[474]),
#  TaggedDocument(words=['one', 'two', 'standard', 'food', 'cat'], tags=[475]),
#  TaggedDocument(words=[], tags=[476]),
#  TaggedDocument(words=['cat', 'hair', 'shed', 'since', 'buy', 'be', 'not', 'goal', 'allergy', 'problem'], tags=[477]),
#  TaggedDocument(words=['terrible', 'get', 'rid', 'hairball', 'product', 'sell', 'tube'], tags=[478]),
#  TaggedDocument(words=['buy', 'pro', 'plan', 'sensitive', 'skin', 'stomach', 'past', 'year'], tags=[479]),
#  TaggedDocument(words=['provide', 'honest', 'personal', 'review', 'feel', 'taste', 'likely', 'step', 'far', 'taste'], tags=[480]),
#  TaggedDocument(words=['yearold', 'colitis', 'particular', 'eat'], tags=[481]),
#  TaggedDocument(words=['purchase', 'trouble', 'cat', 'vomit'], tags=[482]),
#  TaggedDocument(words=['seem', 'disappear', 'bowl'], tags=[483]),
#  TaggedDocument(words=['probably', 'th', 'tired', 'cat', 'dandruff'], tags=[484]),
#  TaggedDocument(words=['allergy'], tags=[485]),
#  TaggedDocument(words=['extremely', 'sensitive', 'stomach', 'seem', 'one', 'food', 'without', 'we', 'worry', 'keep'], tags=[486]),
#  TaggedDocument(words=['receive', 'open', 'immediately', 'sniff', 'begin', 'eat'], tags=[487]),
#  TaggedDocument(words=['cat', 'help', 'sensitive', 'stomach', 'issue'], tags=[488]),
#  TaggedDocument(words=['cat'], tags=[489]),
#  TaggedDocument(words=['rather', 'overprice', 'even', 'like'], tags=[490]),
#  TaggedDocument(words=['male', 'adult', 'sensitive', 'stomach', 'couple', 'year', 'use', 'different', 'brand', 'raise', 'price', 'try', 'one'], tags=[491]),
#  TaggedDocument(words=['use', 'several', 'purina', 'food', 'settle'], tags=[492]),
#  TaggedDocument(words=['switch', 'felidae', 'can', 'control', 'weight', 'cat', 'vet', 'say', 'cat', 'metabolize', 'carb'], tags=[493]),
#  TaggedDocument(words=['cat'], tags=[494]),
#  TaggedDocument(words=['appreciate', 'ingredient', 'well', 'without', 'expensive'], tags=[495]),
#  TaggedDocument(words=['chelsiey', 'problem', 'switch', 'crappy', 'commercial', 'brand', 'healthy'], tags=[496]),
#  TaggedDocument(words=['cat', 'enjoy'], tags=[497]),
#  TaggedDocument(words=['smell', 'terrible', 'cat', 'touch', 'blame'], tags=[498]),
# ...
#  TaggedDocument(words=['cat'], tags=[833]),
#  TaggedDocument(words=['one', 'well', 'one', 'quality', 'healthy', 'must', 'cat', 'anything', 'else'], tags=[834]),
#  TaggedDocument(words=['break', 'leg', 'back', 'limited', 'mobility', 'use', 'amazon', 'order', 'bulk', 'supply', 'normally', 'pick', 'locally'], tags=[835]),
#  TaggedDocument(words=['love'], tags=[836]),
#  TaggedDocument(words=['one', 'brand', 'available', 'regular', 'grocery', 'store', 'actual', 'meat', 'ingredient', 'instead', 'meal'], tags=[837]),
#  TaggedDocument(words=['ingredient', 'meat', 'primary', 'one'], tags=[838]),
#  TaggedDocument(words=['since', 'use', 'cat', 'few', 'hair', 'ball', 'vet', 'say', 'health'], tags=[839]),
#  TaggedDocument(words=['brand', 'flavor', 'brand', 'cat'], tags=[840]),
#  TaggedDocument(words=['want', 'decent', 'quality', 'gizmo'], tags=[841]),
#  TaggedDocument(words=['let', 'face', 'cat', 'picky'], tags=[842]),
#  TaggedDocument(words=['buy', 'yearold', 'cat', 'normal', 'highquality', 'brand', 'store'], tags=[843]),
#  TaggedDocument(words=['purina', 'one', 'brand', 'like', 'tolerate', 'three', 'cat', 'always', 'try', 'store', 'brand', 'cheap'], tags=[844]),
#  TaggedDocument(words=['cat', 'try', 'different', 'cheap', 'food'], tags=[845]),
#  TaggedDocument(words=['per', 'cat', 'enjoy'], tags=[846]),
#  TaggedDocument(words=['purchase', 'item', 'wish', 'list', 'michigan', 'humane', 'society', 'never', 'use'], tags=[847]),
#  TaggedDocument(words=['get', 'everyday'], tags=[848]),
#  TaggedDocument(words=['use', 'since', 'yearold', 'boy', 'oneyearold'], tags=[849]),
#  TaggedDocument(words=['easy', 'amazon', 'price', 'couple', 'time'], tags=[850]),
#  TaggedDocument(words=['prefer'], tags=[851]),
#  TaggedDocument(words=['give', 'foul', 'diarrhea', 'encounter'], tags=[852]),
#  TaggedDocument(words=['package', 'receive', 'quickly', 'content', 'fresh'], tags=[853]),
#  TaggedDocument(words=['right', 'come', 'closed', 'undamaged'], tags=[854]),
#  TaggedDocument(words=['help', 'stay', 'indoors', 'winter'], tags=[855]),
#  TaggedDocument(words=['cat'], tags=[856]),
#  TaggedDocument(words=['try', 'type', 'cat', 'sniff', 'bowl', 'begin', 'whine', 'emptythis', 'try', 'actually', 'like', 'go', 'past', 'year'], tags=[857]),
#  TaggedDocument(words=['kitten'], tags=[858]),
#  TaggedDocument(words=['review'], tags=[859]),
#  TaggedDocument(words=['kitten', 'crazy'], tags=[860]),
#  TaggedDocument(words=['purina', 'one', 'beyond', 'several', 'month'], tags=[861]),
#  TaggedDocument(words=['give', 'one', 'star', 'since', 'order', 'online', 'probably', 'never', 'due', 'opene', 'thus', 'lead', 'ant', 'inside', 'bagall', 'aside', 'cat', 'whole', 'cost', 'effective', 'natural', 'across', 'feel', 'comfortable', 'feeding', 'cat'], tags=[862]),
#  TaggedDocument(words=['normally', 'petco', 'cheap'], tags=[863]),
#  TaggedDocument(words=['doll', 'face', 'persian'], tags=[864]),
#  TaggedDocument(words=['one', 'need', 'goodquality', 'easy', 'store'], tags=[865]),
#  TaggedDocument(words=['downi', 'diagnose', 'allergy', 'face', 'pay', 'cat'], tags=[866]),
#  TaggedDocument(words=['finicky', 'eater'], tags=[867]),
#  TaggedDocument(words=['cat', 'foodand', 'price', 'right'], tags=[868]),
#  TaggedDocument(words=['arrive', 'bottom', 'inside', 'zippered', 'plastic'], tags=[869]),
#  TaggedDocument(words=['kitty'], tags=[870]),
#  TaggedDocument(words=['extra', 'worth', 'pet', 'healthy', 'old'], tags=[871]),
#  TaggedDocument(words=['least', 'always', 'hungry', 'jump', 'right', 'thinking', 'add', 'rd', 'type', 'different'], tags=[872]),
#  TaggedDocument(words=['three', 'catsone', 'year', 'arthritic', 'one', 'occasional', 'urinary', 'tract', 'problem', 'baby', 'one', 'allergy', 'result', 'exzema', 'diarrhea'], tags=[873]),
#  TaggedDocument(words=['switch', 'exclusively', 'purina', 'brand', 'alternate', 'flavor', 'salmon', 'chickenit', 'mos', 'today', 'stop', 'subscribe', 'save', 'shipment', 'convince', 'make', 'cat', 'three', 'sick'], tags=[874]),
#  TaggedDocument(words=['cat', 'fussy'], tags=[875]),
#  TaggedDocument(words=['cat', 'month', 'foodi', 'science', 'diet', 'kibble', 'one', 'one', 'crumb', 'bowl'], tags=[876]),
#  TaggedDocument(words=['girlfriend', 'puke', 'like', 'experiment', 'think', 'opportunity'], tags=[877]),
#  TaggedDocument(words=['become', 'cat', 'favorite', 'one', 'irritate', 'sensitive', 'stomach'], tags=[878]),
#  TaggedDocument(words=['two', 'week', 'deliver', 'outrageous'], tags=[879]),
#  TaggedDocument(words=['always', 'sensitive', 'stomach', 'try', 'kind', 'expensive', 'formula'], tags=[880]),
#  TaggedDocument(words=['two', 'fat', 'cat', 'close', 'year'], tags=[881]),
#  TaggedDocument(words=['regular', 'basis'], tags=[882]),
#  TaggedDocument(words=['cat', 'nearly', 'impossible', 'area', 'live'], tags=[883]),
#  TaggedDocument(words=['subscribe', 'save', 'make', 'cheap', 'get', 'anywhere', 'else'], tags=[884]),
#  TaggedDocument(words=['noticeably', 'shiny', 'feed'], tags=[885]),
#  TaggedDocument(words=['risk', 'get', 'chastise', 'petfoodie', 'let', 'susceptible', 'creative', 'guiltinducing', 'marketing', 'scheme', 'organic', 'wholefood', 'pet', 'brand'], tags=[886]),
#  TaggedDocument(words=['throw', 'violently', 'eat'], tags=[887]),
#  TaggedDocument(words=['corn', 'biggie', 'one', 'corn', 'allergy'], tags=[888]),
#  TaggedDocument(words=['try', 'alot', 'filler', 'brown', 'rice'], tags=[889]),
#  TaggedDocument(words=['fussy', 'kitty', 'agree', 'salmon', 'brown', 'rice', 'purina', 'one'], tags=[890]),
#  TaggedDocument(words=['appear', 'substitute', 'can', 'previously', 'feed'], tags=[891]),
#  TaggedDocument(words=['star', 'rating', 'pet', 'greatly', 'overprice'], tags=[892]),
#  TaggedDocument(words=['mother', 'house', 'order', 'himhe', 'eat', 'gusto', 'grow', 'weed'], tags=[893]),
#  TaggedDocument(words=['excellent', 'producttake', 'ingredient', 'make', 'quality', 'foodrather', 'meat', 'product', 'corn', 'mealmy', 'picky', 'love'], tags=[894]),
#  TaggedDocument(words=['love', 'far', 'price', 'versus', 'value', 'concern', 'well', 'find'], tags=[895]),
#  TaggedDocument(words=['kitten'], tags=[896]),
#  TaggedDocument(words=['easily', 'transition', 'purina', 'one', 'purina'], tags=[897]),
#  TaggedDocument(words=['care', 'eight', 'kitty', 'freewill', 'time'], tags=[898]),
#  TaggedDocument(words=['special', 'prescription', 'liver', 'year'], tags=[899]),
#  TaggedDocument(words=['cat', 'love'], tags=[900]),
#  TaggedDocument(words=['healthy', 'cat', 'eat'], tags=[901]),
#  TaggedDocument(words=['usually', 'take', 'aback', 'buy', 'purina', 'become', 'nutrition', 'nazi', 'come', 'feed', 'cat'], tags=[902]),
#  TaggedDocument(words=['five', 'cat'], tags=[903]),
#  TaggedDocument(words=['cat', 'eat', 'iam', 'one', 'come', 'diabetes', 'vet', 'suggest', 'brand', 'surprise'], tags=[904]),
#  TaggedDocument(words=['kolohe', 'favorite', 'foodin', 'fact', 'run', 'offer', 'hima', 'substitute', 'act', 'try', 'garbagekolohe', 'give', 'two', 'paw'], tags=[905]),
#  TaggedDocument(words=['cat', 'enjoy', 'five', 'minute'], tags=[906]),
#  TaggedDocument(words=['one', 'hand', 'cat', 'wonder', 'chicken', 'meal', 'make', 'soy', 'product', 'include', 'genetically', 'modify', 'soy', 'soy', 'corn', 'consume', 'united', 'states', 'gm'], tags=[907]),
#  TaggedDocument(words=['omg', 'never', 'smell', 'pet', 'overwhelming', 'awful', 'stench'], tags=[908]),
#  TaggedDocument(words=['highly', 'kitten'], tags=[909]),
#  TaggedDocument(words=['contain', 'ingredientsi', 'check', 'different', 'food', 'may', 'allergic', 'sensitivity', 'certain', 'food', 'mostly', 'wheatthe', 'problem', 'selective', 'eat', 'mixed', 'sniff', 'want'], tags=[910]),
#  TaggedDocument(words=['price'], tags=[911]),
#  TaggedDocument(words=['want', 'kitten', 'always', 'trust', 'purina', 'name'], tags=[912]),
#  TaggedDocument(words=['love', 'eat', 'couple', 'year'], tags=[913]),
#  TaggedDocument(words=['expensive', 'chicken', 'oatmeal'], tags=[914]),
#  TaggedDocument(words=['note', 'there', 's', 'recall', 'brand', 'salmonella', 'contamination'], tags=[915]),
#  TaggedDocument(words=['usually', 'catsicle', 'grainfree', 'seem', 'quality'], tags=[916]),
#  TaggedDocument(words=['college', 'student', 'glad', 'ingredient', 'price', 'range', 'windy', 'chow', 'love', 'natural', 'pet', 'store', 'originally', 'buy'], tags=[917]),
#  TaggedDocument(words=['cottie', 'love'], tags=[918]),
#  TaggedDocument(words=['cat', 'previously', 'healthy', 'eater', 'original', 'purina', 'one', 'formula', 'get', 'sick', 'week'], tags=[919]),
#  TaggedDocument(words=['move', 'away', 'food', 'corn', 'one', 'meet', 'requirement', 'substitute', 'brown', 'rice', 'grain'], tags=[920]),
#  TaggedDocument(words=['like', 'flavor', 'good', 'ingredient', 'chicken'], tags=[921]),
#  TaggedDocument(words=['love', 'junky', 'food', 'plus'], tags=[922]),
#  TaggedDocument(words=['expensive', 'title', 'say', 'cat'], tags=[923]),
#  TaggedDocument(words=['enjoy', 'eat', 'happily'], tags=[924]),
#  TaggedDocument(words=['wheat', 'corn'], tags=[925]),
#  TaggedDocument(words=['go', 'quality', 'reasonable', 'price'], tags=[926]),
#  TaggedDocument(words=['one', 'beyond'], tags=[927]),
#  TaggedDocument(words=['four', 'cat'], tags=[928]),
#  TaggedDocument(words=['buy', 'local', 'animal', 'shelter', 'strictly', 'volunteer'], tags=[929]),
#  TaggedDocument(words=['cat', 'enjoy'], tags=[930]),
#  TaggedDocument(words=['cat'], tags=[931]),
#  TaggedDocument(words=['incredible', 'natural', 'ingredient', 'cat', 'purina', 'one', 'support', 'pet', 'shelter', 'donation', 'wholesome'], tags=[932]),
#  TaggedDocument(words=['always', 'hunt', 'good', 'price'], tags=[933]),
#  TaggedDocument(words=['baby', 'kittys', 'ittheir', 'grow', 'crazyid', 'ownerthis', 'grow', 'strong', 'healthy', 'ingredient'], tags=[934]),
#  TaggedDocument(words=['away', 'carry', 'brand', 'local', 'grocery'], tags=[935]),
#  TaggedDocument(words=['use', 'subscribe', 'save', 'price', 'go', 'cheap', 'grab', 'grocery', 'store', 'end'], tags=[936]),
#  TaggedDocument(words=['balance'], tags=[937]),
#  TaggedDocument(words=['try', 'make', 'yo', 'sick'], tags=[938]),
#  TaggedDocument(words=['healthy', 'seem', 'crazy', 'brand', 'one', 'usually', 'help', 'stomach', 'still', 'mixed', 'hoping', 'reason', 'likely', 'reason', 'flatulence', 'stinky', 'number', 'twos'], tags=[939]),
#  TaggedDocument(words=['hungry', 'yet', 'go', 'nutso'], tags=[940]),
#  TaggedDocument(words=['cat', 'delicious', 'problematic', 'ingredient', 'associate', 'recall', 'year', 'backas', 'people', 'read', 'review', 'feral', 'crf', 'finicky', 'eater'], tags=[941]),
#  TaggedDocument(words=['foster', 'kitten', 'love', 'brand'], tags=[942]),
#  TaggedDocument(words=['cat', 'hard', 'town'], tags=[943]),
#  TaggedDocument(words=['cat', 'purina', 'one', 'beyond', 'vet', 'tell', 'main', 'storebought', 'brand', 'purina'], tags=[944]),
#  TaggedDocument(words=['cat', 'one', 'one', 'mos', 'formula'], tags=[945]),
#  TaggedDocument(words=['eight', 'maine', 'coon', 'rescue'], tags=[946]),
#  TaggedDocument(words=['may', 'scami', 'order', 'item', 'amazon', 'subscribe', 'save', 'feature'], tags=[947]),
#  TaggedDocument(words=['cat', 'healthy', 'brand', 'grocery', 'store'], tags=[948]),
#  TaggedDocument(words=['adopt', 'month', 'ago'], tags=[949]),
#  TaggedDocument(words=['chicken', 'high', 'ingredient', 'list', 'grain', 'suppose', 'well', 'supermarket', 'brand', 'cat', 'reluctantly', 'nothing', 'well', 'available'], tags=[950]),
#  TaggedDocument(words=['picky', 'like'], tags=[951]),
#  TaggedDocument(words=['price', 'unbelievable', 'normally', 'catfood', 'odd', 'flavor', 'since', 'rice', 'thank', 'god', 'purina', 'one', 'brand', 'purina'], tags=[952]),
#  TaggedDocument(words=['kitty', 'try', 'almost', 'store', 'buy'], tags=[953]),
#  TaggedDocument(words=['I', 've', 'weene', 'orphan', 'formula', 'use'], tags=[954]),
#  TaggedDocument(words=['service', 'shipment', 'arrive', 'shortly', 'order'], tags=[955]),
#  TaggedDocument(words=['love'], tags=[956]),
#  TaggedDocument(words=['good', 'ingredient', 'list', 'find', 'far'], tags=[957]),
#  TaggedDocument(words=['cat', 'favorite'], tags=[958]),
#  TaggedDocument(words=['try', 'expensive', 'nongrain', 'food', 'end', 'die', 'undiagnosed', 'digestive', 'issue', 'tell'], tags=[959]),
#  TaggedDocument(words=['cat', 'start', 'woofe', 'right', 'away'], tags=[960]),
#  TaggedDocument(words=['feline', 'companion', 'real', 'treasure', 'people', 'feel', 'companion', 'animal'], tags=[961]),
#  TaggedDocument(words=['store', 'buy', 'choice', 'seem', 'least', 'nowlol', 'thank'], tags=[962]),
#  TaggedDocument(words=['love', 'diabetic', 'yr'], tags=[963]),
#  TaggedDocument(words=['cat', 'picky', 'understate', 'itthey', 'people', 'thingthey', 'touch', 'huh'], tags=[964]),
#  TaggedDocument(words=['cat', 'thisi', 'pay', 'special', 'attention', 'ingredient', 'list', 'pleased', 'include', 'corn', 'product', 'byproduct'], tags=[965]),
#  TaggedDocument(words=['kitten'], tags=[966]),
#  TaggedDocument(words=[], tags=[967]),
#  TaggedDocument(words=['use', 'brand', 'half', 'cat'], tags=[968]),
#  TaggedDocument(words=['three', 'cat'], tags=[969]),
#  TaggedDocument(words=['two', 'cat', 'one', 'sensitive', 'tummy', 'tend', 'loose', 'motion', 'switch', 'right', 'back'], tags=[970]),
#  TaggedDocument(words=['take', 'immediately'], tags=[971]),
#  TaggedDocument(words=['cat', 'enjoy'], tags=[972]),
#  TaggedDocument(words=['problem', 'eat', 'long', 'never', 'throw'], tags=[973]),
#  TaggedDocument(words=['eat', 'whole', 'aevery', 'low', 'price', 'thank', 'keep', 'price', 'lowand', 'top', 'quality'], tags=[974]),
#  TaggedDocument(words=['eat', 'purina', 'brand'], tags=[975]),
#  TaggedDocument(words=['cat', 'favorite', 'anything', 'else'], tags=[976]),
#  TaggedDocument(words=['arrive', 'next', 'week', 'rate', 'acceptance', 'hopefully', 'continue', 'grow', 'maintain', 'health'], tags=[977]),
#  TaggedDocument(words=['surprisingly', 'like', 'especially', 'ease', 'use', 'pouch', 'convenient', 'use'], tags=[978]),
#  TaggedDocument(words=['eld', 'can', 'not', 'anything', 'young'], tags=[979]),
#  TaggedDocument(words=['cat', 'eat', 'food'], tags=[980]),
#  TaggedDocument(words=['one', 'well', 'cheap', 'food', 'far', 'protein', 'content', 'go', 'purchase', 'authority', 'brand', 'nutrition'], tags=[981]),
#  TaggedDocument(words=['well', 'science', 'diet', 'blue'], tags=[982]),
#  TaggedDocument(words=['deal', 'cat'], tags=[983]),
#  TaggedDocument(words=['finickyspoile', 'world'], tags=[984]),
#  TaggedDocument(words=['switch', 'liked', 'fact', 'byproduct', 'everything', 'natural', 'plus', 'could', 'local', 'store'], tags=[985]),
#  TaggedDocument(words=['neon', 'age', 'inflammatory', 'bowel', 'allergic', 'wheat', 'corn', 'beef', 'product'], tags=[986]),
#  TaggedDocument(words=['switch', 'kindey', 'issue', 'patient', 'maintenance', 'uti', 'blockage'], tags=[987]),
#  TaggedDocument(words=['love', 'expenxive', 'amount', 'recieve'], tags=[988]),
#  TaggedDocument(words=['expensive', 'name', 'brand', 'cat', 'throw'], tags=[989]),
#  TaggedDocument(words=['never', 'anything', 'cat', 'repeatedly'], tags=[990]),
#  TaggedDocument(words=['could', 'one', 'star'], tags=[991]),
#  TaggedDocument(words=['look', 'healthy', 'cat', 'break', 'bank'], tags=[992]),
#  TaggedDocument(words=['  ', 'year', 'always', 'digestive', 'troublehad', 'feed', 'brandin', 'crazy', 'smell', 'opening', 'containereven', 'though', 'still', 'like', 'smell', 'brand', 'foodhis', 'tooth', 'mouth', 'can', 'foodafter', 'read', 'couple', 'review', 'purina', 'one', 'beyond', 'foodsalmon', 'brown', 'rice', 'figure', 'brandwell', 'like', 'ithe', 'gain', 'weightpurre', 'playful', 'againno', 'upchuck', 'clean', 'upsthough', 'empty', 'cat', 'bouka', 'often'], tags=[993]),
#  TaggedDocument(words=['seem', 'notice', 'throw'], tags=[994]),
#  TaggedDocument(words=['indooroutdoor', 'conjunction', 'can'], tags=[995]),
#  TaggedDocument(words=['buy', 'grocery', 'store', 'cat'], tags=[996]),
#  TaggedDocument(words=[], tags=[997]),
#  TaggedDocument(words=['long', 'subscribe', 'save', 'account', 'miss', 'convenience', 'deliver'], tags=[998]),
#  TaggedDocument(words=['use', 'hate', 'without', 'also', 'try', 'science', 'diet', 'even', 'hate'], tags=[999]),
#  ...]

# %%
model = Doc2Vec(tagged_data, vector_size = 300, window = 2, min_count = 1, epochs = 100) #window = The maximum distance between the current and predicted word within a sentence.

# %%
with open ('./model/gensim_d2v.pickle', 'wb') as handle:
    pickle.dump(model, handle)

# %%
with open ('./model/gensim_d2v.pickle', 'rb') as handle:
    model = pickle.load(handle)

# %%
def cosine(u, v):
    return np.dot(u, v) / (np.lisimnalg.norm(u) * np.linalg.norm(v))

# %%
cleaned_sents_df1_lst[0]
# Out:
# ['find',
#  'sale',
#  'buy',
#  'whim',
#  'kitten',
#  'omg',
#  'go',
#  'nuts',
#  'hardwood',
#  'spin',
#  'easily',
#  'funny',
#  'kitty',
#  'carry',
#  'around',
#  'mouth',
#  'drop',
#  'shoe',
#  'etc',
#  'fish',
#  'furniture',
#  'constantly',
#  'retrieve']

# %%
test_doc_vector = model.infer_vector(cleaned_sents_df1_lst[0])

# %%
test_doc_vector.shape
# Out:
# (300,)

# %%
vec_features.keys()
# Out:
# dict_keys(['amount', 'beef', 'brand', ('break', 'bank'), 'byproduct', ('calcium', 'carbonate'), 'cheap', 'chicken', ('choline', 'chloride'), 'chunk', ('balanced', 'nutrition'), 'corn', 'cost', ('different', 'flavor'), ('diversity', 'flavor', 'choose'), 'expensive', ('fatty', 'acids'), ('ferrous', 'sulfate'), 'fish', 'flavor', ('folic', 'acid'), 'formula', 'fresh', 'grain', 'gravy', 'health', 'ingredient', 'kibble', ('low', 'carb'), 'meat', 'money', 'natural', ('natural', 'balance'), 'nutrition', ('ocean', 'whitefish'), 'organic', 'pack', ('powdered', 'cellulose'), 'prescription', 'price', 'protein', ('pyridoxine', 'hydrochloride'), 'quality', 'rice', 'salmon', ('save', 'money'), 'several', 'size', 'smell', ('sodium', 'bisulfate'), ('sodium', 'bisulfite'), ('subscribe', 'save'), ('subscribe', 'save', 'option'), ('subscribe', 'save', 'program'), 'taste', ('taste', 'wild'), ('thiamine', 'mononitrate'), 'tuna', 'turkey', 'variety', ('variety', 'pack'), 'vegetable', 'vitamin', ('vitamin', 'b', 'supplement'), ('vitamin', 'e', 'supplement'), ('vitamin', 'nutrient', 'mineral'), ('waste', 'money'), ('zinc', 'oxide'), ('zinc', 'sulfate')])

# %%
test_feature = vec_features['vitamin']

# %%
model.docvecs.most_similar(positive = [test_feature])
# Out:
# [(4167, 0.19710245728492737),
#  (5856, 0.18839430809020996),
#  (4101, 0.18564197421073914),
#  (7613, 0.17812590301036835),
#  (25157, 0.17756879329681396),
#  (719, 0.17687790095806122),
#  (24933, 0.17672832310199738),
#  (13050, 0.17672348022460938),
#  (8078, 0.174940288066864),
#  (19538, 0.17162224650382996)]

# %%
sents_df1.Sentence1[4167] #?????
# Out:
# 'I purchased this particular flavor for a sick senior cat who is slowly loosing her appetite and weight, high calorie item.'

# %%
sents_df1.Sentence1[5856] #?????
# Out:
# 'My cats love this food and I feel good giving them this natural product that caters to senior cats.'

# %%
sents_df1.Sentence1[4101] #?????
# Out:
# 'After putting our kitties on natural treats and food, we gave the California Roll to our kitties for their Christmas last year - all three loved it.'

# %%
# waste money

# %%
test_idx = [idx for idx, sen in enumerate(cleaned_sents_df1_lst) if 'waste' in sen and 'money' in sen]

# %%
sents_df1.Sentence1[test_idx].values.tolist()
# Out:
# ['MY 2 CATS..AGE 4 AND 2...LOVE THIS CAT FOOD SO MUCH THEY WILL NOT EAT ANYTHING ELSE..SO I AM HAPPY BECAUSE I DONT HAVE TO QUESS AT WHAT THEY MIGHT LIKE AND WASTE MONEY ON CAT FOOD..TRYING THEM..I HAVE BEEN FEEDING MINE SINCE THEY WERE 4 MONTHS OLD..WHEN I GOT THEM..',
#  'My cat avoids *healthy* premium cat foods and loves the cheap stuff like Friskies but not wanting to feed that to her I have wasted lots of money on cat food.',
#  "I'm always spending a bunch of money of trying to find different flavors that my picky kitties will eat - so I don't waste my money, ha!",
#  'Wasted money!',
#  "Don't even bother wasting your money.",
#  'My cat is a jerk and will only eat the ocean whitefish, so this variety pack was a waste of money for me.',
#  "For better or worse cats love FANCY FEAST and this Variety Pack is the best one offered because it includes 8 cans of three flavores, including Ocean Whitefish & Tuna, which all cats go bananas for.I tried saving money by giving my kitties store brands, but in reality they're just a waste of money.",
#  "My cat won't even take a bite of this stuff,if I put this in his dish he proceeds to scratch all around it trying to bury it and giving me dirty looks all through his vigorous scratching.To me the food smells like a big bowl of oatmeal, so I can't blame him if he won't try it.For me it was a waste of money.",
#  "Don't waste your money.",
#  'Complete waste of money.',
#  'although  my cats loved the food, the packets are difficult to empty and not muchfood in the packet so it seemed like a waste of money.',
#  "my 2  kitties have allergies ...they are sisters and have always had wet food twice daily...they only lick gravy and don't eat the food so its been a waste of money!",
#  'I have been attempting to feed my cats a healthier diet and this is one of the cat foods I have wasted my money on.',
#  'Bought this to give my 5 outdoor cats a treat, but it was money wasted.',
#  'The product is okay, but I sure wasted alot of money on this....he would not touch it.',
#  'Total waste of money.',
#  'What a waste of money.',
#  "AvoDerm makes high quality cat and dog food, not the best but near the top, don't waste your money or risk your animals health with the grocery store bought garbage, even Purina One which is almost as expensive as AvoDerm I've come to find out is garbage as well.",
#  'For my two cats, this cat food was a waste of my money.',
#  'the vet recommend it for my diabetic cat and he does not seem to like it.. such a waste of money on something he will not eat.',
#  "I was tired of wasting money on cat food that they wouldn't finish.",
#  "still too many dark fish chunks that my cat's won't eat, nor will they eat around them.manufacturer:  please remove the dark pieces - huge waste of money and time for me to pick them out so my cats eat it.",
#  'This was a complete waste of money.',
#  'A few months ago I decided to feed my two cats a healthier diet and wasted a lot of money trying a number of &#34;quality&#34; canned cat foods that my one picky cat refused to eat.',
#  'MY cat must of smelled the fish in these little nuggets..........he clawed right thru the bag to get to them...I have ordered these bags of Meow Mix for about 4 months and the price is super-competitive only $.10 more for a bag and no wasting money on petrol...',
#  "After trying a few different varieties of the expensive, healthy, grain-free cat foods and wasting money because my cat wouldn't eat them, I decided to give the cat food aisle of my local superstore another glance.",
#  'My cats are so finicky and I waste alot of money trying to find wet food they will eat.',
#  'This purchase was a waste of money.']

# %% [markdown]
# # sentence2vec - BERT

# %%
from sentence_transformers import SentenceTransformer
sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
sentence_embeddings = sbert_model.encode(sents_df1.Sentence1.values.tolist()) #embedding

# %%
print('Sample BERT embedding vector - length', len(sentence_embeddings[0]))
# Out:
# Sample BERT embedding vector - length 768

# %%
with open ('./model/sentence_embeddings_bert.pickle', 'wb') as handle:
    pickle.dump(sentence_embeddings, handle)

# %%
feature_vec = sbert_model.encode('vitamin')

# %%
sim_dict = {}
for idx, sent in enumerate(sents_df1.Sentence1.values.tolist()):
  sim = cosine(feature_vec, sbert_model.encode([sent])[0])
  sim_dict[idx] = sim

# %%
sorted_sim_dict = {k: v for k, v in sorted(sim_dict.items(), key=lambda item: item[1], reverse=True)}

# %%
sorted_sim_dict
# Out:
# {12186: 0.710034,
#  6543: 0.68144023,
#  27701: 0.653662,
#  13789: 0.6340372,
#  9269: 0.6264949,
#  19791: 0.619125,
#  25731: 0.61844915,
#  4507: 0.60796356,
#  6332: 0.60796356,
#  13465: 0.60796356,
#  14587: 0.60796356,
#  21161: 0.60796356,
#  24794: 0.60712487,
#  18523: 0.6059896,
#  13359: 0.6044056,
#  24075: 0.60422117,
#  26394: 0.6023675,
#  45: 0.59861326,
#  25947: 0.59699076,
#  20838: 0.5961968,
#  1299: 0.59535897,
#  15240: 0.5951553,
#  1497: 0.59476584,
#  3716: 0.59476584,
#  16963: 0.59476584,
#  20499: 0.5945144,
#  25454: 0.5918907,
#  5987: 0.5913501,
#  27513: 0.5903295,
#  8654: 0.59003514,
#  20601: 0.58909017,
#  12328: 0.5884731,
#  17130: 0.5884731,
#  21176: 0.5883609,
#  23695: 0.5854232,
#  10857: 0.5815563,
#  27109: 0.57915103,
#  15578: 0.57703215,
#  21650: 0.5770303,
#  1082: 0.5756109,
#  22119: 0.5730013,
#  1233: 0.57279265,
#  21254: 0.56937665,
#  21474: 0.56937665,
#  24923: 0.5671596,
#  2207: 0.5642239,
#  24415: 0.5636684,
#  11603: 0.5635812,
#  11732: 0.5635812,
#  5664: 0.563059,
#  15143: 0.5622293,
#  15782: 0.5609278,
#  24068: 0.5590563,
#  27356: 0.55777025,
#  11543: 0.5571845,
#  9034: 0.5565133,
#  15360: 0.5544122,
#  24803: 0.5544122,
#  13742: 0.55231565,
#  19992: 0.55231565,
#  13991: 0.5514835,
#  1164: 0.55133355,
#  22635: 0.5508133,
#  24217: 0.5508133,
#  27636: 0.5508133,
#  15362: 0.55062044,
#  1452: 0.5496266,
#  7402: 0.5487179,
#  13052: 0.5484266,
#  24657: 0.5482705,
#  18884: 0.5479464,
#  16152: 0.547425,
#  7346: 0.5465596,
#  27820: 0.5465596,
#  21004: 0.5464804,
#  25394: 0.5464804,
#  9473: 0.5461985,
#  27124: 0.5452671,
#  10719: 0.5448914,
#  20162: 0.54457,
#  7742: 0.5444403,
#  23150: 0.5444403,
#  3983: 0.5427298,
#  17471: 0.54261464,
#  548: 0.54242694,
#  20034: 0.5405133,
#  25977: 0.53906155,
#  15409: 0.538904,
#  25792: 0.53867555,
#  9861: 0.53861105,
#  5412: 0.5384608,
#  15351: 0.53841907,
#  19498: 0.53841907,
#  22113: 0.5379112,
#  3357: 0.5378961,
#  23761: 0.53765917,
#  5586: 0.53757,
#  9755: 0.5372688,
#  4146: 0.5365273,
#  5010: 0.5365273,
#  27062: 0.5365273,
#  19100: 0.5353157,
#  7561: 0.535192,
#  22003: 0.5347976,
#  27728: 0.5345445,
#  16483: 0.53446776,
#  18983: 0.53446776,
#  27384: 0.53446776,
#  15620: 0.5340336,
#  12673: 0.5336566,
#  2456: 0.5326715,
#  617: 0.5325268,
#  25827: 0.532445,
#  24514: 0.53130233,
#  15885: 0.5295979,
#  24570: 0.52877665,
#  23706: 0.5277118,
#  21942: 0.5276395,
#  11292: 0.52744716,
#  8344: 0.527133,
#  287: 0.5270119,
#  16269: 0.5262619,
#  15775: 0.5259876,
#  8759: 0.5249947,
#  17552: 0.5238033,
#  22098: 0.5234688,
#  27138: 0.5232869,
#  534: 0.5215675,
#  6418: 0.5215675,
#  2480: 0.5215283,
#  5092: 0.5215283,
#  8325: 0.5215283,
#  11609: 0.5215283,
#  12914: 0.5215283,
#  13114: 0.5215283,
#  15604: 0.5215283,
#  17493: 0.5215283,
#  19261: 0.5215283,
#  22124: 0.5215283,
#  22244: 0.5215283,
#  22578: 0.5215283,
#  24417: 0.5215283,
#  27104: 0.5215283,
#  27392: 0.5215283,
#  6053: 0.52088773,
#  2974: 0.5204205,
#  12495: 0.5200281,
#  22860: 0.519498,
#  23519: 0.519498,
#  14306: 0.5191771,
#  12952: 0.5185375,
#  9705: 0.51831734,
#  16735: 0.51831734,
#  14211: 0.51811284,
#  17699: 0.5176662,
#  3521: 0.51740825,
#  15472: 0.51707673,
#  26241: 0.5166704,
#  19505: 0.5165439,
#  7140: 0.5165167,
#  11269: 0.51591516,
#  2904: 0.51543814,
#  8251: 0.51543814,
#  11366: 0.51543814,
#  19175: 0.51543814,
#  15100: 0.5152626,
#  3943: 0.51389766,
#  10988: 0.51387084,
#  21594: 0.51329345,
#  16405: 0.5131917,
#  11663: 0.5130906,
#  22772: 0.5126609,
#  26621: 0.51231337,
#  589: 0.5121459,
#  13601: 0.5115039,
#  4329: 0.5114108,
#  8677: 0.510919,
#  26717: 0.51084083,
#  7332: 0.5104401,
#  6483: 0.5098395,
#  13900: 0.50849795,
#  10593: 0.5084031,
#  21484: 0.50829893,
#  17333: 0.5059681,
#  1785: 0.50587034,
#  12254: 0.50587034,
#  26078: 0.50584733,
#  17395: 0.50506824,
#  13548: 0.5050361,
#  13930: 0.5050361,
#  2804: 0.50482386,
#  11446: 0.50448793,
#  9420: 0.504312,
#  2126: 0.5037838,
#  15853: 0.50363314,
#  20108: 0.5035007,
#  23801: 0.50293696,
#  5675: 0.50289357,
#  23207: 0.50272703,
#  25250: 0.5026759,
#  22515: 0.5019445,
#  23291: 0.5014723,
#  4889: 0.5013512,
#  14609: 0.5004204,
#  1795: 0.50035405,
#  25146: 0.5002293,
#  20154: 0.5000071,
#  25369: 0.4999243,
#  4128: 0.49988553,
#  18515: 0.49988553,
#  17565: 0.49969676,
#  27756: 0.49963057,
#  476: 0.4993214,
#  15863: 0.4992956,
#  22114: 0.499169,
#  23051: 0.49883878,
#  16852: 0.4984968,
#  94: 0.4982889,
#  19979: 0.49813408,
#  6751: 0.49808407,
#  20918: 0.49742773,
#  12469: 0.49739626,
#  4748: 0.49726236,
#  2194: 0.497139,
#  12190: 0.497139,
#  17623: 0.497139,
#  21500: 0.497139,
#  10071: 0.49711826,
#  24483: 0.49704835,
#  17306: 0.49680877,
#  26559: 0.49665025,
#  19404: 0.4966399,
#  22857: 0.4958761,
#  10268: 0.49553123,
#  6260: 0.4951767,
#  182: 0.4949104,
#  26860: 0.49409786,
#  13404: 0.49342808,
#  11281: 0.49313146,
#  18871: 0.49306014,
#  11678: 0.49296355,
#  24035: 0.4926946,
#  25564: 0.49251777,
#  756: 0.49248743,
#  24647: 0.4918368,
#  22325: 0.4911232,
#  23345: 0.49111372,
#  15628: 0.49088022,
#  14092: 0.49084252,
#  27231: 0.490682,
#  16311: 0.49016592,
#  22180: 0.49009848,
#  10432: 0.49008438,
#  7800: 0.4900417,
#  16971: 0.49001148,
#  3400: 0.48979804,
#  17265: 0.48944277,
#  7299: 0.48917422,
#  1028: 0.4891219,
#  6532: 0.48883373,
#  22996: 0.48879611,
#  7404: 0.4885974,
#  16203: 0.4881853,
#  2631: 0.4881513,
#  8936: 0.4881513,
#  27524: 0.48765817,
#  8874: 0.48750335,
#  6518: 0.48704022,
#  26037: 0.4869742,
#  4442: 0.48687193,
#  7315: 0.48687193,
#  9219: 0.48687193,
#  17414: 0.48687193,
#  26698: 0.48687193,
#  9921: 0.48681664,
#  17241: 0.48667568,
#  6037: 0.48665985,
#  16966: 0.48632792,
#  26244: 0.48632792,
#  26504: 0.48632792,
#  23993: 0.48618716,
#  25291: 0.4861026,
#  3266: 0.48606578,
#  24219: 0.4855782,
#  13048: 0.4852233,
#  15223: 0.4852233,
#  1946: 0.4842545,
#  27313: 0.4841329,
#  10877: 0.4841275,
#  23091: 0.4840374,
#  16436: 0.4839329,
#  25185: 0.48392975,
#  19641: 0.48378447,
#  19075: 0.483706,
#  26546: 0.48365355,
#  18149: 0.483626,
#  20825: 0.48310348,
#  56: 0.48296624,
#  27754: 0.48252887,
#  7795: 0.48223567,
#  1235: 0.48166546,
#  22352: 0.48163676,
#  1907: 0.48135036,
#  26570: 0.4806273,
#  18213: 0.48015758,
#  12968: 0.47974133,
#  26228: 0.4794482,
#  4377: 0.47939855,
#  13299: 0.47913155,
#  7693: 0.47895706,
#  25196: 0.47895706,
#  1480: 0.4788322,
#  19095: 0.47882724,
#  21270: 0.47869232,
#  6024: 0.47852704,
#  21627: 0.47805142,
#  23560: 0.47767952,
#  3556: 0.4776335,
#  17656: 0.47758478,
#  13062: 0.47753638,
#  14397: 0.47752756,
#  7825: 0.47727245,
#  21651: 0.47726494,
#  22198: 0.47708565,
#  17534: 0.476789,
#  1707: 0.4767848,
#  1396: 0.47658318,
#  20212: 0.47650754,
#  14590: 0.47649038,
#  18546: 0.47633338,
#  20669: 0.47620478,
#  20361: 0.47599006,
#  8392: 0.4756099,
#  19204: 0.47486183,
#  17273: 0.4746422,
#  1571: 0.47442293,
#  11223: 0.47435272,
#  10749: 0.47416377,
#  4703: 0.47403932,
#  22083: 0.47363833,
#  16062: 0.47362176,
#  24936: 0.47353095,
#  1534: 0.47351706,
#  13541: 0.4734746,
#  27129: 0.4732582,
#  22076: 0.4729341,
#  17501: 0.47286022,
#  5971: 0.47281465,
#  16945: 0.47262385,
#  591: 0.47252497,
#  12267: 0.472442,
#  3275: 0.47223297,
#  26447: 0.47210342,
#  7218: 0.47206527,
#  7575: 0.47201425,
#  17448: 0.47198796,
#  13482: 0.4719797,
#  12477: 0.47165316,
#  1221: 0.4710678,
#  9542: 0.4710678,
#  22538: 0.4710678,
#  16582: 0.47086638,
#  18955: 0.47086638,
#  12062: 0.47068328,
#  14515: 0.47045466,
#  10892: 0.4703745,
#  3972: 0.4703378,
#  15062: 0.47030392,
#  14561: 0.47028267,
#  7245: 0.47024435,
#  12425: 0.47024435,
#  23995: 0.47024435,
#  4577: 0.47020975,
#  6369: 0.4695881,
#  19516: 0.46936938,
#  25499: 0.469344,
#  10408: 0.46862647,
#  17957: 0.46862647,
#  7352: 0.46831298,
#  14943: 0.46827185,
#  18622: 0.46821275,
#  17187: 0.46819305,
#  20817: 0.46818367,
#  21750: 0.46789172,
#  18495: 0.46764383,
#  8782: 0.4673689,
#  2813: 0.46733686,
#  8573: 0.46726534,
#  15950: 0.46705943,
#  19568: 0.4670081,
#  10242: 0.4668966,
#  6223: 0.4666625,
#  19747: 0.46659088,
#  26172: 0.4662731,
#  22591: 0.46619964,
#  25671: 0.46607468,
#  27552: 0.4658848,
#  18409: 0.46576566,
#  20379: 0.46576566,
#  21520: 0.46550673,
#  12226: 0.46549577,
#  20580: 0.46543044,
#  5109: 0.46534428,
#  25225: 0.46533272,
#  2909: 0.46512508,
#  4144: 0.46510994,
#  19742: 0.46509603,
#  1869: 0.46499726,
#  18887: 0.4645637,
#  13096: 0.46450883,
#  5370: 0.4643706,
#  17378: 0.4641048,
#  4834: 0.46408406,
#  27824: 0.46408406,
#  6012: 0.46363816,
#  27054: 0.46361113,
#  15755: 0.4629818,
#  2328: 0.46297312,
#  6475: 0.4629611,
#  23689: 0.4628807,
#  17449: 0.4628627,
#  8831: 0.46272117,
#  3525: 0.4627143,
#  7634: 0.46261987,
#  21922: 0.46258512,
#  5615: 0.462577,
#  13127: 0.4625306,
#  4147: 0.46236145,
#  8445: 0.46197754,
#  12973: 0.46197754,
#  13296: 0.46197754,
#  18959: 0.46197754,
#  20507: 0.46197754,
#  1325: 0.4617894,
#  24447: 0.46145588,
#  20587: 0.4613101,
#  21619: 0.46110752,
#  16356: 0.4609726,
#  16933: 0.46090183,
#  27658: 0.4608239,
#  1311: 0.46078798,
#  12060: 0.46077698,
#  10241: 0.46072838,
#  2440: 0.46049136,
#  27275: 0.4604261,
#  24741: 0.46029365,
#  25982: 0.46029225,
#  15041: 0.4600642,
#  25899: 0.4599155,
#  453: 0.45972747,
#  12399: 0.45963708,
#  20552: 0.4594778,
#  15305: 0.45938483,
#  8813: 0.45908284,
#  7004: 0.45906246,
#  6164: 0.45879775,
#  14130: 0.4584085,
#  26450: 0.4583115,
#  19134: 0.45829952,
#  8182: 0.4582739,
#  23828: 0.4582277,
#  2684: 0.4580938,
#  15421: 0.45801103,
#  24354: 0.45801103,
#  7745: 0.4579727,
#  20372: 0.45785198,
#  20878: 0.45763794,
#  18678: 0.4573471,
#  10041: 0.45666882,
#  15857: 0.45642844,
#  18764: 0.4562215,
#  911: 0.4561067,
#  16047: 0.45596945,
#  24516: 0.45594797,
#  4744: 0.45593426,
#  10235: 0.45558453,
#  21749: 0.45538604,
#  2835: 0.4553571,
#  6746: 0.45520768,
#  13300: 0.45507467,
#  7976: 0.45471084,
#  22747: 0.45471084,
#  25214: 0.45471084,
#  25980: 0.45471084,
#  26177: 0.4545175,
#  22779: 0.45446196,
#  27315: 0.45433316,
#  16757: 0.45401546,
#  4562: 0.4537998,
#  22925: 0.4537806,
#  4446: 0.4537253,
#  2778: 0.4530664,
#  4615: 0.45290938,
#  1859: 0.45279446,
#  21621: 0.45249018,
#  17808: 0.45214194,
#  9458: 0.4519952,
#  23979: 0.45177817,
#  2007: 0.45162752,
#  23693: 0.45136786,
#  6758: 0.45089015,
#  1306: 0.4507636,
#  12239: 0.45069656,
#  5373: 0.45053262,
#  13174: 0.45053104,
#  9391: 0.45030773,
#  14230: 0.45029154,
#  8303: 0.45023072,
#  14599: 0.45016354,
#  6510: 0.44999996,
#  24059: 0.44999084,
#  20595: 0.44939345,
#  5362: 0.4491165,
#  12467: 0.44873056,
#  15562: 0.44873056,
#  19806: 0.44873056,
#  26824: 0.44862324,
#  27327: 0.44837788,
#  2991: 0.4481961,
#  6647: 0.44789857,
#  26924: 0.44789857,
#  27039: 0.44789857,
#  17466: 0.44783193,
#  23884: 0.44774577,
#  20986: 0.44766235,
#  9116: 0.4475986,
#  5784: 0.44753778,
#  14539: 0.44734716,
#  16225: 0.44731614,
#  21351: 0.4472221,
#  720: 0.4467498,
#  12302: 0.44650596,
#  21092: 0.44648844,
#  23096: 0.44646043,
#  1928: 0.4464113,
#  15218: 0.44614917,
#  17583: 0.4460643,
#  25824: 0.44587186,
#  16584: 0.44587073,
#  5449: 0.44585496,
#  25620: 0.4458144,
#  10237: 0.44572595,
#  2893: 0.44552296,
#  19262: 0.4453041,
#  23653: 0.44530067,
#  270: 0.44519886,
#  16449: 0.44505537,
#  25851: 0.44503754,
#  25134: 0.44493183,
#  9056: 0.44475624,
#  20458: 0.44473523,
#  11154: 0.44473153,
#  7935: 0.44469628,
#  4465: 0.44458407,
#  10875: 0.4445481,
#  22289: 0.44433892,
#  14241: 0.44388884,
#  6097: 0.44343248,
#  21716: 0.44340438,
#  9650: 0.44318,
#  26609: 0.44318,
#  33: 0.4430605,
#  11384: 0.4430605,
#  13095: 0.443045,
#  17264: 0.4429687,
#  12756: 0.442953,
#  4888: 0.44270492,
#  9041: 0.44263837,
#  3316: 0.4425754,
#  26258: 0.44254568,
#  24772: 0.44244924,
#  20269: 0.4424089,
#  25317: 0.4423898,
#  6353: 0.4423407,
#  1241: 0.44225755,
#  13006: 0.44191685,
#  1985: 0.4419119,
#  13449: 0.44189075,
#  10219: 0.44184595,
#  5867: 0.44181037,
#  11253: 0.44181037,
#  1449: 0.4418085,
#  19801: 0.44169652,
#  22923: 0.44124192,
#  20180: 0.4412225,
#  15112: 0.44120657,
#  411: 0.44119945,
#  508: 0.44119945,
#  3426: 0.44119945,
#  4384: 0.44119945,
#  5126: 0.44119945,
#  13266: 0.44119945,
#  19433: 0.44119945,
#  23423: 0.44119945,
#  24527: 0.44119945,
#  26630: 0.44119945,
#  1776: 0.44118366,
#  17851: 0.4411079,
#  188: 0.44109082,
#  7633: 0.44103175,
#  8841: 0.4410168,
#  8497: 0.44100115,
#  8799: 0.4408287,
#  10079: 0.44072738,
#  16876: 0.44072738,
#  26208: 0.4406782,
#  6766: 0.44063598,
#  13801: 0.44056755,
#  27381: 0.44038358,
#  5663: 0.44035736,
#  21095: 0.44018465,
#  10019: 0.4401746,
#  9097: 0.44015643,
#  24123: 0.44012454,
#  11395: 0.44001544,
#  17505: 0.4399394,
#  585: 0.43989974,
#  25330: 0.43921152,
#  13190: 0.4391419,
#  19090: 0.4390471,
#  2547: 0.43893656,
#  25468: 0.43887517,
#  12899: 0.43881464,
#  9282: 0.43874818,
#  9690: 0.4387236,
#  25221: 0.4386308,
#  632: 0.4385817,
#  13963: 0.4385511,
#  20378: 0.43849868,
#  14046: 0.43848774,
#  3726: 0.43847513,
#  9960: 0.4383581,
#  27545: 0.4382614,
#  4086: 0.4381618,
#  3511: 0.43804917,
#  7220: 0.43789476,
#  19882: 0.4378259,
#  13899: 0.43782383,
#  15936: 0.43782383,
#  16989: 0.4378235,
#  25546: 0.43776628,
#  23610: 0.4377651,
#  19823: 0.4377584,
#  25769: 0.43773332,
#  25939: 0.43761045,
#  771: 0.4375418,
#  4691: 0.43745396,
#  3839: 0.43733057,
#  20974: 0.43724978,
#  17569: 0.4371179,
#  19778: 0.4368671,
#  85: 0.43666208,
#  11656: 0.43652582,
#  15387: 0.4361302,
#  20573: 0.43604267,
#  8488: 0.43566748,
#  693: 0.43564937,
#  11101: 0.43564937,
#  20394: 0.43562958,
#  5912: 0.43556738,
#  27095: 0.4354606,
#  16473: 0.43520474,
#  9054: 0.43491977,
#  17370: 0.4348482,
#  26948: 0.43470135,
#  7674: 0.4345555,
#  7359: 0.43453854,
#  13063: 0.43449163,
#  13199: 0.43442664,
#  21548: 0.4341284,
#  14592: 0.4341004,
#  22943: 0.43400264,
#  2735: 0.4338204,
#  2674: 0.4336109,
#  5983: 0.43360156,
#  26605: 0.4333922,
#  27796: 0.43318284,
#  5407: 0.43302223,
#  20245: 0.43286553,
#  11489: 0.43274614,
#  5403: 0.4326836,
#  4603: 0.43251938,
#  6392: 0.43238932,
#  23722: 0.43238932,
#  16341: 0.43222204,
#  11976: 0.43163782,
#  17825: 0.43134388,
#  6200: 0.43124545,
#  3795: 0.43124205,
#  6951: 0.43124205,
#  8756: 0.43124205,
#  1290: 0.43118224,
#  1200: 0.43100587,
#  2849: 0.43096346,
#  1165: 0.4309451,
#  153: 0.43091547,
#  5258: 0.43091547,
#  18283: 0.4309063,
#  16733: 0.43084267,
#  314: 0.43081164,
#  23240: 0.4306237,
#  18412: 0.4306172,
#  7535: 0.4306002,
#  10975: 0.43044987,
#  21265: 0.43034312,
#  22260: 0.43001944,
#  12256: 0.42908385,
#  18109: 0.4290763,
#  14107: 0.42899486,
#  27149: 0.42898116,
#  22417: 0.42893958,
#  20709: 0.42871943,
#  10033: 0.42865938,
#  14533: 0.42865744,
#  3727: 0.42862538,
#  17793: 0.42862538,
#  24003: 0.42862538,
#  25328: 0.42862538,
#  9121: 0.42847234,
#  21057: 0.42843,
#  12942: 0.42827004,
#  26253: 0.42826688,
#  17444: 0.4282101,
#  25951: 0.42820072,
#  10683: 0.42810363,
#  8561: 0.42807755,
#  14228: 0.42794567,
#  21130: 0.42777723,
#  26563: 0.4277663,
#  26506: 0.42769516,
#  18572: 0.42759237,
#  13226: 0.42732975,
#  397: 0.42720234,
#  19358: 0.4269194,
#  12946: 0.42689794,
#  8524: 0.42687315,
#  24712: 0.42678255,
#  11402: 0.42671973,
#  5993: 0.42670417,
#  6496: 0.4263627,
#  8335: 0.42614406,
#  22022: 0.42601898,
#  18268: 0.42574054,
#  21817: 0.42558062,
#  24721: 0.42557898,
#  13083: 0.42556432,
#  15225: 0.42549932,
#  27179: 0.42538726,
#  22906: 0.42536336,
#  2138: 0.4251588,
#  6802: 0.4251282,
#  18228: 0.42511773,
#  24142: 0.4250397,
#  14899: 0.42501172,
#  25819: 0.4248867,
#  13846: 0.42486197,
#  25017: 0.42471856,
#  394: 0.42462125,
#  2729: 0.4246208,
#  6234: 0.42457092,
#  7878: 0.42444822,
#  7280: 0.42440277,
#  21267: 0.42439273,
#  8876: 0.4242653,
#  12748: 0.42416155,
#  581: 0.4240098,
#  5001: 0.42390952,
#  4665: 0.4238796,
#  27673: 0.42381006,
#  982: 0.4237945,
#  8728: 0.4235892,
#  7837: 0.42355424,
#  20092: 0.4234456,
#  21901: 0.4234456,
#  25156: 0.4234456,
#  26723: 0.4234456,
#  21481: 0.42322543,
#  7329: 0.42303672,
#  16530: 0.42283863,
#  25590: 0.42283452,
#  24903: 0.42281,
#  9444: 0.42262858,
#  10064: 0.42231664,
#  7450: 0.42218024,
#  10145: 0.4221028,
#  24637: 0.42196876,
#  1114: 0.4218293,
#  8898: 0.4218293,
#  12283: 0.4218293,
#  12896: 0.4218293,
#  27390: 0.4218293,
#  269: 0.42178068,
#  21041: 0.42173618,
#  27367: 0.42144844,
#  18833: 0.42143252,
#  26550: 0.4212352,
#  23730: 0.42102882,
#  22138: 0.4209935,
#  213: 0.4209773,
#  27452: 0.4209146,
#  8371: 0.42075142,
#  6529: 0.42065609,
#  23092: 0.42044982,
#  16856: 0.42035112,
#  4565: 0.41995373,
#  12225: 0.41991693,
#  1921: 0.4199001,
#  8563: 0.41967312,
#  7887: 0.419668,
#  20851: 0.41962552,
#  9870: 0.4194425,
#  3757: 0.4194391,
#  18049: 0.41935754,
#  25525: 0.41929474,
#  1481: 0.4192943,
#  11915: 0.41926244,
#  1512: 0.41912314,
#  22212: 0.41908756,
#  17206: 0.41908276,
#  5682: 0.41885102,
#  5413: 0.4184053,
#  5678: 0.41831556,
#  4696: 0.4181858,
#  16993: 0.41815877,
#  20815: 0.41810995,
#  21499: 0.41802835,
#  23709: 0.4180253,
#  14436: 0.41782635,
#  2918: 0.41771513,
#  3358: 0.41771513,
#  7464: 0.41771513,
#  17011: 0.41771513,
#  20339: 0.41771513,
#  21224: 0.41771513,
#  26591: 0.41771513,
#  12303: 0.41764167,
#  561: 0.41759935,
#  21015: 0.4175833,
#  21336: 0.4173578,
#  20629: 0.41694012,
#  22161: 0.41688356,
#  6907: 0.41680533,
#  3242: 0.4164455,
#  3801: 0.41631934,
#  6222: 0.4162694,
#  19859: 0.4161961,
#  13727: 0.41615915,
#  2507: 0.41602302,
#  16677: 0.41602302,
#  23397: 0.41602302,
#  24846: 0.41602302,
#  26427: 0.41602302,
#  12074: 0.41588002,
#  21948: 0.4157695,
#  18610: 0.41573575,
#  4013: 0.41571066,
#  26024: 0.41566423,
#  11176: 0.4156642,
#  3327: 0.41566315,
#  24667: 0.41558588,
#  1046: 0.41550368,
#  3303: 0.41546947,
#  13600: 0.41535702,
#  25799: 0.41533566,
#  17631: 0.41529703,
#  19212: 0.41515395,
#  6824: 0.41514903,
#  6865: 0.41507387,
#  19064: 0.41498432,
#  17462: 0.41493165,
#  4824: 0.4149189,
#  15779: 0.41491538,
#  21507: 0.4148668,
#  27477: 0.4147558,
#  22719: 0.41462806,
#  19573: 0.41451648,
#  13730: 0.41436943,
#  10602: 0.41421258,
#  152: 0.41392738,
#  19116: 0.4139027,
#  9981: 0.41377276,
#  3840: 0.41374278,
#  21577: 0.41372263,
#  12171: 0.4137204,
#  13895: 0.4136876,
#  22361: 0.41368756,
#  23955: 0.41342163,
#  18182: 0.41332772,
#  19264: 0.41323593,
#  17084: 0.41316015,
#  1638: 0.41313142,
#  5011: 0.4131194,
#  12863: 0.41304916,
#  18528: 0.4129416,
#  13571: 0.41278625,
#  20579: 0.41251203,
#  22373: 0.41251203,
#  12934: 0.41243172,
#  8362: 0.41234607,
#  24674: 0.41228262,
#  25489: 0.41209692,
#  14818: 0.4120924,
#  1296: 0.41205493,
#  19980: 0.41186205,
#  3980: 0.4117251,
#  7323: 0.41171035,
#  11477: 0.41169053,
#  24976: 0.41169053,
#  18638: 0.4116143,
#  2704: 0.4116108,
#  3607: 0.4115798,
#  3626: 0.4114422,
#  21028: 0.4114411,
#  12998: 0.41138506,
#  2197: 0.41132638,
#  7991: 0.41129005,
#  17798: 0.41128284,
#  13: 0.41126114,
#  1969: 0.4111463,
#  17184: 0.4110793,
#  20888: 0.41100162,
#  3516: 0.41094005,
#  20173: 0.41087365,
#  21674: 0.4107511,
#  17673: 0.4106891,
#  14281: 0.41064647,
#  18710: 0.41058975,
#  20111: 0.410559,
#  3328: 0.4105526,
#  3572: 0.41049585,
#  19765: 0.41048175,
#  4401: 0.41041154,
#  11348: 0.41041154,
#  18042: 0.4103361,
#  20146: 0.4103361,
#  27076: 0.41028062,
#  18874: 0.41022676,
#  2770: 0.41020024,
#  19697: 0.41020003,
#  6613: 0.41018775,
#  14719: 0.41000944,
#  1435: 0.40991318,
#  499: 0.40985444,
#  4030: 0.40983304,
#  22382: 0.40982318,
#  25566: 0.40974835,
#  18163: 0.40962783,
#  24032: 0.40962783,
#  27107: 0.40962783,
#  8380: 0.40962082,
#  83: 0.4095066,
#  24341: 0.40942857,
#  27448: 0.4092998,
#  23407: 0.40916967,
#  4461: 0.4088459,
#  606: 0.40872502,
#  5313: 0.40872502,
#  18773: 0.40870827,
#  16106: 0.40867272,
#  7953: 0.4086572,
#  11152: 0.40862072,
#  20406: 0.40860963,
#  11708: 0.4085921,
#  3190: 0.4085437,
#  6468: 0.40836796,
#  7735: 0.40830097,
#  7736: 0.40830097,
#  3524: 0.40809566,
#  24588: 0.40808523,
#  11730: 0.40807113,
#  9212: 0.40804422,
#  21349: 0.40803978,
#  3971: 0.4080202,
#  12694: 0.40776268,
#  28: 0.4075045,
#  3617: 0.40733624,
#  16198: 0.4072071,
#  13041: 0.4071096,
#  12730: 0.40680274,
#  17008: 0.40663975,
#  18269: 0.4066258,
#  21014: 0.40660098,
#  19170: 0.40656087,
#  17419: 0.40649992,
#  3348: 0.40636486,
#  9283: 0.40602455,
#  3300: 0.40598074,
#  9535: 0.40588397,
#  10456: 0.405847,
#  9433: 0.40574035,
#  768: 0.40571594,
#  1263: 0.40561122,
#  16537: 0.40561122,
#  3011: 0.40555865,
#  11684: 0.40552256,
#  10858: 0.405485,
#  11115: 0.40545353,
#  17342: 0.4054174,
#  7499: 0.4053814,
#  11606: 0.40535596,
#  ...}

# %%
sents_df1.Sentence1[list({k for k, v in sim_dict.items() if v > 0.6})]
# Out:
# 26394                                             ..
# 25731                                           Rec.
# 21161                                              .
# 18523                              INGREDIENTS LIST.
# 24075                                           OMG.
# 24794                                        Pros:1.
# 6543                                    with health.
# 13359                                           Hmm.
# 14587                                              .
# 19791           Good for nutrition and fiber intake.
# 9269     There is protein and then there is protein.
# 27701             Likes:- Nutrition and ingredients.
# 13465                                              .
# 12186                                 OK supplement.
# 4507                                               .
# 6332                                               .
# 13789           Rich in oils, vitamins and minerals.
# Name: Sentence1, dtype: object

# %%
sents_df1.Sentence1[list({k for k, v in sim_dict.items() if v > 0.55 and v <= 0.6})]
# Out:
# 15360                                           Ugh.
# 15362                                 Real sardines!
# 3716                                      Seriously.
# 24068                                           Wow.
# 21254                            Subscribe and save!
# 15240                        OK I am a Wellness fan.
# 1164                                      All right.
# 23695                                Mostly protein.
# 21650                          Like the ingredients.
# 1299            Great nutrition per the description.
# 20499                              My name is Petey.
# 11543        This seems to be what is stated on can.
# 19992                                            Hi.
# 24217                                            nan
# 2207                                 Umm, umm, good.
# 5664                             Thank you Wellness!
# 15782                                      Tried to.
# 13991                                     Full 1 LB.
# 12328                                             OK
# 15143                                   MIMZY, HERE.
# 45       It's consisting of good nutrients for Lucy.
# 13742                                            Hi.
# 21176                                          OK. .
# 27513                                            Eh.
# 1082                   For Science Diet KD wet food.
# 16963                                     Seriously.
# 9034                                            Woo.
# 8654                                         Well...
# 1233                                      Its okay..
# 11603                                         Hello.
# 11732                                         Hello.
# 1497                                      Seriously.
# 15578                              Oh wallet relief!
# 24923                    ...on this product from FF.
# 25947                                  Healthy food.
# 27356                               This is ONE can.
# 24415                                           Yep.
# 21474                            Subscribe and save!
# 5987                                        I think.
# 24803                                           UGH.
# 27109                           Great for digestion.
# 20838                                 service grate.
# 22119                                          PATE.
# 10857                        This is a pate formula.
# 17130                                             ok
# 22635                                            nan
# 25454                                   Seriously...
# 27636                                            nan
# 20601                                            PT.
# Name: Sentence1, dtype: object

# %%
sents_df1.Sentence1[list({k for k, v in sim_dict.items() if v > 0.5 and v <= 0.55})]
# Out:
# 27138           Good for their teeth.
# 11269                   Great food...
# 21004                         thanks!
# 15885             Doing subscription.
# 16405                  I mix one tsp.
#                      ...
# 22515                     Last batch.
# 27124           Well, what can I say.
# 15351                    that's okay.
# 24570                          Sorry.
# 26621    Re Kirkland Nature's Domain.
# Name: Sentence1, Length: 141, dtype: object

# %%
sents_df1.Sentence1[list({k for k, v in sim_dict.items() if v > 0.45 and v <= 0.5})]
# Out:
# 10241                                       Good seller.
# 10242                                       great value.
# 9219                                         Great food.
# 1028                                            Finally!
# 17414                                        Great food.
#                               ...
# 27129                                        Love these!
# 10235              Good healthy product at a good price.
# 21500                                    So far so good.
# 10749    Yes, Diamond has had food recalled in the past.
# 1534                                   I'm a vegetarian.
# Name: Sentence1, Length: 302, dtype: object
